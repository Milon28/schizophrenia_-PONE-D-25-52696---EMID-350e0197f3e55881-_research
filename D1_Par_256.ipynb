# %%
# %matplotlib inline

import os

#if using Theano with GPU
#os.environ["KERAS_BACKEND"] = "tensorflow"

import random
import numpy as np
import keras

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib.pyplot import imshow
from keras.models import load_model
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.model_selection import KFold
import seaborn as sns

# %%
# Setup data paths and categories
root = 'f:/SD14/D1_256/D1_Par/Parietal'

categories = [x[0] for x in os.walk(root) if x[0]][1:]

print(categories)
# Out:
# ['f:/SD14/D1_256/D1_Par/Parietal\\Healthy_Control', 'f:/SD14/D1_256/D1_Par/Parietal\\Schizophrenia']

# %%
# helper function to load image and return it and input vector
def get_image(path):
    img = image.load_img(path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return img, x

# %%
# Load data
data = []
for c, category in enumerate(categories):
    images = [os.path.join(dp, f) for dp, dn, filenames
              in os.walk(category) for f in filenames
              if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
    for img_path in images:
        img, x = get_image(img_path)
        data.append({'x':np.array(x[0]), 'y':c})

# count the number of classes
num_classes = len(categories)

# %%
# Generate K-fold splits
num_folds = 10
# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=True, random_state = 42)
fold_no = 1
for train, test in kfold.split(data):
  #print("TRAIN:", train, "TEST:", test)
  if os.path.exists(f"f:/SD14/D1_256/R/par/train/train{fold_no}.csv") == False:
    np.savetxt(f"f:/SD14/D1_256/R/par/train/train{fold_no}.csv", train, delimiter=",", fmt='%s')
    np.savetxt(f"f:/SD14/D1_256/R/par/test/test{fold_no}.csv", test, delimiter=",", fmt='%s')
  else:
    print("exists")
  fold_no = fold_no + 1

# %%
# Prepare data
X, y = np.array([t["x"] for t in data]), np.array([t["y"] for t in data])

# normalize data
X = X.astype('float32') / 255.

# %%
# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []

# Additional performance metric containers
specificity_per_fold = []
sensitivity_per_fold = []
precision_per_fold = []
f1_per_fold = []
fpr_per_fold = []

# For combined confusion matrix
all_y_true = []
all_y_pred = []

import tensorflow as tf
import pandas as pd
from tensorflow.keras import utils as np_utils

tf.keras.backend.clear_session()

# K-fold Cross Validation model evaluation
fold_no = 1
for fold_no in range(1, 11):

    train=pd.read_csv(f"f:/SD14/D1_256/R/par/train/train{fold_no}.csv", sep=',',header=None)
    test=pd.read_csv(f"f:/SD14/D1_256/R/par/test/test{fold_no}.csv", sep=',',header=None)

    x_train = X[train[0]]
    y_train = y[train[0]]
    x_test = X[test[0]]
    y_test = y[test[0]]

    # convert labels to one-hot vectors
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)
    print(y_test.shape)

    # summary
    print("finished loading %d images from %d categories"%(len(data), num_classes))
    print("train / test split: %d, %d"%(len(x_train), len(x_test)))
    print("training data shape: ", x_train.shape)
    print("training labels shape: ", y_train.shape)

    # build the network
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=(224, 224, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Dropout(0.25))

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('relu'))

    model.add(Dropout(0.5))

    model.add(Dense(2))
    model.add(Activation('softmax'))


    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    model.summary()
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    filepath=f"f:/SD14/D1_256/R/par/a/a{fold_no}.best.keras"

    # define early stopping callback
    earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=150, mode='auto')

    # saves the model weights after each epoch if the validation loss decreased
    checkpointer = ModelCheckpoint(filepath=filepath, verbose=1, save_best_only=True, monitor='val_accuracy')

    callbacks_list = [earlystop, checkpointer]

    history = model.fit(x_train, y_train, epochs = 100, batch_size=32,validation_data= (x_test, y_test), callbacks = callbacks_list)

    #load saved best model
    model = load_model(filepath)

    # Generate generalization metrics
    scores = model.evaluate(x_test, y_test, verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    Y_pred = model.predict(x_test)
    y_pred = np.argmax(Y_pred, axis=1)
    y_text_new = np.argmax(y_test, axis=1)

    # Store predictions for combined confusion matrix
    all_y_true.extend(y_text_new)
    all_y_pred.extend(y_pred)

    from sklearn.metrics import classification_report, confusion_matrix
    #Confution Matrix and Classification Report

    print('Confusion Matrix')
    confusion = confusion_matrix(y_text_new, y_pred)
    print(confusion)
    print('Classification Report')
    target_names = ['ScZ', 'Healthy']
    print(classification_report(y_text_new, y_pred, target_names=target_names))

    # Calculate detailed performance metrics
    tn, fp, fn, tp = confusion.ravel()

    # Calculate metrics
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    f1_score = 2 * (precision * sensitivity) / (precision + sensitivity) if (precision + sensitivity) > 0 else 0
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0

    # Store metrics
    specificity_per_fold.append(specificity * 100)
    sensitivity_per_fold.append(sensitivity * 100)
    precision_per_fold.append(precision * 100)
    f1_per_fold.append(f1_score * 100)
    fpr_per_fold.append(fpr * 100)

    print(f'Fold {fold_no} Detailed Metrics:')
    print(f'Specificity: {specificity:.4f} ({specificity*100:.2f}%)')
    print(f'Sensitivity (Recall): {sensitivity:.4f} ({sensitivity*100:.2f}%)')
    print(f'Precision: {precision:.4f} ({precision*100:.2f}%)')
    print(f'F1 Score: {f1_score:.4f} ({f1_score*100:.2f}%)')
    print(f'FPR: {fpr:.4f} ({fpr*100:.2f}%)')
    print('------------------------------------------------------------------------')

    fig = plt.figure(figsize=(16,4))
    ax = fig.add_subplot(121)
    ax.plot(history.history["val_loss"])
    ax.set_title("validation loss")
    ax.set_xlabel("epochs")

    ax2 = fig.add_subplot(122)
    ax2.plot(history.history["val_accuracy"])
    ax2.set_title("validation accuracy")
    ax2.set_xlabel("epochs")
    ax2.set_ylim(0, 1)

    plt.show()

    ax= plt.subplot()
    sns.heatmap(confusion, annot=True, fmt="d", ax = ax); #annot=True to annotate cells

    # labels, title and ticks
    ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
    ax.set_title('Confusion Matrix');
    ax.xaxis.set_ticklabels(['ScZ', 'Normal']); ax.yaxis.set_ticklabels(['ScZ', 'Normal']);
    plt.show()
# Out:
# WARNING:tensorflow:From f:\Milon\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# (961, 2)
# finished loading 9610 images from 2 categories
# train / test split: 8649, 961
# training data shape:  (8649, 224, 224, 3)
# training labels shape:  (8649, 2)
# f:\Milon\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 222, 222, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 109, 109, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 52, 52, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           514 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 2)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,209,058 (4.61 MB)
#  Trainable params: 1,209,058 (4.61 MB)
#  Non-trainable params: 0 (0.00 B)
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.5700 - loss: 0.6819
# Epoch 1: val_accuracy improved from -inf to 0.70135, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 87s 283ms/step - accuracy: 0.5702 - loss: 0.6818 - val_accuracy: 0.7014 - val_loss: 0.5731
# Epoch 2/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7074 - loss: 0.5626
# Epoch 2: val_accuracy improved from 0.70135 to 0.76379, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 260ms/step - accuracy: 0.7074 - loss: 0.5625 - val_accuracy: 0.7638 - val_loss: 0.4777
# Epoch 3/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7663 - loss: 0.4780
# Epoch 3: val_accuracy improved from 0.76379 to 0.83247, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 262ms/step - accuracy: 0.7664 - loss: 0.4779 - val_accuracy: 0.8325 - val_loss: 0.3696
# Epoch 4/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.8281 - loss: 0.3805
# Epoch 4: val_accuracy improved from 0.83247 to 0.84183, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 264ms/step - accuracy: 0.8281 - loss: 0.3805 - val_accuracy: 0.8418 - val_loss: 0.3399
# Epoch 5/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.8400 - loss: 0.3537
# Epoch 5: val_accuracy improved from 0.84183 to 0.85432, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 279ms/step - accuracy: 0.8400 - loss: 0.3537 - val_accuracy: 0.8543 - val_loss: 0.3341
# Epoch 6/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8666 - loss: 0.3151
# Epoch 6: val_accuracy improved from 0.85432 to 0.87929, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 261ms/step - accuracy: 0.8666 - loss: 0.3151 - val_accuracy: 0.8793 - val_loss: 0.2832
# Epoch 7/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.8785 - loss: 0.2793
# Epoch 7: val_accuracy did not improve from 0.87929
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 257ms/step - accuracy: 0.8785 - loss: 0.2793 - val_accuracy: 0.8741 - val_loss: 0.2859
# Epoch 8/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.8963 - loss: 0.2504
# Epoch 8: val_accuracy did not improve from 0.87929
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 259ms/step - accuracy: 0.8962 - loss: 0.2504 - val_accuracy: 0.8730 - val_loss: 0.2869
# Epoch 9/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8988 - loss: 0.2522
# Epoch 9: val_accuracy improved from 0.87929 to 0.88345, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 262ms/step - accuracy: 0.8988 - loss: 0.2522 - val_accuracy: 0.8835 - val_loss: 0.2836
# Epoch 10/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9098 - loss: 0.2240
# Epoch 10: val_accuracy improved from 0.88345 to 0.90114, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 259ms/step - accuracy: 0.9098 - loss: 0.2240 - val_accuracy: 0.9011 - val_loss: 0.2511
# Epoch 11/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9200 - loss: 0.2047
# Epoch 11: val_accuracy did not improve from 0.90114
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 257ms/step - accuracy: 0.9199 - loss: 0.2047 - val_accuracy: 0.8928 - val_loss: 0.2397
# Epoch 12/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9259 - loss: 0.1825
# Epoch 12: val_accuracy did not improve from 0.90114
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 259ms/step - accuracy: 0.9259 - loss: 0.1825 - val_accuracy: 0.8887 - val_loss: 0.2516
# Epoch 13/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9228 - loss: 0.1827
# Epoch 13: val_accuracy improved from 0.90114 to 0.90219, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 261ms/step - accuracy: 0.9228 - loss: 0.1827 - val_accuracy: 0.9022 - val_loss: 0.2280
# Epoch 14/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9332 - loss: 0.1581
# Epoch 14: val_accuracy improved from 0.90219 to 0.90843, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 260ms/step - accuracy: 0.9332 - loss: 0.1581 - val_accuracy: 0.9084 - val_loss: 0.2532
# Epoch 15/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9383 - loss: 0.1571
# Epoch 15: val_accuracy did not improve from 0.90843
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 260ms/step - accuracy: 0.9383 - loss: 0.1571 - val_accuracy: 0.9032 - val_loss: 0.2367
# Epoch 16/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9406 - loss: 0.1341
# Epoch 16: val_accuracy did not improve from 0.90843
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 259ms/step - accuracy: 0.9406 - loss: 0.1341 - val_accuracy: 0.9053 - val_loss: 0.2659
# Epoch 17/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9454 - loss: 0.1461
# Epoch 17: val_accuracy did not improve from 0.90843
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 258ms/step - accuracy: 0.9454 - loss: 0.1461 - val_accuracy: 0.8907 - val_loss: 0.2787
# Epoch 18/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9448 - loss: 0.1456
# Epoch 18: val_accuracy did not improve from 0.90843
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 264ms/step - accuracy: 0.9448 - loss: 0.1456 - val_accuracy: 0.9022 - val_loss: 0.2622
# Epoch 19/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9567 - loss: 0.1256
# Epoch 19: val_accuracy did not improve from 0.90843
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 267ms/step - accuracy: 0.9566 - loss: 0.1256 - val_accuracy: 0.9063 - val_loss: 0.2429
# Epoch 20/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9583 - loss: 0.1149
# Epoch 20: val_accuracy did not improve from 0.90843
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 260ms/step - accuracy: 0.9583 - loss: 0.1149 - val_accuracy: 0.9063 - val_loss: 0.2646
# Epoch 21/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9584 - loss: 0.1134
# Epoch 21: val_accuracy did not improve from 0.90843
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 260ms/step - accuracy: 0.9584 - loss: 0.1134 - val_accuracy: 0.9043 - val_loss: 0.2391
# Epoch 22/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9558 - loss: 0.1037
# Epoch 22: val_accuracy did not improve from 0.90843
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 258ms/step - accuracy: 0.9558 - loss: 0.1037 - val_accuracy: 0.9043 - val_loss: 0.2623
# Epoch 23/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9661 - loss: 0.0974
# Epoch 23: val_accuracy improved from 0.90843 to 0.91259, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 259ms/step - accuracy: 0.9661 - loss: 0.0974 - val_accuracy: 0.9126 - val_loss: 0.2425
# Epoch 24/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9652 - loss: 0.1010
# Epoch 24: val_accuracy did not improve from 0.91259
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 261ms/step - accuracy: 0.9652 - loss: 0.1010 - val_accuracy: 0.9074 - val_loss: 0.2690
# Epoch 25/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9623 - loss: 0.1046
# Epoch 25: val_accuracy did not improve from 0.91259
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 261ms/step - accuracy: 0.9623 - loss: 0.1046 - val_accuracy: 0.9043 - val_loss: 0.2911
# Epoch 26/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9658 - loss: 0.0994
# Epoch 26: val_accuracy did not improve from 0.91259
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 261ms/step - accuracy: 0.9658 - loss: 0.0994 - val_accuracy: 0.9032 - val_loss: 0.2609
# Epoch 27/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9657 - loss: 0.0885
# Epoch 27: val_accuracy did not improve from 0.91259
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 258ms/step - accuracy: 0.9657 - loss: 0.0885 - val_accuracy: 0.8949 - val_loss: 0.2709
# Epoch 28/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9678 - loss: 0.0884
# Epoch 28: val_accuracy did not improve from 0.91259
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 258ms/step - accuracy: 0.9678 - loss: 0.0884 - val_accuracy: 0.9063 - val_loss: 0.2521
# Epoch 29/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9709 - loss: 0.0704
# Epoch 29: val_accuracy did not improve from 0.91259
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 260ms/step - accuracy: 0.9709 - loss: 0.0705 - val_accuracy: 0.9126 - val_loss: 0.2481
# Epoch 30/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9709 - loss: 0.0833
# Epoch 30: val_accuracy did not improve from 0.91259
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 260ms/step - accuracy: 0.9709 - loss: 0.0834 - val_accuracy: 0.9084 - val_loss: 0.2756
# Epoch 31/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9665 - loss: 0.0822
# Epoch 31: val_accuracy improved from 0.91259 to 0.91363, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 82s 304ms/step - accuracy: 0.9665 - loss: 0.0822 - val_accuracy: 0.9136 - val_loss: 0.2654
# Epoch 32/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9721 - loss: 0.0825
# Epoch 32: val_accuracy did not improve from 0.91363
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 85s 315ms/step - accuracy: 0.9721 - loss: 0.0825 - val_accuracy: 0.9095 - val_loss: 0.2728
# Epoch 33/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9771 - loss: 0.0643
# Epoch 33: val_accuracy did not improve from 0.91363
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 83s 306ms/step - accuracy: 0.9771 - loss: 0.0644 - val_accuracy: 0.9116 - val_loss: 0.2809
# Epoch 34/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9706 - loss: 0.0804
# Epoch 34: val_accuracy did not improve from 0.91363
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 83s 306ms/step - accuracy: 0.9706 - loss: 0.0804 - val_accuracy: 0.9043 - val_loss: 0.2977
# Epoch 35/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9703 - loss: 0.0809
# Epoch 35: val_accuracy did not improve from 0.91363
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 279ms/step - accuracy: 0.9703 - loss: 0.0809 - val_accuracy: 0.8980 - val_loss: 0.2722
# Epoch 36/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9743 - loss: 0.0728
# Epoch 36: val_accuracy did not improve from 0.91363
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 295ms/step - accuracy: 0.9743 - loss: 0.0728 - val_accuracy: 0.9074 - val_loss: 0.3025
# Epoch 37/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9694 - loss: 0.0783
# Epoch 37: val_accuracy did not improve from 0.91363
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 295ms/step - accuracy: 0.9694 - loss: 0.0783 - val_accuracy: 0.8928 - val_loss: 0.3036
# Epoch 38/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9737 - loss: 0.0714
# Epoch 38: val_accuracy did not improve from 0.91363
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 295ms/step - accuracy: 0.9737 - loss: 0.0714 - val_accuracy: 0.9032 - val_loss: 0.2782
# Epoch 39/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9740 - loss: 0.0759
# Epoch 39: val_accuracy did not improve from 0.91363
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 294ms/step - accuracy: 0.9740 - loss: 0.0759 - val_accuracy: 0.8949 - val_loss: 0.3327
# Epoch 40/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9749 - loss: 0.0678
# Epoch 40: val_accuracy improved from 0.91363 to 0.91467, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 293ms/step - accuracy: 0.9749 - loss: 0.0678 - val_accuracy: 0.9147 - val_loss: 0.3148
# Epoch 41/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9721 - loss: 0.0763
# Epoch 41: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 295ms/step - accuracy: 0.9721 - loss: 0.0763 - val_accuracy: 0.9032 - val_loss: 0.3009
# Epoch 42/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9770 - loss: 0.0600
# Epoch 42: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 293ms/step - accuracy: 0.9770 - loss: 0.0600 - val_accuracy: 0.8980 - val_loss: 0.3056
# Epoch 43/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9760 - loss: 0.0708
# Epoch 43: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 294ms/step - accuracy: 0.9760 - loss: 0.0708 - val_accuracy: 0.9063 - val_loss: 0.2992
# Epoch 44/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9775 - loss: 0.0610
# Epoch 44: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 293ms/step - accuracy: 0.9775 - loss: 0.0610 - val_accuracy: 0.9043 - val_loss: 0.2608
# Epoch 45/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9777 - loss: 0.0611
# Epoch 45: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 295ms/step - accuracy: 0.9777 - loss: 0.0611 - val_accuracy: 0.9001 - val_loss: 0.3314
# Epoch 46/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9827 - loss: 0.0531
# Epoch 46: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 81s 298ms/step - accuracy: 0.9827 - loss: 0.0531 - val_accuracy: 0.9074 - val_loss: 0.3147
# Epoch 47/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9742 - loss: 0.0649
# Epoch 47: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 294ms/step - accuracy: 0.9742 - loss: 0.0648 - val_accuracy: 0.9043 - val_loss: 0.3054
# Epoch 48/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9792 - loss: 0.0604
# Epoch 48: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 293ms/step - accuracy: 0.9792 - loss: 0.0604 - val_accuracy: 0.9095 - val_loss: 0.2965
# Epoch 49/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9816 - loss: 0.0529
# Epoch 49: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 293ms/step - accuracy: 0.9816 - loss: 0.0529 - val_accuracy: 0.8980 - val_loss: 0.2989
# Epoch 50/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9802 - loss: 0.0589
# Epoch 50: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 293ms/step - accuracy: 0.9801 - loss: 0.0589 - val_accuracy: 0.8939 - val_loss: 0.3253
# Epoch 51/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9769 - loss: 0.0570
# Epoch 51: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 293ms/step - accuracy: 0.9769 - loss: 0.0571 - val_accuracy: 0.9074 - val_loss: 0.3130
# Epoch 52/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9822 - loss: 0.0497
# Epoch 52: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 293ms/step - accuracy: 0.9822 - loss: 0.0497 - val_accuracy: 0.9001 - val_loss: 0.4092
# Epoch 53/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9795 - loss: 0.0561
# Epoch 53: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 294ms/step - accuracy: 0.9795 - loss: 0.0561 - val_accuracy: 0.9105 - val_loss: 0.2927
# Epoch 54/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9768 - loss: 0.0597
# Epoch 54: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 294ms/step - accuracy: 0.9768 - loss: 0.0597 - val_accuracy: 0.9105 - val_loss: 0.3123
# Epoch 55/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9815 - loss: 0.0503
# Epoch 55: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 294ms/step - accuracy: 0.9814 - loss: 0.0503 - val_accuracy: 0.9116 - val_loss: 0.2894
# Epoch 56/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9832 - loss: 0.0474
# Epoch 56: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 293ms/step - accuracy: 0.9832 - loss: 0.0474 - val_accuracy: 0.9043 - val_loss: 0.3412
# Epoch 57/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9801 - loss: 0.0526
# Epoch 57: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 296ms/step - accuracy: 0.9801 - loss: 0.0526 - val_accuracy: 0.9074 - val_loss: 0.3053
# Epoch 58/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9790 - loss: 0.0599
# Epoch 58: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 294ms/step - accuracy: 0.9791 - loss: 0.0599 - val_accuracy: 0.8970 - val_loss: 0.3699
# Epoch 59/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9834 - loss: 0.0503
# Epoch 59: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 293ms/step - accuracy: 0.9834 - loss: 0.0503 - val_accuracy: 0.9074 - val_loss: 0.3096
# Epoch 60/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9807 - loss: 0.0566
# Epoch 60: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 293ms/step - accuracy: 0.9807 - loss: 0.0565 - val_accuracy: 0.9063 - val_loss: 0.3289
# Epoch 61/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9825 - loss: 0.0529
# Epoch 61: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 297ms/step - accuracy: 0.9825 - loss: 0.0529 - val_accuracy: 0.8991 - val_loss: 0.3785
# Epoch 62/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9845 - loss: 0.0491
# Epoch 62: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 291ms/step - accuracy: 0.9845 - loss: 0.0491 - val_accuracy: 0.9022 - val_loss: 0.3350
# Epoch 63/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9813 - loss: 0.0446
# Epoch 63: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 295ms/step - accuracy: 0.9813 - loss: 0.0446 - val_accuracy: 0.9053 - val_loss: 0.3339
# Epoch 64/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9772 - loss: 0.0594
# Epoch 64: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 84s 308ms/step - accuracy: 0.9772 - loss: 0.0594 - val_accuracy: 0.9095 - val_loss: 0.3119
# Epoch 65/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9855 - loss: 0.0404
# Epoch 65: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 294ms/step - accuracy: 0.9855 - loss: 0.0405 - val_accuracy: 0.9011 - val_loss: 0.2958
# Epoch 66/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9818 - loss: 0.0518
# Epoch 66: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 78s 288ms/step - accuracy: 0.9818 - loss: 0.0518 - val_accuracy: 0.9126 - val_loss: 0.3248
# Epoch 67/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9824 - loss: 0.0505
# Epoch 67: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 291ms/step - accuracy: 0.9824 - loss: 0.0505 - val_accuracy: 0.9032 - val_loss: 0.3207
# Epoch 68/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9854 - loss: 0.0417
# Epoch 68: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 81s 298ms/step - accuracy: 0.9854 - loss: 0.0417 - val_accuracy: 0.9105 - val_loss: 0.3064
# Epoch 69/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9844 - loss: 0.0466
# Epoch 69: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 81s 299ms/step - accuracy: 0.9844 - loss: 0.0466 - val_accuracy: 0.8991 - val_loss: 0.3404
# Epoch 70/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9856 - loss: 0.0431
# Epoch 70: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 285ms/step - accuracy: 0.9856 - loss: 0.0431 - val_accuracy: 0.9084 - val_loss: 0.3172
# Epoch 71/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9828 - loss: 0.0490
# Epoch 71: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 286ms/step - accuracy: 0.9828 - loss: 0.0490 - val_accuracy: 0.9084 - val_loss: 0.3636
# Epoch 72/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9841 - loss: 0.0447
# Epoch 72: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 283ms/step - accuracy: 0.9841 - loss: 0.0447 - val_accuracy: 0.9136 - val_loss: 0.3191
# Epoch 73/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9855 - loss: 0.0384
# Epoch 73: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 78s 288ms/step - accuracy: 0.9855 - loss: 0.0384 - val_accuracy: 0.9032 - val_loss: 0.3510
# Epoch 74/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9844 - loss: 0.0393
# Epoch 74: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 290ms/step - accuracy: 0.9844 - loss: 0.0393 - val_accuracy: 0.8991 - val_loss: 0.3558
# Epoch 75/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9854 - loss: 0.0442
# Epoch 75: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 280ms/step - accuracy: 0.9854 - loss: 0.0442 - val_accuracy: 0.9136 - val_loss: 0.3464
# Epoch 76/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9821 - loss: 0.0530
# Epoch 76: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 85s 292ms/step - accuracy: 0.9821 - loss: 0.0530 - val_accuracy: 0.9105 - val_loss: 0.3371
# Epoch 77/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9825 - loss: 0.0421
# Epoch 77: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 79s 293ms/step - accuracy: 0.9825 - loss: 0.0421 - val_accuracy: 0.9053 - val_loss: 0.3611
# Epoch 78/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9838 - loss: 0.0480
# Epoch 78: val_accuracy did not improve from 0.91467
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 80s 297ms/step - accuracy: 0.9838 - loss: 0.0480 - val_accuracy: 0.9084 - val_loss: 0.3395
# Epoch 79/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9866 - loss: 0.0426
# Epoch 79: val_accuracy improved from 0.91467 to 0.91779, saving model to f:/SD14/D1_256/R/par/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 85s 315ms/step - accuracy: 0.9866 - loss: 0.0425 - val_accuracy: 0.9178 - val_loss: 0.3122
# Epoch 80/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9876 - loss: 0.0391
# Epoch 80: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 74s 272ms/step - accuracy: 0.9876 - loss: 0.0391 - val_accuracy: 0.9126 - val_loss: 0.3409
# Epoch 81/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9874 - loss: 0.0383
# Epoch 81: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 78s 289ms/step - accuracy: 0.9874 - loss: 0.0383 - val_accuracy: 0.9063 - val_loss: 0.3589
# Epoch 82/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9839 - loss: 0.0489
# Epoch 82: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 282ms/step - accuracy: 0.9839 - loss: 0.0489 - val_accuracy: 0.9053 - val_loss: 0.3315
# Epoch 83/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9863 - loss: 0.0355
# Epoch 83: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 285ms/step - accuracy: 0.9863 - loss: 0.0355 - val_accuracy: 0.9126 - val_loss: 0.3219
# Epoch 84/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9833 - loss: 0.0439
# Epoch 84: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 78s 286ms/step - accuracy: 0.9833 - loss: 0.0439 - val_accuracy: 0.9011 - val_loss: 0.3516
# Epoch 85/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9872 - loss: 0.0390
# Epoch 85: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 279ms/step - accuracy: 0.9872 - loss: 0.0390 - val_accuracy: 0.8980 - val_loss: 0.3657
# Epoch 86/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9875 - loss: 0.0364
# Epoch 86: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 75s 278ms/step - accuracy: 0.9875 - loss: 0.0364 - val_accuracy: 0.9032 - val_loss: 0.3669
# Epoch 87/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9864 - loss: 0.0379
# Epoch 87: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 74s 275ms/step - accuracy: 0.9864 - loss: 0.0379 - val_accuracy: 0.8980 - val_loss: 0.3769
# Epoch 88/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9848 - loss: 0.0407
# Epoch 88: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 74s 272ms/step - accuracy: 0.9848 - loss: 0.0408 - val_accuracy: 0.9116 - val_loss: 0.3510
# Epoch 89/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9856 - loss: 0.0416
# Epoch 89: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 263ms/step - accuracy: 0.9856 - loss: 0.0416 - val_accuracy: 0.9105 - val_loss: 0.3241
# Epoch 90/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9902 - loss: 0.0328
# Epoch 90: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 262ms/step - accuracy: 0.9902 - loss: 0.0328 - val_accuracy: 0.9126 - val_loss: 0.3731
# Epoch 91/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9880 - loss: 0.0354
# Epoch 91: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 262ms/step - accuracy: 0.9880 - loss: 0.0354 - val_accuracy: 0.9095 - val_loss: 0.3611
# Epoch 92/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9861 - loss: 0.0400
# Epoch 92: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 261ms/step - accuracy: 0.9861 - loss: 0.0400 - val_accuracy: 0.9043 - val_loss: 0.3531
# Epoch 93/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9873 - loss: 0.0396
# Epoch 93: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 263ms/step - accuracy: 0.9873 - loss: 0.0396 - val_accuracy: 0.8959 - val_loss: 0.4157
# Epoch 94/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9877 - loss: 0.0313
# Epoch 94: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 266ms/step - accuracy: 0.9877 - loss: 0.0313 - val_accuracy: 0.8970 - val_loss: 0.4232
# Epoch 95/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9878 - loss: 0.0321
# Epoch 95: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 267ms/step - accuracy: 0.9878 - loss: 0.0321 - val_accuracy: 0.8991 - val_loss: 0.3862
# Epoch 96/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9839 - loss: 0.0380
# Epoch 96: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 81s 297ms/step - accuracy: 0.9839 - loss: 0.0380 - val_accuracy: 0.9043 - val_loss: 0.3244
# Epoch 97/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9877 - loss: 0.0379
# Epoch 97: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 284ms/step - accuracy: 0.9877 - loss: 0.0379 - val_accuracy: 0.9126 - val_loss: 0.3366
# Epoch 98/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9898 - loss: 0.0376
# Epoch 98: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 283ms/step - accuracy: 0.9898 - loss: 0.0376 - val_accuracy: 0.9043 - val_loss: 0.3354
# Epoch 99/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9868 - loss: 0.0382
# Epoch 99: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 279ms/step - accuracy: 0.9868 - loss: 0.0382 - val_accuracy: 0.9147 - val_loss: 0.3361
# Epoch 100/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9866 - loss: 0.0354
# Epoch 100: val_accuracy did not improve from 0.91779
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 281ms/step - accuracy: 0.9866 - loss: 0.0354 - val_accuracy: 0.9032 - val_loss: 0.3756
# Score for fold 1: loss of 0.3121996223926544; compile_metrics of 91.77939891815186%
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# Confusion Matrix
# [[398  33]
#  [ 46 484]]
# Classification Report
#               precision    recall  f1-score   support
#
#          ScZ       0.90      0.92      0.91       431
#      Healthy       0.94      0.91      0.92       530
#
#     accuracy                           0.92       961
#    macro avg       0.92      0.92      0.92       961
# weighted avg       0.92      0.92      0.92       961
#
# Fold 1 Detailed Metrics:
# Specificity: 0.9234 (92.34%)
# Sensitivity (Recall): 0.9132 (91.32%)
# Precision: 0.9362 (93.62%)
# F1 Score: 0.9245 (92.45%)
# FPR: 0.0766 (7.66%)
# ------------------------------------------------------------------------
# (961, 2)
# finished loading 9610 images from 2 categories
# train / test split: 8649, 961
# training data shape:  (8649, 224, 224, 3)
# training labels shape:  (8649, 2)
# f:\Milon\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 222, 222, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 109, 109, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 109, 109, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 52, 52, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 52, 52, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 26, 26, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 24, 24, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           514 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 2)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,209,058 (4.61 MB)
#  Trainable params: 1,209,058 (4.61 MB)
#  Non-trainable params: 0 (0.00 B)
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.5558 - loss: 0.6757
# Epoch 1: val_accuracy improved from -inf to 0.68678, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 90s 268ms/step - accuracy: 0.5560 - loss: 0.6755 - val_accuracy: 0.6868 - val_loss: 0.5773
# Epoch 2/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.6991 - loss: 0.5653
# Epoch 2: val_accuracy improved from 0.68678 to 0.76483, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 73s 268ms/step - accuracy: 0.6992 - loss: 0.5652 - val_accuracy: 0.7648 - val_loss: 0.4781
# Epoch 3/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.7808 - loss: 0.4715
# Epoch 3: val_accuracy improved from 0.76483 to 0.82518, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 73s 270ms/step - accuracy: 0.7808 - loss: 0.4715 - val_accuracy: 0.8252 - val_loss: 0.4190
# Epoch 4/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.8033 - loss: 0.4163
# Epoch 4: val_accuracy improved from 0.82518 to 0.83247, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 245ms/step - accuracy: 0.8034 - loss: 0.4162 - val_accuracy: 0.8325 - val_loss: 0.3761
# Epoch 5/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.8389 - loss: 0.3537
# Epoch 5: val_accuracy improved from 0.83247 to 0.84391, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 73s 269ms/step - accuracy: 0.8389 - loss: 0.3537 - val_accuracy: 0.8439 - val_loss: 0.3421
# Epoch 6/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8607 - loss: 0.3229
# Epoch 6: val_accuracy improved from 0.84391 to 0.85536, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 266ms/step - accuracy: 0.8607 - loss: 0.3229 - val_accuracy: 0.8554 - val_loss: 0.3264
# Epoch 7/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.8753 - loss: 0.2875
# Epoch 7: val_accuracy improved from 0.85536 to 0.86785, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 73s 268ms/step - accuracy: 0.8753 - loss: 0.2875 - val_accuracy: 0.8678 - val_loss: 0.3091
# Epoch 8/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.8836 - loss: 0.2696
# Epoch 8: val_accuracy improved from 0.86785 to 0.88450, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 280ms/step - accuracy: 0.8836 - loss: 0.2696 - val_accuracy: 0.8845 - val_loss: 0.2818
# Epoch 9/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9008 - loss: 0.2325
# Epoch 9: val_accuracy did not improve from 0.88450
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 267ms/step - accuracy: 0.9008 - loss: 0.2325 - val_accuracy: 0.8793 - val_loss: 0.2937
# Epoch 10/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9119 - loss: 0.2205
# Epoch 10: val_accuracy improved from 0.88450 to 0.88762, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 265ms/step - accuracy: 0.9118 - loss: 0.2205 - val_accuracy: 0.8876 - val_loss: 0.2738
# Epoch 11/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9204 - loss: 0.1964
# Epoch 11: val_accuracy did not improve from 0.88762
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 263ms/step - accuracy: 0.9204 - loss: 0.1965 - val_accuracy: 0.8855 - val_loss: 0.2888
# Epoch 12/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9286 - loss: 0.1884
# Epoch 12: val_accuracy did not improve from 0.88762
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 259ms/step - accuracy: 0.9286 - loss: 0.1883 - val_accuracy: 0.8866 - val_loss: 0.2574
# Epoch 13/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9352 - loss: 0.1641
# Epoch 13: val_accuracy improved from 0.88762 to 0.90635, saving model to f:/SD14/D1_256/R/par/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 267ms/step - accuracy: 0.9352 - loss: 0.1642 - val_accuracy: 0.9063 - val_loss: 0.2433
# Epoch 14/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9398 - loss: 0.1597
# Epoch 14: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 263ms/step - accuracy: 0.9398 - loss: 0.1597 - val_accuracy: 0.8949 - val_loss: 0.2588
# Epoch 15/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9440 - loss: 0.1449
# Epoch 15: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 281ms/step - accuracy: 0.9440 - loss: 0.1450 - val_accuracy: 0.8928 - val_loss: 0.2631
# Epoch 16/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9458 - loss: 0.1265
# Epoch 16: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 280ms/step - accuracy: 0.9458 - loss: 0.1266 - val_accuracy: 0.8970 - val_loss: 0.2614
# Epoch 17/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9444 - loss: 0.1386
# Epoch 17: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 73s 270ms/step - accuracy: 0.9444 - loss: 0.1386 - val_accuracy: 0.9022 - val_loss: 0.2421
# Epoch 18/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9485 - loss: 0.1302
# Epoch 18: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 74s 271ms/step - accuracy: 0.9485 - loss: 0.1302 - val_accuracy: 0.8959 - val_loss: 0.2585
# Epoch 19/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9454 - loss: 0.1360
# Epoch 19: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 75s 275ms/step - accuracy: 0.9455 - loss: 0.1359 - val_accuracy: 0.8949 - val_loss: 0.2748
# Epoch 20/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9589 - loss: 0.1022
# Epoch 20: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 75s 276ms/step - accuracy: 0.9589 - loss: 0.1022 - val_accuracy: 0.8897 - val_loss: 0.2766
# Epoch 21/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9598 - loss: 0.1033
# Epoch 21: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 73s 269ms/step - accuracy: 0.9597 - loss: 0.1033 - val_accuracy: 0.8939 - val_loss: 0.2973
# Epoch 22/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9606 - loss: 0.1083
# Epoch 22: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9606 - loss: 0.1083 - val_accuracy: 0.9001 - val_loss: 0.2531
# Epoch 23/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9650 - loss: 0.1014
# Epoch 23: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 249ms/step - accuracy: 0.9650 - loss: 0.1015 - val_accuracy: 0.8918 - val_loss: 0.2840
# Epoch 24/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9601 - loss: 0.1031
# Epoch 24: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 65s 241ms/step - accuracy: 0.9601 - loss: 0.1031 - val_accuracy: 0.9043 - val_loss: 0.2689
# Epoch 25/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9633 - loss: 0.0940
# Epoch 25: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9633 - loss: 0.0940 - val_accuracy: 0.9001 - val_loss: 0.2579
# Epoch 26/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9657 - loss: 0.1008
# Epoch 26: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 78s 287ms/step - accuracy: 0.9657 - loss: 0.1008 - val_accuracy: 0.8959 - val_loss: 0.3042
# Epoch 27/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9679 - loss: 0.0871
# Epoch 27: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 75s 278ms/step - accuracy: 0.9679 - loss: 0.0871 - val_accuracy: 0.8939 - val_loss: 0.2780
# Epoch 28/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9683 - loss: 0.0805
# Epoch 28: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 74s 272ms/step - accuracy: 0.9683 - loss: 0.0805 - val_accuracy: 0.8866 - val_loss: 0.2774
# Epoch 29/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9714 - loss: 0.0762
# Epoch 29: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 280ms/step - accuracy: 0.9713 - loss: 0.0762 - val_accuracy: 0.8845 - val_loss: 0.3351
# Epoch 30/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9688 - loss: 0.0860
# Epoch 30: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 74s 272ms/step - accuracy: 0.9688 - loss: 0.0860 - val_accuracy: 0.8928 - val_loss: 0.2829
# Epoch 31/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9744 - loss: 0.0689
# Epoch 31: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 283ms/step - accuracy: 0.9744 - loss: 0.0689 - val_accuracy: 0.8762 - val_loss: 0.2946
# Epoch 32/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9686 - loss: 0.0828
# Epoch 32: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 266ms/step - accuracy: 0.9686 - loss: 0.0828 - val_accuracy: 0.8793 - val_loss: 0.3237
# Epoch 33/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9734 - loss: 0.0731
# Epoch 33: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 74s 273ms/step - accuracy: 0.9735 - loss: 0.0731 - val_accuracy: 0.8907 - val_loss: 0.2894
# Epoch 34/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9728 - loss: 0.0735
# Epoch 34: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 257ms/step - accuracy: 0.9728 - loss: 0.0735 - val_accuracy: 0.8980 - val_loss: 0.3069
# Epoch 35/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9713 - loss: 0.0761
# Epoch 35: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 265ms/step - accuracy: 0.9713 - loss: 0.0761 - val_accuracy: 0.8803 - val_loss: 0.3066
# Epoch 36/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9773 - loss: 0.0645
# Epoch 36: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 246ms/step - accuracy: 0.9773 - loss: 0.0646 - val_accuracy: 0.8855 - val_loss: 0.3026
# Epoch 37/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9770 - loss: 0.0689
# Epoch 37: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 75s 275ms/step - accuracy: 0.9770 - loss: 0.0689 - val_accuracy: 0.8824 - val_loss: 0.2858
# Epoch 38/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9746 - loss: 0.0600
# Epoch 38: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 77s 285ms/step - accuracy: 0.9746 - loss: 0.0600 - val_accuracy: 0.8814 - val_loss: 0.2787
# Epoch 39/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9737 - loss: 0.0726
# Epoch 39: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 266ms/step - accuracy: 0.9737 - loss: 0.0726 - val_accuracy: 0.8959 - val_loss: 0.2810
# Epoch 40/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9809 - loss: 0.0545
# Epoch 40: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 248ms/step - accuracy: 0.9809 - loss: 0.0545 - val_accuracy: 0.8876 - val_loss: 0.3003
# Epoch 41/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9795 - loss: 0.0628
# Epoch 41: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9795 - loss: 0.0628 - val_accuracy: 0.8897 - val_loss: 0.2923
# Epoch 42/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9763 - loss: 0.0676
# Epoch 42: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9764 - loss: 0.0676 - val_accuracy: 0.8824 - val_loss: 0.3585
# Epoch 43/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9758 - loss: 0.0681
# Epoch 43: val_accuracy did not improve from 0.90635
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9758 - loss: 0.0681 - val_accuracy: 0.8876 - val_loss: 0.3044
# Epoch 44/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9727 - loss: 0.0689
# Epoch 44: val_accuracy did not improve from 0.90635
# ...
# Epoch 43: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9657 - loss: 0.0931 - val_accuracy: 0.8949 - val_loss: 0.3539
# Epoch 44/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9738 - loss: 0.0711
# Epoch 44: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.9738 - loss: 0.0711 - val_accuracy: 0.8970 - val_loss: 0.3470
# Epoch 45/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9732 - loss: 0.0704
# Epoch 45: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.9732 - loss: 0.0704 - val_accuracy: 0.8845 - val_loss: 0.3651
# Epoch 46/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9777 - loss: 0.0626
# Epoch 46: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.9777 - loss: 0.0626 - val_accuracy: 0.8855 - val_loss: 0.4006
# Epoch 47/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9787 - loss: 0.0670
# Epoch 47: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.9787 - loss: 0.0670 - val_accuracy: 0.8980 - val_loss: 0.3545
# Epoch 48/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9792 - loss: 0.0579
# Epoch 48: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9792 - loss: 0.0579 - val_accuracy: 0.8835 - val_loss: 0.4057
# Epoch 49/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9737 - loss: 0.0680
# Epoch 49: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9737 - loss: 0.0680 - val_accuracy: 0.8845 - val_loss: 0.3531
# Epoch 50/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9824 - loss: 0.0583
# Epoch 50: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9824 - loss: 0.0583 - val_accuracy: 0.8835 - val_loss: 0.3813
# Epoch 51/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9773 - loss: 0.0602
# Epoch 51: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 65s 242ms/step - accuracy: 0.9773 - loss: 0.0602 - val_accuracy: 0.8897 - val_loss: 0.3955
# Epoch 52/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9794 - loss: 0.0580
# Epoch 52: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9794 - loss: 0.0580 - val_accuracy: 0.8835 - val_loss: 0.3971
# Epoch 53/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9745 - loss: 0.0715
# Epoch 53: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 248ms/step - accuracy: 0.9745 - loss: 0.0715 - val_accuracy: 0.8835 - val_loss: 0.4074
# Epoch 54/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9813 - loss: 0.0551
# Epoch 54: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9813 - loss: 0.0551 - val_accuracy: 0.8980 - val_loss: 0.3692
# Epoch 55/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9810 - loss: 0.0651
# Epoch 55: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9810 - loss: 0.0651 - val_accuracy: 0.8855 - val_loss: 0.3901
# Epoch 56/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9811 - loss: 0.0510
# Epoch 56: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9811 - loss: 0.0510 - val_accuracy: 0.8855 - val_loss: 0.4379
# Epoch 57/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9732 - loss: 0.0652
# Epoch 57: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.9732 - loss: 0.0652 - val_accuracy: 0.8876 - val_loss: 0.3700
# Epoch 58/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9795 - loss: 0.0561
# Epoch 58: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.9795 - loss: 0.0561 - val_accuracy: 0.8855 - val_loss: 0.3922
# Epoch 59/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9775 - loss: 0.0576
# Epoch 59: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.9775 - loss: 0.0576 - val_accuracy: 0.8897 - val_loss: 0.3510
# Epoch 60/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9832 - loss: 0.0479
# Epoch 60: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9832 - loss: 0.0480 - val_accuracy: 0.8876 - val_loss: 0.3929
# Epoch 61/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9796 - loss: 0.0606
# Epoch 61: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9796 - loss: 0.0606 - val_accuracy: 0.8824 - val_loss: 0.4041
# Epoch 62/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9794 - loss: 0.0521
# Epoch 62: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9794 - loss: 0.0521 - val_accuracy: 0.8897 - val_loss: 0.3454
# Epoch 63/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9795 - loss: 0.0624
# Epoch 63: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9795 - loss: 0.0623 - val_accuracy: 0.8897 - val_loss: 0.3889
# Epoch 64/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9803 - loss: 0.0590
# Epoch 64: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9803 - loss: 0.0590 - val_accuracy: 0.8959 - val_loss: 0.3727
# Epoch 65/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9809 - loss: 0.0575
# Epoch 65: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9809 - loss: 0.0575 - val_accuracy: 0.8835 - val_loss: 0.4074
# Epoch 66/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9824 - loss: 0.0465
# Epoch 66: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9824 - loss: 0.0466 - val_accuracy: 0.8928 - val_loss: 0.3556
# Epoch 67/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9789 - loss: 0.0546
# Epoch 67: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 248ms/step - accuracy: 0.9789 - loss: 0.0546 - val_accuracy: 0.8845 - val_loss: 0.4500
# Epoch 68/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9817 - loss: 0.0510
# Epoch 68: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9818 - loss: 0.0510 - val_accuracy: 0.8793 - val_loss: 0.4038
# Epoch 69/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9850 - loss: 0.0458
# Epoch 69: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.9850 - loss: 0.0458 - val_accuracy: 0.8959 - val_loss: 0.3759
# Epoch 70/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9834 - loss: 0.0465
# Epoch 70: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9834 - loss: 0.0465 - val_accuracy: 0.8783 - val_loss: 0.4694
# Epoch 71/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9845 - loss: 0.0466
# Epoch 71: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9845 - loss: 0.0466 - val_accuracy: 0.8866 - val_loss: 0.4352
# Epoch 72/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9803 - loss: 0.0511
# Epoch 72: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9803 - loss: 0.0511 - val_accuracy: 0.8897 - val_loss: 0.4087
# Epoch 73/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9828 - loss: 0.0464
# Epoch 73: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9828 - loss: 0.0464 - val_accuracy: 0.8939 - val_loss: 0.4212
# Epoch 74/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9848 - loss: 0.0438
# Epoch 74: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9848 - loss: 0.0438 - val_accuracy: 0.8866 - val_loss: 0.3769
# Epoch 75/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9828 - loss: 0.0490
# Epoch 75: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9828 - loss: 0.0490 - val_accuracy: 0.8949 - val_loss: 0.3697
# Epoch 76/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9829 - loss: 0.0488
# Epoch 76: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9829 - loss: 0.0488 - val_accuracy: 0.8887 - val_loss: 0.4265
# Epoch 77/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9824 - loss: 0.0463
# Epoch 77: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9824 - loss: 0.0463 - val_accuracy: 0.8866 - val_loss: 0.3754
# Epoch 78/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9818 - loss: 0.0446
# Epoch 78: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9818 - loss: 0.0446 - val_accuracy: 0.8866 - val_loss: 0.4396
# Epoch 79/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9847 - loss: 0.0381
# Epoch 79: val_accuracy did not improve from 0.89802
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9847 - loss: 0.0381 - val_accuracy: 0.8835 - val_loss: 0.4923
# Epoch 80/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9852 - loss: 0.0439
# Epoch 80: val_accuracy improved from 0.89802 to 0.89906, saving model to f:/SD14/D1_256/R/par/a/a10.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 247ms/step - accuracy: 0.9852 - loss: 0.0438 - val_accuracy: 0.8991 - val_loss: 0.3652
# Epoch 81/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9857 - loss: 0.0435
# Epoch 81: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 248ms/step - accuracy: 0.9857 - loss: 0.0435 - val_accuracy: 0.8876 - val_loss: 0.3982
# Epoch 82/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9838 - loss: 0.0442
# Epoch 82: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9838 - loss: 0.0442 - val_accuracy: 0.8772 - val_loss: 0.4830
# Epoch 83/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9814 - loss: 0.0477
# Epoch 83: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9814 - loss: 0.0477 - val_accuracy: 0.8907 - val_loss: 0.4127
# Epoch 84/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9860 - loss: 0.0398
# Epoch 84: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9860 - loss: 0.0398 - val_accuracy: 0.8876 - val_loss: 0.4483
# Epoch 85/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9813 - loss: 0.0508
# Epoch 85: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 243ms/step - accuracy: 0.9813 - loss: 0.0508 - val_accuracy: 0.8918 - val_loss: 0.3675
# Epoch 86/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9823 - loss: 0.0450
# Epoch 86: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9823 - loss: 0.0450 - val_accuracy: 0.8855 - val_loss: 0.3951
# Epoch 87/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9826 - loss: 0.0508
# Epoch 87: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 245ms/step - accuracy: 0.9826 - loss: 0.0508 - val_accuracy: 0.8824 - val_loss: 0.4890
# Epoch 88/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9816 - loss: 0.0514
# Epoch 88: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9816 - loss: 0.0514 - val_accuracy: 0.8897 - val_loss: 0.4576
# Epoch 89/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9879 - loss: 0.0336
# Epoch 89: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9879 - loss: 0.0336 - val_accuracy: 0.8814 - val_loss: 0.4605
# Epoch 90/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9861 - loss: 0.0438
# Epoch 90: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9861 - loss: 0.0438 - val_accuracy: 0.8876 - val_loss: 0.4130
# Epoch 91/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9815 - loss: 0.0440
# Epoch 91: val_accuracy did not improve from 0.89906
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 247ms/step - accuracy: 0.9815 - loss: 0.0440 - val_accuracy: 0.8928 - val_loss: 0.3896
# Epoch 92/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9872 - loss: 0.0391
# Epoch 92: val_accuracy improved from 0.89906 to 0.90427, saving model to f:/SD14/D1_256/R/par/a/a10.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 245ms/step - accuracy: 0.9872 - loss: 0.0391 - val_accuracy: 0.9043 - val_loss: 0.3731
# Epoch 93/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9896 - loss: 0.0322
# Epoch 93: val_accuracy did not improve from 0.90427
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9896 - loss: 0.0321 - val_accuracy: 0.8824 - val_loss: 0.4968
# Epoch 94/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9830 - loss: 0.0470
# Epoch 94: val_accuracy did not improve from 0.90427
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 248ms/step - accuracy: 0.9830 - loss: 0.0470 - val_accuracy: 0.8918 - val_loss: 0.4741
# Epoch 95/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9832 - loss: 0.0444
# Epoch 95: val_accuracy did not improve from 0.90427
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 246ms/step - accuracy: 0.9832 - loss: 0.0444 - val_accuracy: 0.8959 - val_loss: 0.4044
# Epoch 96/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9844 - loss: 0.0447
# Epoch 96: val_accuracy did not improve from 0.90427
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9844 - loss: 0.0447 - val_accuracy: 0.8845 - val_loss: 0.4377
# Epoch 97/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9857 - loss: 0.0423
# Epoch 97: val_accuracy did not improve from 0.90427
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 244ms/step - accuracy: 0.9857 - loss: 0.0423 - val_accuracy: 0.8845 - val_loss: 0.4057
# Epoch 98/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9877 - loss: 0.0352
# Epoch 98: val_accuracy did not improve from 0.90427
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 245ms/step - accuracy: 0.9877 - loss: 0.0352 - val_accuracy: 0.8918 - val_loss: 0.4586
# Epoch 99/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9897 - loss: 0.0290
# Epoch 99: val_accuracy did not improve from 0.90427
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 66s 245ms/step - accuracy: 0.9897 - loss: 0.0290 - val_accuracy: 0.8907 - val_loss: 0.4000
# Epoch 100/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9904 - loss: 0.0313
# Epoch 100: val_accuracy did not improve from 0.90427
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 67s 245ms/step - accuracy: 0.9904 - loss: 0.0313 - val_accuracy: 0.8928 - val_loss: 0.4365
# Score for fold 10: loss of 0.37309080362319946; compile_metrics of 90.42664170265198%
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
# Confusion Matrix
# [[369  46]
#  [ 46 500]]
# Classification Report
#               precision    recall  f1-score   support
#
#          ScZ       0.89      0.89      0.89       415
#      Healthy       0.92      0.92      0.92       546
#
#     accuracy                           0.90       961
#    macro avg       0.90      0.90      0.90       961
# weighted avg       0.90      0.90      0.90       961
#
# Fold 10 Detailed Metrics:
# Specificity: 0.8892 (88.92%)
# Sensitivity (Recall): 0.9158 (91.58%)
# Precision: 0.9158 (91.58%)
# F1 Score: 0.9158 (91.58%)
# FPR: 0.1108 (11.08%)
# ------------------------------------------------------------------------

# %%
# == Provide average scores ==
print('========================================================================')
print('                          COMPREHENSIVE RESULTS                        ')
print('========================================================================')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1}:')
  print(f'  - Accuracy: {acc_per_fold[i]:.2f}%')
  print(f'  - Loss: {loss_per_fold[i]:.4f}')
  print(f'  - Specificity: {specificity_per_fold[i]:.2f}%')
  print(f'  - Sensitivity: {sensitivity_per_fold[i]:.2f}%')
  print(f'  - Precision: {precision_per_fold[i]:.2f}%')
  print(f'  - F1 Score: {f1_per_fold[i]:.2f}%')
  print(f'  - FPR: {fpr_per_fold[i]:.2f}%')

print('========================================================================')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (± {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f} (± {np.std(loss_per_fold):.4f})')
print(f'> Specificity: {np.mean(specificity_per_fold):.2f}% (± {np.std(specificity_per_fold):.2f}%)')
print(f'> Sensitivity: {np.mean(sensitivity_per_fold):.2f}% (± {np.std(sensitivity_per_fold):.2f}%)')
print(f'> Precision: {np.mean(precision_per_fold):.2f}% (± {np.std(precision_per_fold):.2f}%)')
print(f'> F1 Score: {np.mean(f1_per_fold):.2f}% (± {np.std(f1_per_fold):.2f}%)')
print(f'> FPR: {np.mean(fpr_per_fold):.2f}% (± {np.std(fpr_per_fold):.2f}%)')
print('========================================================================')

# Fold-wise performance visualization
plt.figure(figsize=(20, 14))
plt.rcParams.update({'font.size': 12})  # Set global font size

# Plot each metric across folds
metrics = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
metric_data = [acc_per_fold, specificity_per_fold, sensitivity_per_fold,
               precision_per_fold, f1_per_fold, fpr_per_fold]

# Color palette for different metrics
colors = ['#2E86C1', '#28B463', '#F39C12', '#E74C3C', '#8E44AD', '#D35400']

for i, (metric, data) in enumerate(zip(metrics, metric_data)):
    plt.subplot(2, 3, i+1)
    folds = range(1, num_folds+1)

    # Plot main line with enhanced styling
    plt.plot(folds, data, 'o-', linewidth=3, markersize=10, color=colors[i],
             markerfacecolor='white', markeredgewidth=2, markeredgecolor=colors[i],
             label=f'{metric} Values')

    plt.title(f'{metric} Across All Folds', fontsize=16, fontweight='bold', pad=15)
    plt.xlabel('Fold Number', fontsize=14, fontweight='bold')
    plt.ylabel(f'{metric} (%)', fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
    plt.xticks(folds, fontsize=12, fontweight='bold')
    plt.yticks(fontsize=12, fontweight='bold')

    # Add mean line with improved styling
    mean_val = np.mean(data)
    std_val = np.std(data)
    plt.axhline(y=mean_val, color='red', linestyle='--', linewidth=2, alpha=0.8,
                label=f'Mean: {mean_val:.2f}%')

    # Add standard deviation band
    plt.fill_between(folds, mean_val - std_val, mean_val + std_val,
                     alpha=0.2, color='red', label=f'±1 SD: {std_val:.2f}%')

    # Customize legend
    plt.legend(loc='best', fontsize=11, frameon=True, fancybox=True, shadow=True)

    # Set y-axis limits for better visualization
    if metric != 'FPR':
        plt.ylim(max(0, min(data) - 5), min(100, max(data) + 5))
    else:
        plt.ylim(0, max(data) + 2)

plt.tight_layout(pad=3.0)
plt.suptitle('',
             fontsize=20, fontweight='bold', y=0.98)
plt.show()
# Out:
# ========================================================================
#                           COMPREHENSIVE RESULTS
# ========================================================================
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1:
#   - Accuracy: 91.78%
#   - Loss: 0.3122
#   - Specificity: 92.34%
#   - Sensitivity: 91.32%
#   - Precision: 93.62%
#   - F1 Score: 92.45%
#   - FPR: 7.66%
# ------------------------------------------------------------------------
# > Fold 2:
#   - Accuracy: 90.63%
#   - Loss: 0.2433
#   - Specificity: 88.71%
#   - Sensitivity: 92.28%
#   - Precision: 90.53%
#   - F1 Score: 91.40%
#   - FPR: 11.29%
# ------------------------------------------------------------------------
# > Fold 3:
#   - Accuracy: 90.53%
#   - Loss: 0.4452
#   - Specificity: 91.03%
#   - Sensitivity: 90.11%
#   - Precision: 92.40%
#   - F1 Score: 91.24%
#   - FPR: 8.97%
# ------------------------------------------------------------------------
# > Fold 4:
#   - Accuracy: 89.49%
#   - Loss: 0.4123
#   - Specificity: 89.37%
#   - Sensitivity: 89.60%
#   - Precision: 90.14%
#   - F1 Score: 89.87%
#   - FPR: 10.63%
# ------------------------------------------------------------------------
# > Fold 5:
#   - Accuracy: 91.57%
#   - Loss: 0.3344
#   - Specificity: 90.40%
#   - Sensitivity: 92.51%
#   - Precision: 92.34%
#   - F1 Score: 92.42%
#   - FPR: 9.60%
# ------------------------------------------------------------------------
# > Fold 6:
#   - Accuracy: 91.05%
#   - Loss: 0.4145
#   - Specificity: 89.31%
#   - Sensitivity: 92.41%
#   - Precision: 91.73%
#   - F1 Score: 92.07%
#   - FPR: 10.69%
# ------------------------------------------------------------------------
# > Fold 7:
#   - Accuracy: 91.36%
#   - Loss: 0.3341
#   - Specificity: 91.88%
#   - Sensitivity: 90.94%
#   - Precision: 93.23%
#   - F1 Score: 92.07%
#   - FPR: 8.12%
# ------------------------------------------------------------------------
# > Fold 8:
#   - Accuracy: 90.43%
#   - Loss: 0.3284
#   - Specificity: 92.23%
#   - Sensitivity: 89.07%
#   - Precision: 93.86%
#   - F1 Score: 91.40%
#   - FPR: 7.77%
# ------------------------------------------------------------------------
# > Fold 9:
#   - Accuracy: 92.09%
#   - Loss: 0.3199
#   - Specificity: 91.58%
#   - Sensitivity: 92.57%
#   - Precision: 92.20%
#   - F1 Score: 92.38%
#   - FPR: 8.42%
# ------------------------------------------------------------------------
# > Fold 10:
#   - Accuracy: 90.43%
#   - Loss: 0.3731
#   - Specificity: 88.92%
#   - Sensitivity: 91.58%
#   - Precision: 91.58%
#   - F1 Score: 91.58%
#   - FPR: 11.08%
# ========================================================================
# Average scores for all folds:
# > Accuracy: 90.94% (± 0.74%)
# > Loss: 0.3517 (± 0.0568)
# > Specificity: 90.58% (± 1.34%)
# > Sensitivity: 91.24% (± 1.21%)
# > Precision: 92.16% (± 1.16%)
# > F1 Score: 91.69% (± 0.75%)
# > FPR: 9.42% (± 1.34%)
# ========================================================================

# %%
# Radar plot for average performance
from math import pi
import matplotlib.pyplot as plt

# %%
# Create radar plot with enhanced styling
categories_radar = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score']
values = [np.mean(acc_per_fold), np.mean(specificity_per_fold),
          np.mean(sensitivity_per_fold), np.mean(precision_per_fold),
          np.mean(f1_per_fold)]

# Number of variables
N = len(categories_radar)

# Compute angle for each axis
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]  # Complete the circle

# Add values to complete the circle
values += values[:1]

# Create the plot with enhanced styling
fig, ax = plt.subplots(figsize=(14, 14), subplot_kw=dict(projection='polar'))

# Plot the values with enhanced styling
ax.plot(angles, values, 'o-', linewidth=4, color='#2E86C1', alpha=0.8,
        markersize=12, markerfacecolor='white', markeredgewidth=3, markeredgecolor='#2E86C1')
ax.fill(angles, values, alpha=0.3, color='#2E86C1')

# Add labels with proper font sizes - positioned further outside
ax.set_xticks(angles[:-1])
ax.set_xticklabels([])  # Remove default labels

# Manually position category labels further outside
for angle, category in zip(angles[:-1], categories_radar):
    # Position labels much further outside the chart
    label_distance = 115  # Much further than the 100% circle
    ax.text(angle, label_distance, category,
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=16,
            fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.5',
                     facecolor='lightblue',
                     alpha=0.8,
                     edgecolor='navy',
                     linewidth=1))

# Set y-axis limits and labels
ax.set_ylim(0, 100)
ax.set_yticks([20, 40, 60, 80, 100])
ax.set_yticklabels(['20%', '40%', '60%', '80%', '100%'], fontsize=14, fontweight='bold')

# Add enhanced grid
ax.grid(True, alpha=0.4, linewidth=1.2)

# Add values as text with better positioning - closer to the data points
for angle, value in zip(angles[:-1], values[:-1]):
    # Position value labels closer to the actual data points
    value_distance = value + 5  # Just slightly outside the data point
    ax.text(angle, value_distance, f'{value:.1f}%',
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=14,
            fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.3',
                     facecolor='white',
                     edgecolor='#2E86C1',
                     alpha=0.9,
                     linewidth=1.5))

plt.title('Average Performance Metrics - Radar Chart\nSchizophrenia Classification Model Performance',
          size=18, fontweight='bold', pad=70)
plt.tight_layout()
plt.show()

# %%
# Summary comparison plot - All folds on one radar plot
fig, ax = plt.subplots(figsize=(16, 16), subplot_kw=dict(projection='polar'))

# Enhanced colors for better distinction
fold_colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEAA7',
               '#DDA0DD', '#98D8C8', '#F7DC6F', '#BB8FCE', '#85C1E9']

# Plot each fold on the same radar plot
for fold_idx in range(10):
    fold_values = [acc_per_fold[fold_idx], specificity_per_fold[fold_idx],
                   sensitivity_per_fold[fold_idx], precision_per_fold[fold_idx],
                   f1_per_fold[fold_idx]]

    # Add values to complete the circle
    fold_values_plot = fold_values + fold_values[:1]

    # Plot the values with enhanced styling
    ax.plot(angles, fold_values_plot, 'o-', linewidth=2,
            color=fold_colors[fold_idx], alpha=0.7, markersize=6,
            label=f'Fold {fold_idx + 1} (Avg: {np.mean(fold_values):.1f}%)')
    ax.fill(angles, fold_values_plot, alpha=0.1, color=fold_colors[fold_idx])

# Plot average line with enhanced styling
avg_values = [np.mean(acc_per_fold), np.mean(specificity_per_fold),
              np.mean(sensitivity_per_fold), np.mean(precision_per_fold),
              np.mean(f1_per_fold)]
avg_values_plot = avg_values + avg_values[:1]

ax.plot(angles, avg_values_plot, 'o-', linewidth=5,
        color='red', alpha=0.9, markersize=12,
        markerfacecolor='white', markeredgewidth=3, markeredgecolor='red',
        label=f'Average Performance ({np.mean(avg_values):.1f}%)', zorder=10)
ax.fill(angles, avg_values_plot, alpha=0.3, color='red')

# Fix category labels - position them further outside
ax.set_xticks(angles[:-1])
ax.set_xticklabels([])  # Remove default labels

# Manually position category labels further outside the chart
for angle, category in zip(angles[:-1], categories_radar):
    # Position labels much further outside the chart
    label_distance = 120  # Much further than the 100% circle
    ax.text(angle, label_distance, category,
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=16,
            fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.5',
                     facecolor='lightblue',
                     alpha=0.8,
                     edgecolor='navy',
                     linewidth=1))

# Set y-axis limits and labels
ax.set_ylim(0, 100)
ax.set_yticks([20, 40, 60, 80, 100])
ax.set_yticklabels(['20%', '40%', '60%', '80%', '100%'], fontsize=14, fontweight='bold')

# Add enhanced grid
ax.grid(True, alpha=0.4, linewidth=1.2)

# Add comprehensive legend
ax.legend(loc='upper right', bbox_to_anchor=(1.4, 1.1), fontsize=11,
          frameon=True, fancybox=True, shadow=True, ncol=1)

# Add average values as text - positioned closer to data points
for angle, value in zip(angles[:-1], avg_values):
    value_distance = value + 8  # Just slightly outside the data point
    ax.text(angle, value_distance, f'{value:.1f}%',
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=12,
            fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.3',
                     facecolor='red',
                     alpha=0.7,
                     edgecolor='white'))

plt.title('Cross-Validation Performance Comparison\nAll Folds vs Average Performance\nSchizophrenia Classification Model',
          size=18, fontweight='bold', pad=80)
plt.tight_layout()
plt.show()

# %%
# Box Plots with Standard Deviation - Centered Layout
print('Generating comprehensive box plots with standard deviation...')

# Prepare data for box plots
metrics_names = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
metrics_data = [acc_per_fold, specificity_per_fold, sensitivity_per_fold,
                precision_per_fold, f1_per_fold, fpr_per_fold]

# Enhanced color palette
box_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6', '#E67E22']

# Create comprehensive box plot with centered layout
fig = plt.figure(figsize=(24, 16))
fig.suptitle('Performance Metrics Distribution Analysis\nSchizophrenia Classification Model - 10-Fold Cross-Validation\n(Box Plots with Statistical Measures)',
             fontsize=20, fontweight='bold', y=0.95)

# Create subplots with custom positioning for centering
# Top row: 3 plots
for i in range(3):
    ax = plt.subplot(2, 3, i + 1)
    metric_name = metrics_names[i]
    metric_values = metrics_data[i]

    # Create box plot with enhanced styling
    bp = ax.boxplot(metric_values, patch_artist=True, widths=0.7,
                    boxprops=dict(facecolor=box_colors[i], alpha=0.7, linewidth=2),
                    medianprops=dict(color='darkblue', linewidth=3),
                    whiskerprops=dict(linewidth=2),
                    capprops=dict(linewidth=2),
                    flierprops=dict(marker='o', markerfacecolor='red', markersize=8, alpha=0.7))

    # Calculate statistics
    mean_val = np.mean(metric_values)
    std_val = np.std(metric_values)
    median_val = np.median(metric_values)
    min_val = np.min(metric_values)
    max_val = np.max(metric_values)

    # Add mean line with enhanced styling
    ax.axhline(y=mean_val, color='red', linestyle='-', linewidth=3, alpha=0.9,
               label=f'Mean: {mean_val:.2f}%')

    # Add standard deviation bands
    ax.axhline(y=mean_val + std_val, color='orange', linestyle='--', linewidth=2, alpha=0.8,
               label=f'+1 SD: {mean_val + std_val:.2f}%')
    ax.axhline(y=mean_val - std_val, color='orange', linestyle='--', linewidth=2, alpha=0.8,
               label=f'-1 SD: {mean_val - std_val:.2f}%')
    ax.fill_between([0.5, 1.5], mean_val - std_val, mean_val + std_val, alpha=0.25, color='orange')

    # Enhanced plot customization
    ax.set_title(f'{metric_name} Distribution', fontsize=16, fontweight='bold', pad=15)
    ax.set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
    ax.legend(loc='upper right', fontsize=11, frameon=True, fancybox=True, shadow=True)

    # Enhanced statistics text box
    stats_text = f'📊 Statistics:\nMean: {mean_val:.2f}%\nStd Dev: {std_val:.2f}%\nMedian: {median_val:.2f}%\nRange: {min_val:.2f}% - {max_val:.2f}%\nCV: {(std_val/mean_val)*100:.1f}%'
    ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, fontsize=11, fontweight='bold',
            verticalalignment='top',
            bbox=dict(boxstyle='round,pad=0.5', facecolor='white', alpha=0.9,
                     edgecolor=box_colors[i], linewidth=2))

    # Enhanced x-axis labeling
    ax.set_xticklabels([metric_name], fontsize=14, fontweight='bold')
    ax.tick_params(axis='y', labelsize=12, labelcolor='black')

    # Set appropriate y-limits
    y_min = max(0, min_val - std_val - 5)
    y_max = min(100 if metric_name != 'FPR' else max_val + std_val + 5, max_val + std_val + 5)
    ax.set_ylim(y_min, y_max)

# Bottom row: 3 plots centered (using positions 4, 5, 6 which centers them)
for i in range(3, 6):
    ax = plt.subplot(2, 3, i + 1)
    metric_name = metrics_names[i]
    metric_values = metrics_data[i]

    # Create box plot with enhanced styling
    bp = ax.boxplot(metric_values, patch_artist=True, widths=0.7,
                    boxprops=dict(facecolor=box_colors[i], alpha=0.7, linewidth=2),
                    medianprops=dict(color='darkblue', linewidth=3),
                    whiskerprops=dict(linewidth=2),
                    capprops=dict(linewidth=2),
                    flierprops=dict(marker='o', markerfacecolor='red', markersize=8, alpha=0.7))

    # Calculate statistics
    mean_val = np.mean(metric_values)
    std_val = np.std(metric_values)
    median_val = np.median(metric_values)
    min_val = np.min(metric_values)
    max_val = np.max(metric_values)

    # Add mean line with enhanced styling
    ax.axhline(y=mean_val, color='red', linestyle='-', linewidth=3, alpha=0.9,
               label=f'Mean: {mean_val:.2f}%')

    # Add standard deviation bands
    ax.axhline(y=mean_val + std_val, color='orange', linestyle='--', linewidth=2, alpha=0.8,
               label=f'+1 SD: {mean_val + std_val:.2f}%')
    ax.axhline(y=mean_val - std_val, color='orange', linestyle='--', linewidth=2, alpha=0.8,
               label=f'-1 SD: {mean_val - std_val:.2f}%')
    ax.fill_between([0.5, 1.5], mean_val - std_val, mean_val + std_val, alpha=0.25, color='orange')

    # Enhanced plot customization
    ax.set_title(f'{metric_name} Distribution', fontsize=16, fontweight='bold', pad=15)
    ax.set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
    ax.legend(loc='upper right', fontsize=11, frameon=True, fancybox=True, shadow=True)

    # Enhanced statistics text box
    stats_text = f'📊 Statistics:\nMean: {mean_val:.2f}%\nStd Dev: {std_val:.2f}%\nMedian: {median_val:.2f}%\nRange: {min_val:.2f}% - {max_val:.2f}%\nCV: {(std_val/mean_val)*100:.1f}%'
    ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, fontsize=11, fontweight='bold',
            verticalalignment='top',
            bbox=dict(boxstyle='round,pad=0.5', facecolor='white', alpha=0.9,
                     edgecolor=box_colors[i], linewidth=2))

    # Enhanced x-axis labeling
    ax.set_xticklabels([metric_name], fontsize=14, fontweight='bold')
    ax.tick_params(axis='y', labelsize=12, labelcolor='black')

    # Set appropriate y-limits
    y_min = max(0, min_val - std_val - 5)
    y_max = min(100 if metric_name != 'FPR' else max_val + std_val + 5, max_val + std_val + 5)
    ax.set_ylim(y_min, y_max)

plt.tight_layout(pad=3.0)
plt.subplots_adjust(top=0.90)  # Adjust for the main title
plt.show()
# Out:
# Generating comprehensive box plots with standard deviation...
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\1756891483.py:126: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(pad=3.0)
# f:\Milon\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Combined Box Plot - All metrics together for comparison
plt.figure(figsize=(14, 10))

# Prepare data for combined box plot (excluding FPR for better scale)
combined_data = [acc_per_fold, specificity_per_fold, sensitivity_per_fold,
                 precision_per_fold, f1_per_fold]
combined_labels = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score']

# Enhanced color palette
combined_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6']

# Create combined box plot with enhanced styling
bp = plt.boxplot(combined_data, labels=combined_labels, patch_artist=True, widths=0.7,
                 boxprops=dict(linewidth=2),
                 medianprops=dict(color='darkblue', linewidth=3),
                 whiskerprops=dict(linewidth=2),
                 capprops=dict(linewidth=2),
                 flierprops=dict(marker='o', markerfacecolor='red', markersize=8, alpha=0.7))

# Color each box differently with enhanced styling
for patch, color in zip(bp['boxes'], combined_colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

# Calculate means and stds
means = [np.mean(data) for data in combined_data]
stds = [np.std(data) for data in combined_data]

# Find the maximum value in the data to position mean markers above
max_values = [np.max(data) for data in combined_data]

# Add mean diamonds OUTSIDE/ABOVE each box plot
for i, (mean_val, std_val, max_val) in enumerate(zip(means, stds, max_values)):
    # Position mean marker above the box plot
    mean_position = max_val + 1.5  # Position above the highest point

    plt.plot(i+1, mean_position, 'D', color='red', markersize=12, markeredgecolor='darkred',
             markeredgewidth=2, label='Mean Values' if i == 0 else "", zorder=10)

    # Add text label with mean value
    plt.text(i+1, mean_position + 0.5, f'{mean_val:.1f}%',
             horizontalalignment='center', fontsize=11, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8, edgecolor='red'))

    # Add error bars for standard deviation - also positioned above
    plt.errorbar(i+1, mean_position, yerr=std_val, fmt='none', color='red',
                 capsize=8, capthick=2, linewidth=2, alpha=0.8,
                 label='±1 Standard Deviation' if i == 0 else "")

# Adjust y-axis to reduce gaps and focus on the data range
data_min = min([np.min(data) for data in combined_data])
data_max = max([np.max(data) for data in combined_data])
mean_position_max = max([np.max(data) + 1.5 for data in combined_data])

# Set tighter y-limits to reduce empty space
y_min = data_min - 1  # Small buffer below minimum
y_max = mean_position_max + 2  # Small buffer above mean markers
plt.ylim(y_min, y_max)

# Enhanced plot styling
plt.title('Performance Metrics Comparative Analysis\nSchizophrenia Classification Model (10-Fold Cross-Validation)\nCombined Distribution Overview',
          fontsize=18, fontweight='bold', pad=20)
plt.ylabel('Performance Score (%)', fontsize=16, fontweight='bold')
plt.xlabel('Performance Metrics', fontsize=16, fontweight='bold')
plt.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)

# Enhanced axis styling
plt.xticks(fontsize=14, fontweight='bold', rotation=15)
plt.yticks(fontsize=12, fontweight='bold')

# Enhanced legend
plt.legend(loc='upper left', fontsize=12, frameon=True, fancybox=True, shadow=True)

# Enhanced statistics table - positioned OUTSIDE the plot area
stats_text = "📊 PERFORMANCE SUMMARY\n" + "="*35 + "\n"
for i, (label, data) in enumerate(zip(combined_labels, combined_data)):
    mean_val = np.mean(data)
    std_val = np.std(data)
    cv = (std_val/mean_val)*100  # Coefficient of variation
    stats_text += f"{label}:\n  Mean: {mean_val:.2f}% (±{std_val:.2f}%)\n  CV: {cv:.1f}%\n\n"

# Position the statistics box outside the plot area (to the right)
plt.text(1.02, 0.98, stats_text, transform=plt.gca().transAxes, fontsize=11, fontweight='bold',
         verticalalignment='top', horizontalalignment='left',
         bbox=dict(boxstyle='round,pad=0.5', facecolor='lightblue', alpha=0.9,
                  edgecolor='darkblue', linewidth=2))

plt.tight_layout()
# Adjust layout to make room for external statistics box
plt.subplots_adjust(right=0.75)
plt.show()
# Out:
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\3907595124.py:13: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot(combined_data, labels=combined_labels, patch_artist=True, widths=0.7,
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\3907595124.py:88: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# f:\Milon\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Separate FPR Box Plot with Statistics Box Outside
plt.figure(figsize=(12, 10))  # Increased width to accommodate external stats

# Create subplot to control layout better
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

# Enhanced styling for FPR box plot
bp = ax.boxplot(fpr_per_fold, patch_artist=True, widths=0.7,
                boxprops=dict(facecolor='#E67E22', alpha=0.7, linewidth=2),
                medianprops=dict(color='darkblue', linewidth=3),
                whiskerprops=dict(linewidth=2),
                capprops=dict(linewidth=2),
                flierprops=dict(marker='o', markerfacecolor='red', markersize=10, alpha=0.7))

# Calculate FPR statistics
fpr_mean = np.mean(fpr_per_fold)
fpr_std = np.std(fpr_per_fold)
fpr_median = np.median(fpr_per_fold)
fpr_cv = (fpr_std/fpr_mean)*100

# Add mean line with enhanced styling
ax.axhline(y=fpr_mean, color='red', linestyle='-', linewidth=3, alpha=0.9,
           label=f'Mean: {fpr_mean:.2f}%')

# Add standard deviation bands
ax.axhline(y=fpr_mean + fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
           label=f'+1 SD: {fpr_mean + fpr_std:.2f}%')
ax.axhline(y=fpr_mean - fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
           label=f'-1 SD: {fpr_mean - fpr_std:.2f}%')
ax.fill_between([0.5, 1.5], fpr_mean - fpr_std, fpr_mean + fpr_std, alpha=0.25, color='orange')

# Enhanced plot styling
ax.set_title('False Positive Rate (FPR) Distribution Analysis\nSchizophrenia Classification Model\n10-Fold Cross-Validation Results',
             fontsize=16, fontweight='bold', pad=20)
ax.set_ylabel('False Positive Rate (%)', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)

# Enhanced legend
ax.legend(loc='upper right', fontsize=12, frameon=True, fancybox=True, shadow=True)

# Enhanced x-axis labeling
ax.set_xticks([1])
ax.set_xticklabels(['False Positive Rate'], fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=12)

# Method 1: Position statistics box to the right of the plot
fpr_stats_text = f'📊 FPR STATISTICS\n{"="*25}\nMean: {fpr_mean:.2f}%\nStd Dev: {fpr_std:.2f}%\nMedian: {fpr_median:.2f}%\nRange: {np.min(fpr_per_fold):.2f}% - {np.max(fpr_per_fold):.2f}%\nCV: {fpr_cv:.1f}%\n\n💡 Lower FPR is Better\n(Fewer False Positives)'

# Position the text box outside the plot area (to the right)
ax.text(1.02, 0.98, fpr_stats_text, transform=ax.transAxes, fontsize=12, fontweight='bold',
        verticalalignment='top', horizontalalignment='left',
        bbox=dict(boxstyle='round,pad=0.5', facecolor='lightyellow', alpha=0.9,
                 edgecolor='orange', linewidth=2))

# Adjust layout to prevent clipping of the external text box
plt.tight_layout()
plt.subplots_adjust(right=0.7)  # Leave space on the right for the statistics box
plt.show()

# Alternative Method 2: Position statistics box below the plot
plt.figure(figsize=(10, 12))  # Increased height to accommodate bottom stats
fig, ax = plt.subplots(1, 1, figsize=(10, 12))

# Same box plot code as above
bp = ax.boxplot(fpr_per_fold, patch_artist=True, widths=0.7,
                boxprops=dict(facecolor='#E67E22', alpha=0.7, linewidth=2),
                medianprops=dict(color='darkblue', linewidth=3),
                whiskerprops=dict(linewidth=2),
                capprops=dict(linewidth=2),
                flierprops=dict(marker='o', markerfacecolor='red', markersize=10, alpha=0.7))

# Add mean line and bands
ax.axhline(y=fpr_mean, color='red', linestyle='-', linewidth=3, alpha=0.9,
           label=f'Mean: {fpr_mean:.2f}%')
ax.axhline(y=fpr_mean + fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
           label=f'+1 SD: {fpr_mean + fpr_std:.2f}%')
ax.axhline(y=fpr_mean - fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
           label=f'-1 SD: {fpr_mean - fpr_std:.2f}%')
ax.fill_between([0.5, 1.5], fpr_mean - fpr_std, fpr_mean + fpr_std, alpha=0.25, color='orange')

# Plot styling
ax.set_title('False Positive Rate (FPR) Distribution Analysis\nSchizophrenia Classification Model\n10-Fold Cross-Validation Results',
             fontsize=16, fontweight='bold', pad=20)
ax.set_ylabel('False Positive Rate (%)', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
ax.legend(loc='upper right', fontsize=12, frameon=True, fancybox=True, shadow=True)
ax.set_xticks([1])
ax.set_xticklabels(['False Positive Rate'], fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=12)

# Position the text box below the plot
ax.text(0.5, -0.15, fpr_stats_text, transform=ax.transAxes, fontsize=12, fontweight='bold',
        verticalalignment='top', horizontalalignment='center',
        bbox=dict(boxstyle='round,pad=0.5', facecolor='lightyellow', alpha=0.9,
                 edgecolor='orange', linewidth=2))

# Adjust layout to prevent clipping of the external text box
plt.tight_layout()
plt.subplots_adjust(bottom=0.25)  # Leave space at the bottom for the statistics box
plt.show()

# Method 3: Create a separate subplot for statistics (most professional)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), gridspec_kw={'width_ratios': [3, 1]})

# Main box plot in the left subplot
bp = ax1.boxplot(fpr_per_fold, patch_artist=True, widths=0.7,
                 boxprops=dict(facecolor='#E67E22', alpha=0.7, linewidth=2),
                 medianprops=dict(color='darkblue', linewidth=3),
                 whiskerprops=dict(linewidth=2),
                 capprops=dict(linewidth=2),
                 flierprops=dict(marker='o', markerfacecolor='red', markersize=10, alpha=0.7))

# Add mean line and bands
ax1.axhline(y=fpr_mean, color='red', linestyle='-', linewidth=3, alpha=0.9,
            label=f'Mean: {fpr_mean:.2f}%')
ax1.axhline(y=fpr_mean + fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
            label=f'+1 SD: {fpr_mean + fpr_std:.2f}%')
ax1.axhline(y=fpr_mean - fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
            label=f'-1 SD: {fpr_mean - fpr_std:.2f}%')
ax1.fill_between([0.5, 1.5], fpr_mean - fpr_std, fpr_mean + fpr_std, alpha=0.25, color='orange')

# Main plot styling
ax1.set_title('False Positive Rate (FPR) Distribution Analysis\nSchizophrenia Classification Model\n10-Fold Cross-Validation Results',
              fontsize=16, fontweight='bold', pad=20)
ax1.set_ylabel('False Positive Rate (%)', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
ax1.legend(loc='upper right', fontsize=12, frameon=True, fancybox=True, shadow=True)
ax1.set_xticks([1])
ax1.set_xticklabels(['False Positive Rate'], fontsize=14, fontweight='bold')
ax1.tick_params(axis='y', labelsize=12)

# Statistics panel in the right subplot
ax2.axis('off')  # Hide axes for the statistics panel
ax2.text(0.1, 0.9, fpr_stats_text, transform=ax2.transAxes, fontsize=14, fontweight='bold',
         verticalalignment='top', horizontalalignment='left',
         bbox=dict(boxstyle='round,pad=0.8', facecolor='lightyellow', alpha=0.9,
                  edgecolor='orange', linewidth=3))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\5396930.py:56: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\5396930.py:56: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# f:\Milon\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\Milon\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\5396930.py:98: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\5396930.py:98: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# f:\Milon\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\Milon\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\5396930.py:139: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\IIT\AppData\Local\Temp\ipykernel_20320\5396930.py:139: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# f:\Milon\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\Milon\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print("Box plot analysis complete!")
print("="*80)

# Combined Confusion Matrix
print('========================================================================')
print('                       COMBINED CONFUSION MATRIX                       ')
print('========================================================================')

# Calculate combined confusion matrix
combined_confusion = confusion_matrix(all_y_true, all_y_pred)
print('Combined Confusion Matrix across all folds:')
print(combined_confusion)

# Calculate overall metrics from combined confusion matrix
tn_total, fp_total, fn_total, tp_total = combined_confusion.ravel()

overall_accuracy = (tp_total + tn_total) / (tp_total + tn_total + fp_total + fn_total) * 100
overall_specificity = tn_total / (tn_total + fp_total) * 100 if (tn_total + fp_total) > 0 else 0
overall_sensitivity = tp_total / (tp_total + fn_total) * 100 if (tp_total + fn_total) > 0 else 0
overall_precision = tp_total / (tp_total + fp_total) * 100 if (tp_total + fp_total) > 0 else 0
overall_f1 = 2 * (overall_precision/100 * overall_sensitivity/100) / (overall_precision/100 + overall_sensitivity/100) * 100 if (overall_precision + overall_sensitivity) > 0 else 0
overall_fpr = fp_total / (fp_total + tn_total) * 100 if (fp_total + tn_total) > 0 else 0

print('\nOverall Performance from Combined Matrix:')
print(f'Overall Accuracy: {overall_accuracy:.2f}%')
print(f'Overall Specificity: {overall_specificity:.2f}%')
print(f'Overall Sensitivity: {overall_sensitivity:.2f}%')
print(f'Overall Precision: {overall_precision:.2f}%')
print(f'Overall F1 Score: {overall_f1:.2f}%')
print(f'Overall FPR: {overall_fpr:.2f}%')

# Enhanced Combined Confusion Matrix Visualization
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# Left plot: Confusion Matrix Heatmap
sns.heatmap(combined_confusion, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=ax1, cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 16, 'weight': 'bold'})

ax1.set_title('Combined Confusion Matrix\nAll Folds (10-Fold Cross-Validation)\nSchizophrenia Classification',
              fontsize=16, fontweight='bold', pad=20)
ax1.set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
ax1.set_ylabel('True Labels', fontsize=14, fontweight='bold')
ax1.tick_params(labelsize=12)

# Add percentage annotations
total_samples = np.sum(combined_confusion)
for i in range(2):
    for j in range(2):
        percentage = (combined_confusion[i, j] / total_samples) * 100
        ax1.text(j + 0.5, i + 0.7, f'({percentage:.1f}%)',
                ha='center', va='center', fontsize=12, fontweight='bold', color='darkred')

# Right plot: Performance Metrics Bar Chart
metrics_names_final = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
overall_values = [overall_accuracy, overall_specificity, overall_sensitivity,
                  overall_precision, overall_f1, overall_fpr]
bar_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6', '#E67E22']

bars = ax2.bar(metrics_names_final, overall_values, color=bar_colors, alpha=0.8,
               edgecolor='black', linewidth=1.5)

# Add value labels on bars
for bar, value in zip(bars, overall_values):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 1,
             f'{value:.2f}%', ha='center', va='bottom',
             fontsize=12, fontweight='bold')

ax2.set_title('Overall Performance Metrics\nCombined Results from All Folds',
              fontsize=16, fontweight='bold', pad=20)
ax2.set_ylabel('Performance Score (%)', fontsize=14, fontweight='bold')
ax2.set_xlabel('Performance Metrics', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.4, axis='y')
ax2.set_ylim(0, max(overall_values) + 10)

# Rotate x-axis labels for better readability
ax2.tick_params(axis='x', labelsize=12, labelrotation=45)
ax2.tick_params(axis='y', labelsize=12)

plt.tight_layout()
plt.show()

# Additional detailed confusion matrix analysis
print('\n' + '='*80)
print('                    DETAILED CONFUSION MATRIX ANALYSIS                 ')
print('='*80)

# Classification metrics breakdown
print(f'\n📊 SAMPLE DISTRIBUTION:')
print(f'Total Samples: {total_samples}')
print(f'Schizophrenia Samples: {combined_confusion[0,0] + combined_confusion[0,1]} ({((combined_confusion[0,0] + combined_confusion[0,1])/total_samples)*100:.1f}%)')
print(f'Healthy Control Samples: {combined_confusion[1,0] + combined_confusion[1,1]} ({((combined_confusion[1,0] + combined_confusion[1,1])/total_samples)*100:.1f}%)')

print(f'\n🎯 PREDICTION RESULTS:')
print(f'True Positives (TP): {tp_total} - Correctly identified Healthy Controls')
print(f'True Negatives (TN): {tn_total} - Correctly identified Schizophrenia cases')
print(f'False Positives (FP): {fp_total} - Schizophrenia cases misclassified as Healthy')
print(f'False Negatives (FN): {fn_total} - Healthy cases misclassified as Schizophrenia')

print(f'\n📈 CLINICAL INTERPRETATION:')
print(f'Sensitivity (Recall): {overall_sensitivity:.2f}% - Ability to correctly identify Healthy Controls')
print(f'Specificity: {overall_specificity:.2f}% - Ability to correctly identify Schizophrenia cases')
print(f'Precision: {overall_precision:.2f}% - Reliability of positive predictions (Healthy)')
print(f'F1 Score: {overall_f1:.2f}% - Harmonic mean of precision and recall')
print(f'False Positive Rate: {overall_fpr:.2f}% - Rate of incorrectly classifying Schizophrenia as Healthy')

print('========================================================================')
print('                           ANALYSIS COMPLETE                           ')
print('========================================================================')
# Out:
# Box plot analysis complete!
# ================================================================================
# ========================================================================
#                        COMBINED CONFUSION MATRIX
# ========================================================================
# Combined Confusion Matrix across all folds:
# [[3930  409]
#  [ 462 4809]]
#
# Overall Performance from Combined Matrix:
# Overall Accuracy: 90.94%
# Overall Specificity: 90.57%
# Overall Sensitivity: 91.24%
# Overall Precision: 92.16%
# Overall F1 Score: 91.70%
# Overall FPR: 9.43%
# ================================================================================
#                     DETAILED CONFUSION MATRIX ANALYSIS
# ================================================================================
#
# 📊 SAMPLE DISTRIBUTION:
# Total Samples: 9610
# Schizophrenia Samples: 4339 (45.2%)
# Healthy Control Samples: 5271 (54.8%)
#
# 🎯 PREDICTION RESULTS:
# True Positives (TP): 4809 - Correctly identified Healthy Controls
# True Negatives (TN): 3930 - Correctly identified Schizophrenia cases
# False Positives (FP): 409 - Schizophrenia cases misclassified as Healthy
# False Negatives (FN): 462 - Healthy cases misclassified as Schizophrenia
#
# 📈 CLINICAL INTERPRETATION:
# Sensitivity (Recall): 91.24% - Ability to correctly identify Healthy Controls
# Specificity: 90.57% - Ability to correctly identify Schizophrenia cases
# Precision: 92.16% - Reliability of positive predictions (Healthy)
# F1 Score: 91.70% - Harmonic mean of precision and recall
# False Positive Rate: 9.43% - Rate of incorrectly classifying Schizophrenia as Healthy
# ========================================================================
#                            ANALYSIS COMPLETE
# ========================================================================

# %%
print("Box plot analysis complete!")
print("="*80)

# Combined Confusion Matrix
print('========================================================================')
print('                       COMBINED CONFUSION MATRIX                       ')
print('========================================================================')

# Calculate combined confusion matrix
combined_confusion = confusion_matrix(all_y_true, all_y_pred)
print('Combined Confusion Matrix across all folds:')
print(combined_confusion)

# Calculate overall metrics from combined confusion matrix
tn_total, fp_total, fn_total, tp_total = combined_confusion.ravel()

overall_accuracy = (tp_total + tn_total) / (tp_total + tn_total + fp_total + fn_total) * 100
overall_specificity = tn_total / (tn_total + fp_total) * 100 if (tn_total + fp_total) > 0 else 0
overall_sensitivity = tp_total / (tp_total + fn_total) * 100 if (tp_total + fn_total) > 0 else 0
overall_precision = tp_total / (tp_total + fp_total) * 100 if (tp_total + fp_total) > 0 else 0
overall_f1 = 2 * (overall_precision/100 * overall_sensitivity/100) / (overall_precision/100 + overall_sensitivity/100) * 100 if (overall_precision + overall_sensitivity) > 0 else 0
overall_fpr = fp_total / (fp_total + tn_total) * 100 if (fp_total + tn_total) > 0 else 0

print('\nOverall Performance from Combined Matrix:')
print(f'Overall Accuracy: {overall_accuracy:.2f}%')
print(f'Overall Specificity: {overall_specificity:.2f}%')
print(f'Overall Sensitivity: {overall_sensitivity:.2f}%')
print(f'Overall Precision: {overall_precision:.2f}%')
print(f'Overall F1 Score: {overall_f1:.2f}%')
print(f'Overall FPR: {overall_fpr:.2f}%')

# Enhanced Combined Confusion Matrix Visualization
fig, axes = plt.subplots(2, 2, figsize=(20, 16))

# Top Left: Confusion Matrix Heatmap with Percentages
sns.heatmap(combined_confusion, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[0,0], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 16, 'weight': 'bold'})

axes[0,0].set_title('Combined Confusion Matrix with Percentages\nAll Folds (10-Fold Cross-Validation)',
                    fontsize=16, fontweight='bold', pad=20)
axes[0,0].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0,0].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0,0].tick_params(labelsize=12)

# Add percentage annotations with better color visibility
total_samples = np.sum(combined_confusion)
for i in range(2):
    for j in range(2):
        percentage = (combined_confusion[i, j] / total_samples) * 100
        # Use white color for the TN cell (top-left, dark blue) and dark color for others
        text_color = 'white' if (i == 0 and j == 0) else 'darkred'
        axes[0,0].text(j + 0.5, i + 0.7, f'({percentage:.1f}%)',
                       ha='center', va='center', fontsize=12, fontweight='bold', color=text_color)

# Top Right: Simple Confusion Matrix without Percentages
sns.heatmap(combined_confusion, annot=True, fmt="d", cmap="Greens",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[0,1], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 18, 'weight': 'bold'})

axes[0,1].set_title('Simple Confusion Matrix\nAll Folds (10-Fold Cross-Validation)',
                    fontsize=16, fontweight='bold', pad=20)
axes[0,1].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0,1].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0,1].tick_params(labelsize=12)

# Bottom Left: Performance Metrics Bar Chart
metrics_names_final = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
overall_values = [overall_accuracy, overall_specificity, overall_sensitivity,
                  overall_precision, overall_f1, overall_fpr]
bar_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6', '#E67E22']

bars = axes[1,0].bar(metrics_names_final, overall_values, color=bar_colors, alpha=0.8,
                     edgecolor='black', linewidth=1.5)

# Add value labels on bars
for bar, value in zip(bars, overall_values):
    height = bar.get_height()
    axes[1,0].text(bar.get_x() + bar.get_width()/2., height + 1,
                   f'{value:.2f}%', ha='center', va='bottom',
                   fontsize=12, fontweight='bold')

axes[1,0].set_title('Overall Performance Metrics\nCombined Results from All Folds',
                    fontsize=16, fontweight='bold', pad=20)
axes[1,0].set_ylabel('Performance Score (%)', fontsize=14, fontweight='bold')
axes[1,0].set_xlabel('Performance Metrics', fontsize=14, fontweight='bold')
axes[1,0].grid(True, alpha=0.4, axis='y')
axes[1,0].set_ylim(0, max(overall_values) + 10)

# Rotate x-axis labels for better readability
axes[1,0].tick_params(axis='x', labelsize=12, labelrotation=45)
axes[1,0].tick_params(axis='y', labelsize=12)

# Bottom Right: Confusion Matrix with Classification Labels
# Create a custom annotation with both counts and labels
confusion_labels = np.array([['TN\n' + str(combined_confusion[0,0]), 'FP\n' + str(combined_confusion[0,1])],
                            ['FN\n' + str(combined_confusion[1,0]), 'TP\n' + str(combined_confusion[1,1])]])

sns.heatmap(combined_confusion, annot=confusion_labels, fmt='', cmap="Oranges",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[1,1], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 14, 'weight': 'bold'})

axes[1,1].set_title('Confusion Matrix with Classification Labels\nTN/FP/FN/TP Breakdown',
                    fontsize=16, fontweight='bold', pad=20)
axes[1,1].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[1,1].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[1,1].tick_params(labelsize=12)

plt.tight_layout()
plt.show()

# Additional detailed confusion matrix analysis
print('\n' + '='*80)
print('                    DETAILED CONFUSION MATRIX ANALYSIS                 ')
print('='*80)

# Classification metrics breakdown
print(f'\n📊 SAMPLE DISTRIBUTION:')
print(f'Total Samples: {total_samples}')
print(f'Schizophrenia Samples: {combined_confusion[0,0] + combined_confusion[0,1]} ({((combined_confusion[0,0] + combined_confusion[0,1])/total_samples)*100:.1f}%)')
print(f'Healthy Control Samples: {combined_confusion[1,0] + combined_confusion[1,1]} ({((combined_confusion[1,0] + combined_confusion[1,1])/total_samples)*100:.1f}%)')

print(f'\n🎯 PREDICTION RESULTS:')
print(f'True Positives (TP): {tp_total} - Correctly identified Healthy Controls')
print(f'True Negatives (TN): {tn_total} - Correctly identified Schizophrenia cases')
print(f'False Positives (FP): {fp_total} - Schizophrenia cases misclassified as Healthy')
print(f'False Negatives (FN): {fn_total} - Healthy cases misclassified as Schizophrenia')

print(f'\n📈 CLINICAL INTERPRETATION:')
print(f'Sensitivity (Recall): {overall_sensitivity:.2f}% - Ability to correctly identify Healthy Controls')
print(f'Specificity: {overall_specificity:.2f}% - Ability to correctly identify Schizophrenia cases')
print(f'Precision: {overall_precision:.2f}% - Reliability of positive predictions (Healthy)')
print(f'F1 Score: {overall_f1:.2f}% - Harmonic mean of precision and recall')
print(f'False Positive Rate: {overall_fpr:.2f}% - Rate of incorrectly classifying Schizophrenia as Healthy')

print('========================================================================')
print('                           ANALYSIS COMPLETE                           ')
print('========================================================================')
# Out:
# Box plot analysis complete!
# ================================================================================
# ========================================================================
#                        COMBINED CONFUSION MATRIX
# ========================================================================
# Combined Confusion Matrix across all folds:
# [[3930  409]
#  [ 462 4809]]
#
# Overall Performance from Combined Matrix:
# Overall Accuracy: 90.94%
# Overall Specificity: 90.57%
# Overall Sensitivity: 91.24%
# Overall Precision: 92.16%
# Overall F1 Score: 91.70%
# Overall FPR: 9.43%
# ================================================================================
#                     DETAILED CONFUSION MATRIX ANALYSIS
# ================================================================================
#
# 📊 SAMPLE DISTRIBUTION:
# Total Samples: 9610
# Schizophrenia Samples: 4339 (45.2%)
# Healthy Control Samples: 5271 (54.8%)
#
# 🎯 PREDICTION RESULTS:
# True Positives (TP): 4809 - Correctly identified Healthy Controls
# True Negatives (TN): 3930 - Correctly identified Schizophrenia cases
# False Positives (FP): 409 - Schizophrenia cases misclassified as Healthy
# False Negatives (FN): 462 - Healthy cases misclassified as Schizophrenia
#
# 📈 CLINICAL INTERPRETATION:
# Sensitivity (Recall): 91.24% - Ability to correctly identify Healthy Controls
# Specificity: 90.57% - Ability to correctly identify Schizophrenia cases
# Precision: 92.16% - Reliability of positive predictions (Healthy)
# F1 Score: 91.70% - Harmonic mean of precision and recall
# False Positive Rate: 9.43% - Rate of incorrectly classifying Schizophrenia as Healthy
# ========================================================================
#                            ANALYSIS COMPLETE
# ========================================================================

# %%
print("Box plot analysis complete!")
print("="*80)

# Combined Confusion Matrix
print('========================================================================')
print('                       COMBINED CONFUSION MATRIX                       ')
print('========================================================================')

# Calculate combined confusion matrix
combined_confusion = confusion_matrix(all_y_true, all_y_pred)
print('Combined Confusion Matrix across all folds:')
print(combined_confusion)

# Calculate overall metrics from combined confusion matrix
tn_total, fp_total, fn_total, tp_total = combined_confusion.ravel()

overall_accuracy = (tp_total + tn_total) / (tp_total + tn_total + fp_total + fn_total) * 100
overall_specificity = tn_total / (tn_total + fp_total) * 100 if (tn_total + fp_total) > 0 else 0
overall_sensitivity = tp_total / (tp_total + fn_total) * 100 if (tp_total + fn_total) > 0 else 0
overall_precision = tp_total / (tp_total + fp_total) * 100 if (tp_total + fp_total) > 0 else 0
overall_f1 = 2 * (overall_precision/100 * overall_sensitivity/100) / (overall_precision/100 + overall_sensitivity/100) * 100 if (overall_precision + overall_sensitivity) > 0 else 0
overall_fpr = fp_total / (fp_total + tn_total) * 100 if (fp_total + tn_total) > 0 else 0

print('\nOverall Performance from Combined Matrix:')
print(f'Overall Accuracy: {overall_accuracy:.2f}%')
print(f'Overall Specificity: {overall_specificity:.2f}%')
print(f'Overall Sensitivity: {overall_sensitivity:.2f}%')
print(f'Overall Precision: {overall_precision:.2f}%')
print(f'Overall F1 Score: {overall_f1:.2f}%')
print(f'Overall FPR: {overall_fpr:.2f}%')

# Enhanced Combined Confusion Matrix Visualization
fig, axes = plt.subplots(2, 2, figsize=(20, 16))

# Top Left: Enhanced Confusion Matrix with Percentages and Labels
sns.heatmap(combined_confusion, annot=True, fmt="d", cmap="Greens",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[0,0], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 16, 'weight': 'bold'})

axes[0,0].set_title('Enhanced Confusion Matrix\nWith Percentages and Labels',
                    fontsize=16, fontweight='bold', pad=20)
axes[0,0].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0,0].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0,0].tick_params(labelsize=12)

# Add both percentages and TN/FP/FN/TP labels
total_samples = np.sum(combined_confusion)
labels_map = [['TN', 'FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        percentage = (combined_confusion[i, j] / total_samples) * 100
        # Add TN/FP/FN/TP label
        axes[0,0].text(j + 0.5, i + 0.3, labels_map[i][j],
                       ha='center', va='center', fontsize=14, fontweight='bold', color='black')
        # Add percentage with better visibility - use white for darker green cells
        percentage_color = 'white' if (i == 1 and j == 1) else 'darkred'
        axes[0,0].text(j + 0.5, i + 0.7, f'({percentage:.1f}%)',
                       ha='center', va='center', fontsize=12, fontweight='bold', color=percentage_color)

# Top Right: Confusion Matrix with Classification Labels
# Create a custom annotation with both counts and labels
confusion_labels = np.array([['TN\n' + str(combined_confusion[0,0]), 'FP\n' + str(combined_confusion[0,1])],
                            ['FN\n' + str(combined_confusion[1,0]), 'TP\n' + str(combined_confusion[1,1])]])

sns.heatmap(combined_confusion, annot=confusion_labels, fmt='', cmap="Oranges",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[0,1], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 14, 'weight': 'bold'})

axes[0,1].set_title('Confusion Matrix with Classification Labels\nTN/FP/FN/TP Breakdown',
                    fontsize=16, fontweight='bold', pad=20)
axes[0,1].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0,1].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0,1].tick_params(labelsize=12)

# Bottom Left: Original Performance Metrics Bar Chart
metrics_names_final = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
overall_values = [overall_accuracy, overall_specificity, overall_sensitivity,
                  overall_precision, overall_f1, overall_fpr]
bar_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6', '#E67E22']

bars = axes[1,0].bar(metrics_names_final, overall_values, color=bar_colors, alpha=0.8,
                     edgecolor='black', linewidth=1.5)

# Add value labels on bars
for bar, value in zip(bars, overall_values):
    height = bar.get_height()
    axes[1,0].text(bar.get_x() + bar.get_width()/2., height + 1,
                   f'{value:.2f}%', ha='center', va='bottom',
                   fontsize=12, fontweight='bold')

axes[1,0].set_title('Performance Metrics (Original)\nCombined Results from All Folds',
                    fontsize=16, fontweight='bold', pad=20)
axes[1,0].set_ylabel('Performance Score (%)', fontsize=14, fontweight='bold')
axes[1,0].set_xlabel('Performance Metrics', fontsize=14, fontweight='bold')
axes[1,0].grid(True, alpha=0.4, axis='y')
axes[1,0].set_ylim(0, max(overall_values) + 10)

# Rotate x-axis labels for better readability
axes[1,0].tick_params(axis='x', labelsize=12, labelrotation=45)
axes[1,0].tick_params(axis='y', labelsize=12)

# Bottom Right: Enhanced Performance Metrics with Better Colors
import matplotlib.colors as mcolors
# Enhanced gradient color palette
enhanced_colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FECA57', '#FF9FF3']

bars2 = axes[1,1].bar(metrics_names_final, overall_values, color=enhanced_colors, alpha=0.9,
                      edgecolor='white', linewidth=2.5)

# Add value labels with contrasting background
for bar, value in zip(bars2, overall_values):
    height = bar.get_height()
    axes[1,1].text(bar.get_x() + bar.get_width()/2., height + 1,
                   f'{value:.2f}%', ha='center', va='bottom',
                   fontsize=12, fontweight='bold', color='black',
                   bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.9, edgecolor='gray'))

axes[1,1].set_title('Performance Metrics (Enhanced)\nWith Improved Color Visualization',
                    fontsize=16, fontweight='bold', pad=20)
axes[1,1].set_ylabel('Performance Score (%)', fontsize=14, fontweight='bold')
axes[1,1].set_xlabel('Performance Metrics', fontsize=14, fontweight='bold')
axes[1,1].grid(True, alpha=0.3, axis='y', linestyle=':', color='gray')
axes[1,1].set_ylim(0, max(overall_values) + 10)
axes[1,1].tick_params(axis='x', labelsize=12, labelrotation=45)
axes[1,1].tick_params(axis='y', labelsize=12)

# Add subtle background gradient
axes[1,1].set_facecolor('#f8f9fa')

plt.tight_layout()
plt.show()

# Additional detailed confusion matrix analysis
print('\n' + '='*80)
print('                    DETAILED CONFUSION MATRIX ANALYSIS                 ')
print('='*80)

# Classification metrics breakdown
print(f'\n📊 SAMPLE DISTRIBUTION:')
print(f'Total Samples: {total_samples}')
print(f'Schizophrenia Samples: {combined_confusion[0,0] + combined_confusion[0,1]} ({((combined_confusion[0,0] + combined_confusion[0,1])/total_samples)*100:.1f}%)')
print(f'Healthy Control Samples: {combined_confusion[1,0] + combined_confusion[1,1]} ({((combined_confusion[1,0] + combined_confusion[1,1])/total_samples)*100:.1f}%)')

print(f'\n🎯 PREDICTION RESULTS:')
print(f'True Positives (TP): {tp_total} - Correctly identified Healthy Controls')
print(f'True Negatives (TN): {tn_total} - Correctly identified Schizophrenia cases')
print(f'False Positives (FP): {fp_total} - Schizophrenia cases misclassified as Healthy')
print(f'False Negatives (FN): {fn_total} - Healthy cases misclassified as Schizophrenia')

print(f'\n📈 CLINICAL INTERPRETATION:')
print(f'Sensitivity (Recall): {overall_sensitivity:.2f}% - Ability to correctly identify Healthy Controls')
print(f'Specificity: {overall_specificity:.2f}% - Ability to correctly identify Schizophrenia cases')
print(f'Precision: {overall_precision:.2f}% - Reliability of positive predictions (Healthy)')
print(f'F1 Score: {overall_f1:.2f}% - Harmonic mean of precision and recall')
print(f'False Positive Rate: {overall_fpr:.2f}% - Rate of incorrectly classifying Schizophrenia as Healthy')

print('========================================================================')
print('                           ANALYSIS COMPLETE                           ')
print('========================================================================')
# Out:
# Box plot analysis complete!
# ================================================================================
# ========================================================================
#                        COMBINED CONFUSION MATRIX
# ========================================================================
# Combined Confusion Matrix across all folds:
# [[3069 1270]
#  [ 719 4552]]
#
# Overall Performance from Combined Matrix:
# Overall Accuracy: 79.30%
# Overall Specificity: 70.73%
# Overall Sensitivity: 86.36%
# Overall Precision: 78.19%
# Overall F1 Score: 82.07%
# Overall FPR: 29.27%
# ================================================================================
#                     DETAILED CONFUSION MATRIX ANALYSIS
# ================================================================================
#
# 📊 SAMPLE DISTRIBUTION:
# Total Samples: 9610
# Schizophrenia Samples: 4339 (45.2%)
# Healthy Control Samples: 5271 (54.8%)
#
# 🎯 PREDICTION RESULTS:
# True Positives (TP): 4552 - Correctly identified Healthy Controls
# True Negatives (TN): 3069 - Correctly identified Schizophrenia cases
# False Positives (FP): 1270 - Schizophrenia cases misclassified as Healthy
# False Negatives (FN): 719 - Healthy cases misclassified as Schizophrenia
#
# 📈 CLINICAL INTERPRETATION:
# Sensitivity (Recall): 86.36% - Ability to correctly identify Healthy Controls
# Specificity: 70.73% - Ability to correctly identify Schizophrenia cases
# Precision: 78.19% - Reliability of positive predictions (Healthy)
# F1 Score: 82.07% - Harmonic mean of precision and recall
# False Positive Rate: 29.27% - Rate of incorrectly classifying Schizophrenia as Healthy
# ========================================================================
#                            ANALYSIS COMPLETE
# ========================================================================
