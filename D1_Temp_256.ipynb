# %%
# %matplotlib inline

import os

#if using Theano with GPU
#os.environ["KERAS_BACKEND"] = "tensorflow"

import random
import numpy as np
import keras

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib.pyplot import imshow
from keras.models import load_model
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.model_selection import KFold
import seaborn as sns

# %%
# Setup data paths and categories
root = 'F:/Milon/D1/D1_256/Temporal'

categories = [x[0] for x in os.walk(root) if x[0]][1:]

print(categories)
# Out:
# ['F:/Milon/D1/D1_256/Temporal\\Healthy_Control', 'F:/Milon/D1/D1_256/Temporal\\Schizophrenia']

# %%
# helper function to load image and return it and input vector
def get_image(path):
    img = image.load_img(path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return img, x

# %%
# Load data
data = []
for c, category in enumerate(categories):
    images = [os.path.join(dp, f) for dp, dn, filenames
              in os.walk(category) for f in filenames
              if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
    for img_path in images:
        img, x = get_image(img_path)
        data.append({'x':np.array(x[0]), 'y':c})

# count the number of classes
num_classes = len(categories)

# %%
# Generate K-fold splits
num_folds = 10
# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=True, random_state = 42)
fold_no = 1
for train, test in kfold.split(data):
  #print("TRAIN:", train, "TEST:", test)
  if os.path.exists(f"F:/Milon/D1/D1_256/Result/temp/train/train{fold_no}.csv") == False:
    np.savetxt(f"F:/Milon/D1/D1_256/Result/temp/train/train{fold_no}.csv", train, delimiter=",", fmt='%s')
    np.savetxt(f"F:/Milon/D1/D1_256/Result/temp/test/test{fold_no}.csv", test, delimiter=",", fmt='%s')
  else:
    print("exists")
  fold_no = fold_no + 1
# Out:
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists

# %%
# Prepare data
X, y = np.array([t["x"] for t in data]), np.array([t["y"] for t in data])

# normalize data
X = X.astype('float32') / 255.

# %%
# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []

# Additional performance metric containers
specificity_per_fold = []
sensitivity_per_fold = []
precision_per_fold = []
f1_per_fold = []
fpr_per_fold = []

# For combined confusion matrix
all_y_true = []
all_y_pred = []

import tensorflow as tf
import pandas as pd
from tensorflow.keras import utils as np_utils

tf.keras.backend.clear_session()

# K-fold Cross Validation model evaluation
fold_no = 1
for fold_no in range(1, 11):

    train=pd.read_csv(f"F:/Milon/D1/D1_256/Result/temp/train/train{fold_no}.csv", sep=',',header=None)
    test=pd.read_csv(f"F:/Milon/D1/D1_256/Result/temp/test/test{fold_no}.csv", sep=',',header=None)

    x_train = X[train[0]]
    y_train = y[train[0]]
    x_test = X[test[0]]
    y_test = y[test[0]]

    # convert labels to one-hot vectors
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)
    print(y_test.shape)

    # summary
    print("finished loading %d images from %d categories"%(len(data), num_classes))
    print("train / test split: %d, %d"%(len(x_train), len(x_test)))
    print("training data shape: ", x_train.shape)
    print("training labels shape: ", y_train.shape)

    # build the network
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=(224, 224, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Dropout(0.25))

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('relu'))

    model.add(Dropout(0.5))

    model.add(Dense(2))
    model.add(Activation('softmax'))


    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    model.summary()
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    filepath=f"F:/Milon/D1/D1_256/Result/temp/a/a{fold_no}.best.keras"

    # define early stopping callback
    earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=150, mode='auto')

    # saves the model weights after each epoch if the validation loss decreased
    checkpointer = ModelCheckpoint(filepath=filepath, verbose=1, save_best_only=True, monitor='val_accuracy')

    callbacks_list = [earlystop, checkpointer]

    history = model.fit(x_train, y_train, epochs = 100, batch_size=32,validation_data= (x_test, y_test), callbacks = callbacks_list)

    #load saved best model
    model = load_model(filepath)

    # Generate generalization metrics
    scores = model.evaluate(x_test, y_test, verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    Y_pred = model.predict(x_test)
    y_pred = np.argmax(Y_pred, axis=1)
    y_text_new = np.argmax(y_test, axis=1)

    # Store predictions for combined confusion matrix
    all_y_true.extend(y_text_new)
    all_y_pred.extend(y_pred)

    from sklearn.metrics import classification_report, confusion_matrix
    #Confution Matrix and Classification Report

    print('Confusion Matrix')
    confusion = confusion_matrix(y_text_new, y_pred)
    print(confusion)
    print('Classification Report')
    target_names = ['ScZ', 'Healthy']
    print(classification_report(y_text_new, y_pred, target_names=target_names))

    # Calculate detailed performance metrics
    tn, fp, fn, tp = confusion.ravel()

    # Calculate metrics
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    f1_score = 2 * (precision * sensitivity) / (precision + sensitivity) if (precision + sensitivity) > 0 else 0
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0

    # Store metrics
    specificity_per_fold.append(specificity * 100)
    sensitivity_per_fold.append(sensitivity * 100)
    precision_per_fold.append(precision * 100)
    f1_per_fold.append(f1_score * 100)
    fpr_per_fold.append(fpr * 100)

    print(f'Fold {fold_no} Detailed Metrics:')
    print(f'Specificity: {specificity:.4f} ({specificity*100:.2f}%)')
    print(f'Sensitivity (Recall): {sensitivity:.4f} ({sensitivity*100:.2f}%)')
    print(f'Precision: {precision:.4f} ({precision*100:.2f}%)')
    print(f'F1 Score: {f1_score:.4f} ({f1_score*100:.2f}%)')
    print(f'FPR: {fpr:.4f} ({fpr*100:.2f}%)')
    print('------------------------------------------------------------------------')

    fig = plt.figure(figsize=(16,4))
    ax = fig.add_subplot(121)
    ax.plot(history.history["val_loss"])
    ax.set_title("validation loss")
    ax.set_xlabel("epochs")

    ax2 = fig.add_subplot(122)
    ax2.plot(history.history["val_accuracy"])
    ax2.set_title("validation accuracy")
    ax2.set_xlabel("epochs")
    ax2.set_ylim(0, 1)

    plt.show()

    ax= plt.subplot()
    sns.heatmap(confusion, annot=True, fmt="d", ax = ax); #annot=True to annotate cells

    # labels, title and ticks
    ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
    ax.set_title('Confusion Matrix');
    ax.xaxis.set_ticklabels(['ScZ', 'Normal']); ax.yaxis.set_ticklabels(['ScZ', 'Normal']);
    plt.show()
# Out:
# WARNING:tensorflow:From f:\code\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# (961, 2)
# finished loading 9610 images from 2 categories
# train / test split: 8649, 961
# training data shape:  (8649, 224, 224, 3)
# training labels shape:  (8649, 2)
# f:\code\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 222, 222, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 109, 109, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 52, 52, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           514 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 2)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,209,058 (4.61 MB)
#  Trainable params: 1,209,058 (4.61 MB)
#  Non-trainable params: 0 (0.00 B)
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.6724 - loss: 0.5793
# Epoch 1: val_accuracy improved from None to 0.83975, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 114s 287ms/step - accuracy: 0.7381 - loss: 0.5108 - val_accuracy: 0.8398 - val_loss: 0.3699
# Epoch 2/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.8257 - loss: 0.3952
# Epoch 2: val_accuracy improved from 0.83975 to 0.87929, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 75s 276ms/step - accuracy: 0.8361 - loss: 0.3726 - val_accuracy: 0.8793 - val_loss: 0.2769
# Epoch 3/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8658 - loss: 0.3064
# Epoch 3: val_accuracy improved from 0.87929 to 0.92196, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.8746 - loss: 0.2924 - val_accuracy: 0.9220 - val_loss: 0.2334
# Epoch 4/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9048 - loss: 0.2336
# Epoch 4: val_accuracy improved from 0.92196 to 0.92924, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9044 - loss: 0.2347 - val_accuracy: 0.9292 - val_loss: 0.1858
# Epoch 5/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9098 - loss: 0.2129
# Epoch 5: val_accuracy improved from 0.92924 to 0.93652, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9110 - loss: 0.2105 - val_accuracy: 0.9365 - val_loss: 0.1821
# Epoch 6/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9260 - loss: 0.1835
# Epoch 6: val_accuracy improved from 0.93652 to 0.94173, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9239 - loss: 0.1904 - val_accuracy: 0.9417 - val_loss: 0.1677
# Epoch 7/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9353 - loss: 0.1611
# Epoch 7: val_accuracy improved from 0.94173 to 0.95213, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 258ms/step - accuracy: 0.9334 - loss: 0.1680 - val_accuracy: 0.9521 - val_loss: 0.1460
# Epoch 8/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9381 - loss: 0.1545
# Epoch 8: val_accuracy did not improve from 0.95213
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9392 - loss: 0.1491 - val_accuracy: 0.9292 - val_loss: 0.1813
# Epoch 9/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9464 - loss: 0.1423
# Epoch 9: val_accuracy did not improve from 0.95213
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9481 - loss: 0.1357 - val_accuracy: 0.9438 - val_loss: 0.1538
# Epoch 10/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9437 - loss: 0.1410
# Epoch 10: val_accuracy did not improve from 0.95213
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9467 - loss: 0.1354 - val_accuracy: 0.9438 - val_loss: 0.1645
# Epoch 11/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9569 - loss: 0.1134
# Epoch 11: val_accuracy did not improve from 0.95213
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9561 - loss: 0.1124 - val_accuracy: 0.9480 - val_loss: 0.1511
# Epoch 12/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9554 - loss: 0.1160
# Epoch 12: val_accuracy did not improve from 0.95213
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9565 - loss: 0.1140 - val_accuracy: 0.9407 - val_loss: 0.1556
# Epoch 13/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9585 - loss: 0.1036
# Epoch 13: val_accuracy did not improve from 0.95213
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9613 - loss: 0.1006 - val_accuracy: 0.9417 - val_loss: 0.1708
# Epoch 14/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9663 - loss: 0.0944
# Epoch 14: val_accuracy improved from 0.95213 to 0.95525, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9632 - loss: 0.1035 - val_accuracy: 0.9553 - val_loss: 0.1461
# Epoch 15/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9671 - loss: 0.0875
# Epoch 15: val_accuracy did not improve from 0.95525
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9666 - loss: 0.0898 - val_accuracy: 0.9376 - val_loss: 0.1809
# Epoch 16/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9650 - loss: 0.0903
# Epoch 16: val_accuracy did not improve from 0.95525
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9658 - loss: 0.0933 - val_accuracy: 0.9511 - val_loss: 0.1380
# Epoch 17/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9710 - loss: 0.0785
# Epoch 17: val_accuracy did not improve from 0.95525
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9692 - loss: 0.0817 - val_accuracy: 0.9459 - val_loss: 0.1678
# Epoch 18/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9740 - loss: 0.0726
# Epoch 18: val_accuracy did not improve from 0.95525
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9705 - loss: 0.0796 - val_accuracy: 0.9490 - val_loss: 0.1546
# Epoch 19/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9692 - loss: 0.0795
# Epoch 19: val_accuracy did not improve from 0.95525
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 249ms/step - accuracy: 0.9702 - loss: 0.0767 - val_accuracy: 0.9459 - val_loss: 0.1515
# Epoch 20/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9731 - loss: 0.0705
# Epoch 20: val_accuracy did not improve from 0.95525
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9735 - loss: 0.0677 - val_accuracy: 0.9501 - val_loss: 0.1515
# Epoch 21/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9679 - loss: 0.0833
# Epoch 21: val_accuracy did not improve from 0.95525
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9731 - loss: 0.0711 - val_accuracy: 0.9532 - val_loss: 0.1460
# Epoch 22/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9765 - loss: 0.0605
# Epoch 22: val_accuracy improved from 0.95525 to 0.96358, saving model to F:/Milon/D1/D1_256/Result/temp/a/a1.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9757 - loss: 0.0647 - val_accuracy: 0.9636 - val_loss: 0.1272
# Epoch 23/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9760 - loss: 0.0676
# Epoch 23: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9753 - loss: 0.0687 - val_accuracy: 0.9553 - val_loss: 0.1453
# Epoch 24/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9798 - loss: 0.0585
# Epoch 24: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9790 - loss: 0.0606 - val_accuracy: 0.9584 - val_loss: 0.1396
# Epoch 25/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9796 - loss: 0.0507
# Epoch 25: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9806 - loss: 0.0506 - val_accuracy: 0.9480 - val_loss: 0.1742
# Epoch 26/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9806 - loss: 0.0527
# Epoch 26: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9806 - loss: 0.0541 - val_accuracy: 0.9521 - val_loss: 0.1453
# Epoch 27/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9818 - loss: 0.0489
# Epoch 27: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9808 - loss: 0.0489 - val_accuracy: 0.9480 - val_loss: 0.2136
# Epoch 28/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9813 - loss: 0.0505
# Epoch 28: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9809 - loss: 0.0521 - val_accuracy: 0.9542 - val_loss: 0.1812
# Epoch 29/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9843 - loss: 0.0453
# Epoch 29: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9808 - loss: 0.0531 - val_accuracy: 0.9501 - val_loss: 0.1449
# Epoch 30/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9824 - loss: 0.0537
# Epoch 30: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9822 - loss: 0.0524 - val_accuracy: 0.9511 - val_loss: 0.1713
# Epoch 31/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9824 - loss: 0.0481
# Epoch 31: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9829 - loss: 0.0474 - val_accuracy: 0.9553 - val_loss: 0.1330
# Epoch 32/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9809 - loss: 0.0511
# Epoch 32: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 260ms/step - accuracy: 0.9813 - loss: 0.0518 - val_accuracy: 0.9605 - val_loss: 0.1609
# Epoch 33/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9844 - loss: 0.0450
# Epoch 33: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 260ms/step - accuracy: 0.9843 - loss: 0.0445 - val_accuracy: 0.9573 - val_loss: 0.1706
# Epoch 34/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9768 - loss: 0.0601
# Epoch 34: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 264ms/step - accuracy: 0.9808 - loss: 0.0524 - val_accuracy: 0.9501 - val_loss: 0.2007
# Epoch 35/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9798 - loss: 0.0547
# Epoch 35: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 265ms/step - accuracy: 0.9791 - loss: 0.0565 - val_accuracy: 0.9594 - val_loss: 0.1348
# Epoch 36/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9886 - loss: 0.0391
# Epoch 36: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 260ms/step - accuracy: 0.9868 - loss: 0.0429 - val_accuracy: 0.9573 - val_loss: 0.1713
# Epoch 37/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9868 - loss: 0.0362
# Epoch 37: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9846 - loss: 0.0409 - val_accuracy: 0.9480 - val_loss: 0.1976
# Epoch 38/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9821 - loss: 0.0556
# Epoch 38: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9846 - loss: 0.0445 - val_accuracy: 0.9563 - val_loss: 0.1635
# Epoch 39/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9869 - loss: 0.0387
# Epoch 39: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9852 - loss: 0.0409 - val_accuracy: 0.9511 - val_loss: 0.1581
# Epoch 40/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9810 - loss: 0.0487
# Epoch 40: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9839 - loss: 0.0435 - val_accuracy: 0.9594 - val_loss: 0.1818
# Epoch 41/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9879 - loss: 0.0381
# Epoch 41: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9871 - loss: 0.0383 - val_accuracy: 0.9542 - val_loss: 0.1759
# Epoch 42/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9893 - loss: 0.0337
# Epoch 42: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9874 - loss: 0.0376 - val_accuracy: 0.9584 - val_loss: 0.1622
# Epoch 43/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9853 - loss: 0.0407
# Epoch 43: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9865 - loss: 0.0407 - val_accuracy: 0.9615 - val_loss: 0.1423
# Epoch 44/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9899 - loss: 0.0311
# Epoch 44: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 249ms/step - accuracy: 0.9881 - loss: 0.0340 - val_accuracy: 0.9605 - val_loss: 0.1686
# Epoch 45/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9881 - loss: 0.0393
# Epoch 45: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9869 - loss: 0.0386 - val_accuracy: 0.9573 - val_loss: 0.1527
# Epoch 46/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9879 - loss: 0.0343
# Epoch 46: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9862 - loss: 0.0422 - val_accuracy: 0.9605 - val_loss: 0.1238
# Epoch 47/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9840 - loss: 0.0467
# Epoch 47: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9859 - loss: 0.0426 - val_accuracy: 0.9563 - val_loss: 0.1947
# Epoch 48/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9876 - loss: 0.0392
# Epoch 48: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9887 - loss: 0.0339 - val_accuracy: 0.9521 - val_loss: 0.1758
# Epoch 49/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9877 - loss: 0.0389
# Epoch 49: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9881 - loss: 0.0337 - val_accuracy: 0.9584 - val_loss: 0.1478
# Epoch 50/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9903 - loss: 0.0293
# Epoch 50: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9890 - loss: 0.0323 - val_accuracy: 0.9615 - val_loss: 0.1486
# Epoch 51/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9825 - loss: 0.0471
# Epoch 51: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9821 - loss: 0.0467 - val_accuracy: 0.9480 - val_loss: 0.1702
# Epoch 52/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9873 - loss: 0.0397
# Epoch 52: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9869 - loss: 0.0374 - val_accuracy: 0.9584 - val_loss: 0.1358
# Epoch 53/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9895 - loss: 0.0281
# Epoch 53: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9876 - loss: 0.0341 - val_accuracy: 0.9563 - val_loss: 0.1468
# Epoch 54/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9876 - loss: 0.0419
# Epoch 54: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9894 - loss: 0.0346 - val_accuracy: 0.9573 - val_loss: 0.1514
# Epoch 55/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9906 - loss: 0.0265
# Epoch 55: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9897 - loss: 0.0290 - val_accuracy: 0.9563 - val_loss: 0.1700
# Epoch 56/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9907 - loss: 0.0280
# Epoch 56: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9883 - loss: 0.0362 - val_accuracy: 0.9553 - val_loss: 0.1511
# Epoch 57/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9886 - loss: 0.0339
# Epoch 57: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9876 - loss: 0.0351 - val_accuracy: 0.9542 - val_loss: 0.1669
# Epoch 58/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9921 - loss: 0.0223
# Epoch 58: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9904 - loss: 0.0252 - val_accuracy: 0.9511 - val_loss: 0.1948
# Epoch 59/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9849 - loss: 0.0467
# Epoch 59: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9857 - loss: 0.0436 - val_accuracy: 0.9563 - val_loss: 0.1610
# Epoch 60/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9892 - loss: 0.0346
# Epoch 60: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9895 - loss: 0.0315 - val_accuracy: 0.9521 - val_loss: 0.1860
# Epoch 61/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9898 - loss: 0.0288
# Epoch 61: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9890 - loss: 0.0308 - val_accuracy: 0.9594 - val_loss: 0.1808
# Epoch 62/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9913 - loss: 0.0243
# Epoch 62: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9903 - loss: 0.0259 - val_accuracy: 0.9521 - val_loss: 0.1871
# Epoch 63/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9897 - loss: 0.0293
# Epoch 63: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9891 - loss: 0.0310 - val_accuracy: 0.9542 - val_loss: 0.1871
# Epoch 64/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9888 - loss: 0.0348
# Epoch 64: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9886 - loss: 0.0334 - val_accuracy: 0.9553 - val_loss: 0.1356
# Epoch 65/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9904 - loss: 0.0274
# Epoch 65: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9904 - loss: 0.0272 - val_accuracy: 0.9542 - val_loss: 0.1877
# Epoch 66/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9903 - loss: 0.0288
# Epoch 66: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9901 - loss: 0.0276 - val_accuracy: 0.9521 - val_loss: 0.2243
# Epoch 67/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9906 - loss: 0.0257
# Epoch 67: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9890 - loss: 0.0318 - val_accuracy: 0.9480 - val_loss: 0.1865
# Epoch 68/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9903 - loss: 0.0313
# Epoch 68: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9906 - loss: 0.0296 - val_accuracy: 0.9594 - val_loss: 0.1568
# Epoch 69/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9937 - loss: 0.0225
# Epoch 69: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9912 - loss: 0.0261 - val_accuracy: 0.9563 - val_loss: 0.1442
# Epoch 70/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9922 - loss: 0.0243
# Epoch 70: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9892 - loss: 0.0327 - val_accuracy: 0.9501 - val_loss: 0.1604
# Epoch 71/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9899 - loss: 0.0294
# Epoch 71: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9901 - loss: 0.0320 - val_accuracy: 0.9542 - val_loss: 0.1478
# Epoch 72/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9896 - loss: 0.0317
# Epoch 72: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9910 - loss: 0.0279 - val_accuracy: 0.9563 - val_loss: 0.1669
# Epoch 73/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9914 - loss: 0.0250
# Epoch 73: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9913 - loss: 0.0259 - val_accuracy: 0.9532 - val_loss: 0.2058
# Epoch 74/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9891 - loss: 0.0302
# Epoch 74: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9905 - loss: 0.0268 - val_accuracy: 0.9511 - val_loss: 0.1694
# Epoch 75/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9907 - loss: 0.0224
# Epoch 75: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9901 - loss: 0.0241 - val_accuracy: 0.9542 - val_loss: 0.2267
# Epoch 76/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9905 - loss: 0.0245
# Epoch 76: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9901 - loss: 0.0274 - val_accuracy: 0.9605 - val_loss: 0.1537
# Epoch 77/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9930 - loss: 0.0203
# Epoch 77: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9919 - loss: 0.0249 - val_accuracy: 0.9448 - val_loss: 0.1948
# Epoch 78/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9912 - loss: 0.0272
# Epoch 78: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9897 - loss: 0.0312 - val_accuracy: 0.9480 - val_loss: 0.2024
# Epoch 79/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9942 - loss: 0.0212
# Epoch 79: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9926 - loss: 0.0235 - val_accuracy: 0.9594 - val_loss: 0.1860
# Epoch 80/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9897 - loss: 0.0311
# Epoch 80: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9905 - loss: 0.0298 - val_accuracy: 0.9573 - val_loss: 0.1939
# Epoch 81/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9939 - loss: 0.0202
# Epoch 81: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9910 - loss: 0.0258 - val_accuracy: 0.9480 - val_loss: 0.2592
# Epoch 82/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9861 - loss: 0.0329
# Epoch 82: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9875 - loss: 0.0317 - val_accuracy: 0.9563 - val_loss: 0.2129
# Epoch 83/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9894 - loss: 0.0299
# Epoch 83: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9887 - loss: 0.0324 - val_accuracy: 0.9584 - val_loss: 0.1447
# Epoch 84/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9914 - loss: 0.0236
# Epoch 84: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9920 - loss: 0.0210 - val_accuracy: 0.9584 - val_loss: 0.1850
# Epoch 85/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9906 - loss: 0.0350
# Epoch 85: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9914 - loss: 0.0271 - val_accuracy: 0.9615 - val_loss: 0.1735
# Epoch 86/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9936 - loss: 0.0176
# Epoch 86: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9927 - loss: 0.0216 - val_accuracy: 0.9469 - val_loss: 0.2455
# Epoch 87/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9925 - loss: 0.0200
# Epoch 87: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9928 - loss: 0.0220 - val_accuracy: 0.9584 - val_loss: 0.1788
# Epoch 88/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9951 - loss: 0.0195
# Epoch 88: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9934 - loss: 0.0230 - val_accuracy: 0.9501 - val_loss: 0.1769
# Epoch 89/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9911 - loss: 0.0269
# Epoch 89: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9910 - loss: 0.0263 - val_accuracy: 0.9532 - val_loss: 0.1796
# Epoch 90/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9915 - loss: 0.0265
# Epoch 90: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9916 - loss: 0.0277 - val_accuracy: 0.9563 - val_loss: 0.1934
# Epoch 91/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9900 - loss: 0.0255
# Epoch 91: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9908 - loss: 0.0258 - val_accuracy: 0.9553 - val_loss: 0.2019
# Epoch 92/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9907 - loss: 0.0269
# Epoch 92: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9911 - loss: 0.0244 - val_accuracy: 0.9501 - val_loss: 0.2036
# Epoch 93/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9879 - loss: 0.0307
# Epoch 93: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9886 - loss: 0.0296 - val_accuracy: 0.9563 - val_loss: 0.1822
# Epoch 94/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9937 - loss: 0.0184
# Epoch 94: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9926 - loss: 0.0228 - val_accuracy: 0.9490 - val_loss: 0.1911
# Epoch 95/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9930 - loss: 0.0196
# Epoch 95: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9918 - loss: 0.0230 - val_accuracy: 0.9563 - val_loss: 0.1653
# Epoch 96/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9927 - loss: 0.0213
# Epoch 96: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9921 - loss: 0.0221 - val_accuracy: 0.9521 - val_loss: 0.1947
# Epoch 97/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9922 - loss: 0.0177
# Epoch 97: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9918 - loss: 0.0207 - val_accuracy: 0.9615 - val_loss: 0.1934
# Epoch 98/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9922 - loss: 0.0238
# Epoch 98: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9921 - loss: 0.0239 - val_accuracy: 0.9573 - val_loss: 0.1575
# Epoch 99/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9925 - loss: 0.0239
# Epoch 99: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9919 - loss: 0.0251 - val_accuracy: 0.9542 - val_loss: 0.2020
# Epoch 100/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9943 - loss: 0.0173
# Epoch 100: val_accuracy did not improve from 0.96358
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9931 - loss: 0.0209 - val_accuracy: 0.9542 - val_loss: 0.2507
# Score for fold 1: loss of 0.12720660865306854; compile_metrics of 96.35795950889587%
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# Confusion Matrix
# [[410  21]
#  [ 14 516]]
# Classification Report
#               precision    recall  f1-score   support
#
#          ScZ       0.97      0.95      0.96       431
#      Healthy       0.96      0.97      0.97       530
#
#     accuracy                           0.96       961
#    macro avg       0.96      0.96      0.96       961
# weighted avg       0.96      0.96      0.96       961
#
# Fold 1 Detailed Metrics:
# Specificity: 0.9513 (95.13%)
# Sensitivity (Recall): 0.9736 (97.36%)
# Precision: 0.9609 (96.09%)
# F1 Score: 0.9672 (96.72%)
# FPR: 0.0487 (4.87%)
# ------------------------------------------------------------------------
# (961, 2)
# finished loading 9610 images from 2 categories
# train / test split: 8649, 961
# training data shape:  (8649, 224, 224, 3)
# training labels shape:  (8649, 2)
# f:\code\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 222, 222, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 109, 109, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 109, 109, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 52, 52, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 52, 52, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 26, 26, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 24, 24, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           514 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 2)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,209,058 (4.61 MB)
#  Trainable params: 1,209,058 (4.61 MB)
#  Non-trainable params: 0 (0.00 B)
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.6686 - loss: 0.5959
# Epoch 1: val_accuracy improved from None to 0.82726, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 87s 272ms/step - accuracy: 0.7271 - loss: 0.5303 - val_accuracy: 0.8273 - val_loss: 0.4247
# Epoch 2/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8161 - loss: 0.3997
# Epoch 2: val_accuracy improved from 0.82726 to 0.85432, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.8290 - loss: 0.3795 - val_accuracy: 0.8543 - val_loss: 0.3388
# Epoch 3/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.8708 - loss: 0.3086
# Epoch 3: val_accuracy improved from 0.85432 to 0.88970, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.8730 - loss: 0.3044 - val_accuracy: 0.8897 - val_loss: 0.2715
# Epoch 4/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8869 - loss: 0.2607
# Epoch 4: val_accuracy did not improve from 0.88970
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 249ms/step - accuracy: 0.8890 - loss: 0.2598 - val_accuracy: 0.8803 - val_loss: 0.2792
# Epoch 5/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9069 - loss: 0.2259
# Epoch 5: val_accuracy improved from 0.88970 to 0.91675, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9117 - loss: 0.2186 - val_accuracy: 0.9168 - val_loss: 0.2144
# Epoch 6/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9320 - loss: 0.1726
# Epoch 6: val_accuracy improved from 0.91675 to 0.92196, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 73s 271ms/step - accuracy: 0.9258 - loss: 0.1867 - val_accuracy: 0.9220 - val_loss: 0.2109
# Epoch 7/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9292 - loss: 0.1642
# Epoch 7: val_accuracy did not improve from 0.92196
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 261ms/step - accuracy: 0.9332 - loss: 0.1624 - val_accuracy: 0.9105 - val_loss: 0.2153
# Epoch 8/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9382 - loss: 0.1520
# Epoch 8: val_accuracy improved from 0.92196 to 0.93028, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9402 - loss: 0.1490 - val_accuracy: 0.9303 - val_loss: 0.1874
# Epoch 9/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9504 - loss: 0.1303
# Epoch 9: val_accuracy did not improve from 0.93028
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 249ms/step - accuracy: 0.9477 - loss: 0.1300 - val_accuracy: 0.9220 - val_loss: 0.2256
# Epoch 10/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9482 - loss: 0.1317
# Epoch 10: val_accuracy did not improve from 0.93028
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 263ms/step - accuracy: 0.9507 - loss: 0.1260 - val_accuracy: 0.9292 - val_loss: 0.1833
# Epoch 11/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9590 - loss: 0.1146
# Epoch 11: val_accuracy did not improve from 0.93028
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 265ms/step - accuracy: 0.9569 - loss: 0.1122 - val_accuracy: 0.9199 - val_loss: 0.2218
# Epoch 12/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9636 - loss: 0.1024
# Epoch 12: val_accuracy did not improve from 0.93028
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 261ms/step - accuracy: 0.9622 - loss: 0.1040 - val_accuracy: 0.9157 - val_loss: 0.2157
# Epoch 13/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9646 - loss: 0.1048
# Epoch 13: val_accuracy did not improve from 0.93028
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 266ms/step - accuracy: 0.9697 - loss: 0.0906 - val_accuracy: 0.9282 - val_loss: 0.2154
# Epoch 14/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9648 - loss: 0.0909
# Epoch 14: val_accuracy did not improve from 0.93028
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 263ms/step - accuracy: 0.9630 - loss: 0.0962 - val_accuracy: 0.9292 - val_loss: 0.2085
# Epoch 15/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9664 - loss: 0.0833
# Epoch 15: val_accuracy did not improve from 0.93028
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 76s 281ms/step - accuracy: 0.9688 - loss: 0.0806 - val_accuracy: 0.9303 - val_loss: 0.2152
# Epoch 16/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9701 - loss: 0.0845
# Epoch 16: val_accuracy improved from 0.93028 to 0.93548, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 71s 260ms/step - accuracy: 0.9686 - loss: 0.0876 - val_accuracy: 0.9355 - val_loss: 0.1904
# Epoch 17/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9719 - loss: 0.0775
# Epoch 17: val_accuracy did not improve from 0.93548
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 72s 264ms/step - accuracy: 0.9741 - loss: 0.0735 - val_accuracy: 0.9344 - val_loss: 0.2176
# Epoch 18/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9744 - loss: 0.0758
# Epoch 18: val_accuracy improved from 0.93548 to 0.93861, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9738 - loss: 0.0764 - val_accuracy: 0.9386 - val_loss: 0.1787
# Epoch 19/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9773 - loss: 0.0614
# Epoch 19: val_accuracy improved from 0.93861 to 0.94173, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9768 - loss: 0.0640 - val_accuracy: 0.9417 - val_loss: 0.1954
# Epoch 20/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9761 - loss: 0.0761
# Epoch 20: val_accuracy did not improve from 0.94173
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9750 - loss: 0.0695 - val_accuracy: 0.9303 - val_loss: 0.2170
# Epoch 21/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9745 - loss: 0.0650
# Epoch 21: val_accuracy did not improve from 0.94173
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9762 - loss: 0.0657 - val_accuracy: 0.9396 - val_loss: 0.1765
# Epoch 22/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9775 - loss: 0.0645
# Epoch 22: val_accuracy did not improve from 0.94173
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9777 - loss: 0.0622 - val_accuracy: 0.9376 - val_loss: 0.2004
# Epoch 23/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9812 - loss: 0.0539
# Epoch 23: val_accuracy did not improve from 0.94173
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9793 - loss: 0.0572 - val_accuracy: 0.9282 - val_loss: 0.2217
# Epoch 24/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9797 - loss: 0.0543
# Epoch 24: val_accuracy improved from 0.94173 to 0.94381, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9800 - loss: 0.0559 - val_accuracy: 0.9438 - val_loss: 0.1936
# Epoch 25/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9822 - loss: 0.0499
# Epoch 25: val_accuracy did not improve from 0.94381
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9814 - loss: 0.0525 - val_accuracy: 0.9272 - val_loss: 0.2198
# Epoch 26/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9808 - loss: 0.0529
# Epoch 26: val_accuracy did not improve from 0.94381
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9816 - loss: 0.0514 - val_accuracy: 0.9344 - val_loss: 0.2430
# Epoch 27/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9808 - loss: 0.0555
# Epoch 27: val_accuracy improved from 0.94381 to 0.94589, saving model to F:/Milon/D1/D1_256/Result/temp/a/a2.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9817 - loss: 0.0536 - val_accuracy: 0.9459 - val_loss: 0.2067
# Epoch 28/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9844 - loss: 0.0527
# Epoch 28: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9830 - loss: 0.0522 - val_accuracy: 0.9417 - val_loss: 0.1979
# Epoch 29/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9845 - loss: 0.0458
# Epoch 29: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9832 - loss: 0.0484 - val_accuracy: 0.9428 - val_loss: 0.2021
# Epoch 30/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9829 - loss: 0.0437
# Epoch 30: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9827 - loss: 0.0454 - val_accuracy: 0.9407 - val_loss: 0.2098
# Epoch 31/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9824 - loss: 0.0532
# Epoch 31: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9844 - loss: 0.0475 - val_accuracy: 0.9365 - val_loss: 0.2268
# Epoch 32/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9883 - loss: 0.0429
# Epoch 32: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9866 - loss: 0.0425 - val_accuracy: 0.9407 - val_loss: 0.2289
# Epoch 33/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9836 - loss: 0.0425
# Epoch 33: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9825 - loss: 0.0462 - val_accuracy: 0.9344 - val_loss: 0.2074
# Epoch 34/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9876 - loss: 0.0364
# Epoch 34: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 249ms/step - accuracy: 0.9875 - loss: 0.0379 - val_accuracy: 0.9313 - val_loss: 0.2714
# Epoch 35/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9858 - loss: 0.0461
# Epoch 35: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9868 - loss: 0.0422 - val_accuracy: 0.9396 - val_loss: 0.2188
# Epoch 36/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9859 - loss: 0.0418
# Epoch 36: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9862 - loss: 0.0392 - val_accuracy: 0.9386 - val_loss: 0.2731
# Epoch 37/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9850 - loss: 0.0460
# Epoch 37: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 260ms/step - accuracy: 0.9842 - loss: 0.0457 - val_accuracy: 0.9365 - val_loss: 0.2610
# Epoch 38/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9826 - loss: 0.0415
# Epoch 38: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9829 - loss: 0.0459 - val_accuracy: 0.9386 - val_loss: 0.1760
# Epoch 39/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9890 - loss: 0.0356
# Epoch 39: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9881 - loss: 0.0361 - val_accuracy: 0.9344 - val_loss: 0.2321
# Epoch 40/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9864 - loss: 0.0353
# Epoch 40: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 250ms/step - accuracy: 0.9881 - loss: 0.0331 - val_accuracy: 0.9459 - val_loss: 0.2094
# Epoch 41/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9871 - loss: 0.0379
# Epoch 41: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9874 - loss: 0.0374 - val_accuracy: 0.9178 - val_loss: 0.2999
# Epoch 42/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9848 - loss: 0.0393
# Epoch 42: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9862 - loss: 0.0375 - val_accuracy: 0.9448 - val_loss: 0.2074
# Epoch 43/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9896 - loss: 0.0344
# Epoch 43: val_accuracy did not improve from 0.94589
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9899 - loss: 0.0326 - val_accuracy: 0.9407 - val_loss: 0.2143
# Epoch 44/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9909 - loss: 0.0286
# Epoch 44: val_accuracy did not improve from 0.94589
# ...
# Epoch 43: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 258ms/step - accuracy: 0.9861 - loss: 0.0399 - val_accuracy: 0.9542 - val_loss: 0.1651
# Epoch 44/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9853 - loss: 0.0395
# Epoch 44: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9851 - loss: 0.0428 - val_accuracy: 0.9563 - val_loss: 0.1955
# Epoch 45/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9905 - loss: 0.0306
# Epoch 45: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9888 - loss: 0.0352 - val_accuracy: 0.9428 - val_loss: 0.2894
# Epoch 46/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9861 - loss: 0.0383
# Epoch 46: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9874 - loss: 0.0369 - val_accuracy: 0.9480 - val_loss: 0.2076
# Epoch 47/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9867 - loss: 0.0367
# Epoch 47: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 253ms/step - accuracy: 0.9861 - loss: 0.0370 - val_accuracy: 0.9438 - val_loss: 0.2440
# Epoch 48/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9869 - loss: 0.0375
# Epoch 48: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 70s 259ms/step - accuracy: 0.9880 - loss: 0.0333 - val_accuracy: 0.9407 - val_loss: 0.2880
# Epoch 49/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9898 - loss: 0.0295
# Epoch 49: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9886 - loss: 0.0337 - val_accuracy: 0.9428 - val_loss: 0.2315
# Epoch 50/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9893 - loss: 0.0324
# Epoch 50: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9891 - loss: 0.0328 - val_accuracy: 0.9459 - val_loss: 0.2139
# Epoch 51/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9852 - loss: 0.0395
# Epoch 51: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 253ms/step - accuracy: 0.9890 - loss: 0.0317 - val_accuracy: 0.9501 - val_loss: 0.2087
# Epoch 52/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9874 - loss: 0.0401
# Epoch 52: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9864 - loss: 0.0430 - val_accuracy: 0.9469 - val_loss: 0.2340
# Epoch 53/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9879 - loss: 0.0323
# Epoch 53: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 253ms/step - accuracy: 0.9875 - loss: 0.0361 - val_accuracy: 0.9459 - val_loss: 0.2059
# Epoch 54/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9888 - loss: 0.0351
# Epoch 54: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9875 - loss: 0.0355 - val_accuracy: 0.9501 - val_loss: 0.2073
# Epoch 55/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9876 - loss: 0.0326
# Epoch 55: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9888 - loss: 0.0321 - val_accuracy: 0.9490 - val_loss: 0.1930
# Epoch 56/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9895 - loss: 0.0311
# Epoch 56: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 256ms/step - accuracy: 0.9890 - loss: 0.0319 - val_accuracy: 0.9480 - val_loss: 0.1854
# Epoch 57/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9892 - loss: 0.0295
# Epoch 57: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 253ms/step - accuracy: 0.9904 - loss: 0.0281 - val_accuracy: 0.9490 - val_loss: 0.2074
# Epoch 58/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9897 - loss: 0.0374
# Epoch 58: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9896 - loss: 0.0334 - val_accuracy: 0.9480 - val_loss: 0.1980
# Epoch 59/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9906 - loss: 0.0273
# Epoch 59: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9889 - loss: 0.0314 - val_accuracy: 0.9553 - val_loss: 0.2166
# Epoch 60/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9889 - loss: 0.0260
# Epoch 60: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9891 - loss: 0.0299 - val_accuracy: 0.9469 - val_loss: 0.2281
# Epoch 61/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9910 - loss: 0.0262
# Epoch 61: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9903 - loss: 0.0266 - val_accuracy: 0.9438 - val_loss: 0.2333
# Epoch 62/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9900 - loss: 0.0291
# Epoch 62: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9909 - loss: 0.0275 - val_accuracy: 0.9407 - val_loss: 0.2958
# Epoch 63/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9883 - loss: 0.0322
# Epoch 63: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9876 - loss: 0.0320 - val_accuracy: 0.9490 - val_loss: 0.2714
# Epoch 64/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9869 - loss: 0.0419
# Epoch 64: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9891 - loss: 0.0326 - val_accuracy: 0.9521 - val_loss: 0.2274
# Epoch 65/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9894 - loss: 0.0332
# Epoch 65: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9909 - loss: 0.0278 - val_accuracy: 0.9501 - val_loss: 0.2452
# Epoch 66/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9913 - loss: 0.0243
# Epoch 66: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9910 - loss: 0.0272 - val_accuracy: 0.9521 - val_loss: 0.2129
# Epoch 67/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9909 - loss: 0.0262
# Epoch 67: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9905 - loss: 0.0267 - val_accuracy: 0.9501 - val_loss: 0.1893
# Epoch 68/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9886 - loss: 0.0302
# Epoch 68: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 253ms/step - accuracy: 0.9895 - loss: 0.0296 - val_accuracy: 0.9521 - val_loss: 0.1807
# Epoch 69/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9897 - loss: 0.0288
# Epoch 69: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9898 - loss: 0.0299 - val_accuracy: 0.9490 - val_loss: 0.1785
# Epoch 70/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9901 - loss: 0.0264
# Epoch 70: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9884 - loss: 0.0293 - val_accuracy: 0.9511 - val_loss: 0.2212
# Epoch 71/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9932 - loss: 0.0283
# Epoch 71: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9914 - loss: 0.0309 - val_accuracy: 0.9459 - val_loss: 0.1909
# Epoch 72/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9905 - loss: 0.0296
# Epoch 72: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9911 - loss: 0.0297 - val_accuracy: 0.9553 - val_loss: 0.2546
# Epoch 73/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9914 - loss: 0.0217
# Epoch 73: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 251ms/step - accuracy: 0.9914 - loss: 0.0255 - val_accuracy: 0.9532 - val_loss: 0.1961
# Epoch 74/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9885 - loss: 0.0371
# Epoch 74: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9897 - loss: 0.0286 - val_accuracy: 0.9511 - val_loss: 0.1672
# Epoch 75/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9935 - loss: 0.0195
# Epoch 75: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9927 - loss: 0.0202 - val_accuracy: 0.9490 - val_loss: 0.2285
# Epoch 76/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9897 - loss: 0.0290
# Epoch 76: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9909 - loss: 0.0267 - val_accuracy: 0.9532 - val_loss: 0.2214
# Epoch 77/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9895 - loss: 0.0341
# Epoch 77: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9890 - loss: 0.0347 - val_accuracy: 0.9459 - val_loss: 0.1921
# Epoch 78/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9915 - loss: 0.0249
# Epoch 78: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9917 - loss: 0.0247 - val_accuracy: 0.9511 - val_loss: 0.2100
# Epoch 79/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9908 - loss: 0.0253
# Epoch 79: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9910 - loss: 0.0263 - val_accuracy: 0.9428 - val_loss: 0.2711
# Epoch 80/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9917 - loss: 0.0247
# Epoch 80: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9906 - loss: 0.0267 - val_accuracy: 0.9501 - val_loss: 0.2485
# Epoch 81/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9950 - loss: 0.0143
# Epoch 81: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9928 - loss: 0.0213 - val_accuracy: 0.9490 - val_loss: 0.2140
# Epoch 82/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9934 - loss: 0.0246
# Epoch 82: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9917 - loss: 0.0255 - val_accuracy: 0.9490 - val_loss: 0.2389
# Epoch 83/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9928 - loss: 0.0215
# Epoch 83: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9925 - loss: 0.0217 - val_accuracy: 0.9469 - val_loss: 0.2484
# Epoch 84/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9909 - loss: 0.0286
# Epoch 84: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 253ms/step - accuracy: 0.9923 - loss: 0.0243 - val_accuracy: 0.9459 - val_loss: 0.2678
# Epoch 85/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9908 - loss: 0.0243
# Epoch 85: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9917 - loss: 0.0229 - val_accuracy: 0.9501 - val_loss: 0.2110
# Epoch 86/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9919 - loss: 0.0263
# Epoch 86: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9916 - loss: 0.0257 - val_accuracy: 0.9521 - val_loss: 0.2089
# Epoch 87/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9945 - loss: 0.0180
# Epoch 87: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9920 - loss: 0.0227 - val_accuracy: 0.9532 - val_loss: 0.2184
# Epoch 88/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9925 - loss: 0.0229
# Epoch 88: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9933 - loss: 0.0194 - val_accuracy: 0.9428 - val_loss: 0.2587
# Epoch 89/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9920 - loss: 0.0236
# Epoch 89: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 253ms/step - accuracy: 0.9919 - loss: 0.0251 - val_accuracy: 0.9532 - val_loss: 0.2299
# Epoch 90/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9933 - loss: 0.0244
# Epoch 90: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9927 - loss: 0.0262 - val_accuracy: 0.9501 - val_loss: 0.2112
# Epoch 91/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9950 - loss: 0.0164
# Epoch 91: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9941 - loss: 0.0173 - val_accuracy: 0.9469 - val_loss: 0.2700
# Epoch 92/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9911 - loss: 0.0267
# Epoch 92: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9917 - loss: 0.0254 - val_accuracy: 0.9490 - val_loss: 0.2360
# Epoch 93/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9916 - loss: 0.0221
# Epoch 93: val_accuracy did not improve from 0.95630
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9908 - loss: 0.0257 - val_accuracy: 0.9459 - val_loss: 0.2810
# Epoch 94/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9956 - loss: 0.0150
# Epoch 94: val_accuracy improved from 0.95630 to 0.95734, saving model to F:/Milon/D1/D1_256/Result/temp/a/a10.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9938 - loss: 0.0182 - val_accuracy: 0.9573 - val_loss: 0.2168
# Epoch 95/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9925 - loss: 0.0241
# Epoch 95: val_accuracy did not improve from 0.95734
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 255ms/step - accuracy: 0.9927 - loss: 0.0215 - val_accuracy: 0.9553 - val_loss: 0.2517
# Epoch 96/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9930 - loss: 0.0200
# Epoch 96: val_accuracy improved from 0.95734 to 0.95838, saving model to F:/Milon/D1/D1_256/Result/temp/a/a10.best.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 256ms/step - accuracy: 0.9925 - loss: 0.0218 - val_accuracy: 0.9584 - val_loss: 0.2004
# Epoch 97/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9933 - loss: 0.0218
# Epoch 97: val_accuracy did not improve from 0.95838
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9924 - loss: 0.0227 - val_accuracy: 0.9376 - val_loss: 0.2493
# Epoch 98/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9930 - loss: 0.0234
# Epoch 98: val_accuracy did not improve from 0.95838
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 68s 252ms/step - accuracy: 0.9927 - loss: 0.0213 - val_accuracy: 0.9563 - val_loss: 0.2301
# Epoch 99/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9931 - loss: 0.0208
# Epoch 99: val_accuracy did not improve from 0.95838
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 254ms/step - accuracy: 0.9946 - loss: 0.0184 - val_accuracy: 0.9521 - val_loss: 0.2252
# Epoch 100/100
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9910 - loss: 0.0267
# Epoch 100: val_accuracy did not improve from 0.95838
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 69s 253ms/step - accuracy: 0.9914 - loss: 0.0266 - val_accuracy: 0.9563 - val_loss: 0.1904
# Score for fold 10: loss of 0.20044881105422974; compile_metrics of 95.83767056465149%
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step
# Confusion Matrix
# [[399  16]
#  [ 24 522]]
# Classification Report
#               precision    recall  f1-score   support
#
#          ScZ       0.94      0.96      0.95       415
#      Healthy       0.97      0.96      0.96       546
#
#     accuracy                           0.96       961
#    macro avg       0.96      0.96      0.96       961
# weighted avg       0.96      0.96      0.96       961
#
# Fold 10 Detailed Metrics:
# Specificity: 0.9614 (96.14%)
# Sensitivity (Recall): 0.9560 (95.60%)
# Precision: 0.9703 (97.03%)
# F1 Score: 0.9631 (96.31%)
# FPR: 0.0386 (3.86%)
# ------------------------------------------------------------------------

# %%
# == Provide average scores ==
print('========================================================================')
print('                          COMPREHENSIVE RESULTS                        ')
print('========================================================================')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1}:')
  print(f'  - Accuracy: {acc_per_fold[i]:.2f}%')
  print(f'  - Loss: {loss_per_fold[i]:.4f}')
  print(f'  - Specificity: {specificity_per_fold[i]:.2f}%')
  print(f'  - Sensitivity: {sensitivity_per_fold[i]:.2f}%')
  print(f'  - Precision: {precision_per_fold[i]:.2f}%')
  print(f'  - F1 Score: {f1_per_fold[i]:.2f}%')
  print(f'  - FPR: {fpr_per_fold[i]:.2f}%')

print('========================================================================')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):.2f}% (± {np.std(acc_per_fold):.2f}%)')
print(f'> Loss: {np.mean(loss_per_fold):.4f} (± {np.std(loss_per_fold):.4f})')
print(f'> Specificity: {np.mean(specificity_per_fold):.2f}% (± {np.std(specificity_per_fold):.2f}%)')
print(f'> Sensitivity: {np.mean(sensitivity_per_fold):.2f}% (± {np.std(sensitivity_per_fold):.2f}%)')
print(f'> Precision: {np.mean(precision_per_fold):.2f}% (± {np.std(precision_per_fold):.2f}%)')
print(f'> F1 Score: {np.mean(f1_per_fold):.2f}% (± {np.std(f1_per_fold):.2f}%)')
print(f'> FPR: {np.mean(fpr_per_fold):.2f}% (± {np.std(fpr_per_fold):.2f}%)')
print('========================================================================')

# Fold-wise performance visualization
plt.figure(figsize=(20, 14))
plt.rcParams.update({'font.size': 12})  # Set global font size

# Plot each metric across folds
metrics = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
metric_data = [acc_per_fold, specificity_per_fold, sensitivity_per_fold,
               precision_per_fold, f1_per_fold, fpr_per_fold]

# Color palette for different metrics
colors = ['#2E86C1', '#28B463', '#F39C12', '#E74C3C', '#8E44AD', '#D35400']

for i, (metric, data) in enumerate(zip(metrics, metric_data)):
    plt.subplot(2, 3, i+1)
    folds = range(1, num_folds+1)

    # Plot main line with enhanced styling
    plt.plot(folds, data, 'o-', linewidth=3, markersize=10, color=colors[i],
             markerfacecolor='white', markeredgewidth=2, markeredgecolor=colors[i],
             label=f'{metric} Values')

    plt.title(f'{metric} Across All Folds', fontsize=16, fontweight='bold', pad=15)
    plt.xlabel('Fold Number', fontsize=14, fontweight='bold')
    plt.ylabel(f'{metric} (%)', fontsize=14, fontweight='bold')
    plt.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
    plt.xticks(folds, fontsize=12, fontweight='bold')
    plt.yticks(fontsize=12, fontweight='bold')

    # Add mean line with improved styling
    mean_val = np.mean(data)
    std_val = np.std(data)
    plt.axhline(y=mean_val, color='red', linestyle='--', linewidth=2, alpha=0.8,
                label=f'Mean: {mean_val:.2f}%')

    # Add standard deviation band
    plt.fill_between(folds, mean_val - std_val, mean_val + std_val,
                     alpha=0.2, color='red', label=f'±1 SD: {std_val:.2f}%')

    # Customize legend
    plt.legend(loc='best', fontsize=11, frameon=True, fancybox=True, shadow=True)

    # Set y-axis limits for better visualization
    if metric != 'FPR':
        plt.ylim(max(0, min(data) - 5), min(100, max(data) + 5))
    else:
        plt.ylim(0, max(data) + 2)

plt.tight_layout(pad=3.0)
plt.suptitle('',
             fontsize=20, fontweight='bold', y=0.98)
plt.show()
# Out:
# ========================================================================
#                           COMPREHENSIVE RESULTS
# ========================================================================
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1:
#   - Accuracy: 96.36%
#   - Loss: 0.1272
#   - Specificity: 95.13%
#   - Sensitivity: 97.36%
#   - Precision: 96.09%
#   - F1 Score: 96.72%
#   - FPR: 4.87%
# ------------------------------------------------------------------------
# > Fold 2:
#   - Accuracy: 95.01%
#   - Loss: 0.2501
#   - Specificity: 94.13%
#   - Sensitivity: 95.75%
#   - Precision: 95.02%
#   - F1 Score: 95.38%
#   - FPR: 5.87%
# ------------------------------------------------------------------------
# > Fold 3:
#   - Accuracy: 96.25%
#   - Loss: 0.1360
#   - Specificity: 97.01%
#   - Sensitivity: 95.63%
#   - Precision: 97.48%
#   - F1 Score: 96.55%
#   - FPR: 2.99%
# ------------------------------------------------------------------------
# > Fold 4:
#   - Accuracy: 96.67%
#   - Loss: 0.1499
#   - Specificity: 95.66%
#   - Sensitivity: 97.60%
#   - Precision: 96.06%
#   - F1 Score: 96.83%
#   - FPR: 4.34%
# ------------------------------------------------------------------------
# > Fold 5:
#   - Accuracy: 97.09%
#   - Loss: 0.1210
#   - Specificity: 96.49%
#   - Sensitivity: 97.57%
#   - Precision: 97.20%
#   - F1 Score: 97.38%
#   - FPR: 3.51%
# ------------------------------------------------------------------------
# > Fold 6:
#   - Accuracy: 96.77%
#   - Loss: 0.1116
#   - Specificity: 97.15%
#   - Sensitivity: 96.48%
#   - Precision: 97.75%
#   - F1 Score: 97.11%
#   - FPR: 2.85%
# ------------------------------------------------------------------------
# > Fold 7:
#   - Accuracy: 95.63%
#   - Loss: 0.1971
#   - Specificity: 95.82%
#   - Sensitivity: 95.47%
#   - Precision: 96.56%
#   - F1 Score: 96.02%
#   - FPR: 4.18%
# ------------------------------------------------------------------------
# > Fold 8:
#   - Accuracy: 97.19%
#   - Loss: 0.1236
#   - Specificity: 97.09%
#   - Sensitivity: 97.27%
#   - Precision: 97.80%
#   - F1 Score: 97.53%
#   - FPR: 2.91%
# ------------------------------------------------------------------------
# > Fold 9:
#   - Accuracy: 96.88%
#   - Loss: 0.1643
#   - Specificity: 95.25%
#   - Sensitivity: 98.39%
#   - Precision: 95.70%
#   - F1 Score: 97.03%
#   - FPR: 4.75%
# ------------------------------------------------------------------------
# > Fold 10:
#   - Accuracy: 95.84%
#   - Loss: 0.2004
#   - Specificity: 96.14%
#   - Sensitivity: 95.60%
#   - Precision: 97.03%
#   - F1 Score: 96.31%
#   - FPR: 3.86%
# ========================================================================
# Average scores for all folds:
# > Accuracy: 96.37% (± 0.66%)
# > Loss: 0.1581 (± 0.0425)
# > Specificity: 95.99% (± 0.94%)
# > Sensitivity: 96.71% (± 1.00%)
# > Precision: 96.67% (± 0.89%)
# > F1 Score: 96.69% (± 0.62%)
# > FPR: 4.01% (± 0.94%)
# ========================================================================

# %%
# Radar plot for average performance
from math import pi
import matplotlib.pyplot as plt

# %%
# Create radar plot with enhanced styling
categories_radar = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score']
values = [np.mean(acc_per_fold), np.mean(specificity_per_fold),
          np.mean(sensitivity_per_fold), np.mean(precision_per_fold),
          np.mean(f1_per_fold)]

# Number of variables
N = len(categories_radar)

# Compute angle for each axis
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]  # Complete the circle

# Add values to complete the circle
values += values[:1]

# Create the plot with enhanced styling
fig, ax = plt.subplots(figsize=(14, 14), subplot_kw=dict(projection='polar'))

# Plot the values with enhanced styling
ax.plot(angles, values, 'o-', linewidth=4, color='#2E86C1', alpha=0.8,
        markersize=12, markerfacecolor='white', markeredgewidth=3, markeredgecolor='#2E86C1')
ax.fill(angles, values, alpha=0.3, color='#2E86C1')

# Add labels with proper font sizes - positioned further outside
ax.set_xticks(angles[:-1])
ax.set_xticklabels([])  # Remove default labels

# Manually position category labels further outside
for angle, category in zip(angles[:-1], categories_radar):
    # Position labels much further outside the chart
    label_distance = 115  # Much further than the 100% circle
    ax.text(angle, label_distance, category,
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=16,
            fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.5',
                     facecolor='lightblue',
                     alpha=0.8,
                     edgecolor='navy',
                     linewidth=1))

# Set y-axis limits and labels
ax.set_ylim(0, 100)
ax.set_yticks([20, 40, 60, 80, 100])
ax.set_yticklabels(['20%', '40%', '60%', '80%', '100%'], fontsize=14, fontweight='bold')

# Add enhanced grid
ax.grid(True, alpha=0.4, linewidth=1.2)

# Add values as text with better positioning - closer to the data points
for angle, value in zip(angles[:-1], values[:-1]):
    # Position value labels closer to the actual data points
    value_distance = value + 5  # Just slightly outside the data point
    ax.text(angle, value_distance, f'{value:.1f}%',
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=14,
            fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.3',
                     facecolor='white',
                     edgecolor='#2E86C1',
                     alpha=0.9,
                     linewidth=1.5))

plt.title('Average Performance Metrics - Radar Chart\nSchizophrenia Classification Model Performance',
          size=18, fontweight='bold', pad=70)
plt.tight_layout()
plt.show()

# %%
# Summary comparison plot - All folds on one radar plot
fig, ax = plt.subplots(figsize=(16, 16), subplot_kw=dict(projection='polar'))

# Enhanced colors for better distinction
fold_colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEAA7',
               '#DDA0DD', '#98D8C8', '#F7DC6F', '#BB8FCE', '#85C1E9']

# Plot each fold on the same radar plot
for fold_idx in range(10):
    fold_values = [acc_per_fold[fold_idx], specificity_per_fold[fold_idx],
                   sensitivity_per_fold[fold_idx], precision_per_fold[fold_idx],
                   f1_per_fold[fold_idx]]

    # Add values to complete the circle
    fold_values_plot = fold_values + fold_values[:1]

    # Plot the values with enhanced styling
    ax.plot(angles, fold_values_plot, 'o-', linewidth=2,
            color=fold_colors[fold_idx], alpha=0.7, markersize=6,
            label=f'Fold {fold_idx + 1} (Avg: {np.mean(fold_values):.1f}%)')
    ax.fill(angles, fold_values_plot, alpha=0.1, color=fold_colors[fold_idx])

# Plot average line with enhanced styling
avg_values = [np.mean(acc_per_fold), np.mean(specificity_per_fold),
              np.mean(sensitivity_per_fold), np.mean(precision_per_fold),
              np.mean(f1_per_fold)]
avg_values_plot = avg_values + avg_values[:1]

ax.plot(angles, avg_values_plot, 'o-', linewidth=5,
        color='red', alpha=0.9, markersize=12,
        markerfacecolor='white', markeredgewidth=3, markeredgecolor='red',
        label=f'Average Performance ({np.mean(avg_values):.1f}%)', zorder=10)
ax.fill(angles, avg_values_plot, alpha=0.3, color='red')

# Fix category labels - position them further outside
ax.set_xticks(angles[:-1])
ax.set_xticklabels([])  # Remove default labels

# Manually position category labels further outside the chart
for angle, category in zip(angles[:-1], categories_radar):
    # Position labels much further outside the chart
    label_distance = 120  # Much further than the 100% circle
    ax.text(angle, label_distance, category,
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=16,
            fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.5',
                     facecolor='lightblue',
                     alpha=0.8,
                     edgecolor='navy',
                     linewidth=1))

# Set y-axis limits and labels
ax.set_ylim(0, 100)
ax.set_yticks([20, 40, 60, 80, 100])
ax.set_yticklabels(['20%', '40%', '60%', '80%', '100%'], fontsize=14, fontweight='bold')

# Add enhanced grid
ax.grid(True, alpha=0.4, linewidth=1.2)

# Add comprehensive legend
ax.legend(loc='upper right', bbox_to_anchor=(1.4, 1.1), fontsize=11,
          frameon=True, fancybox=True, shadow=True, ncol=1)

# Add average values as text - positioned closer to data points
for angle, value in zip(angles[:-1], avg_values):
    value_distance = value + 8  # Just slightly outside the data point
    ax.text(angle, value_distance, f'{value:.1f}%',
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=12,
            fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.3',
                     facecolor='red',
                     alpha=0.7,
                     edgecolor='white'))

plt.title('Cross-Validation Performance Comparison\nAll Folds vs Average Performance\nSchizophrenia Classification Model',
          size=18, fontweight='bold', pad=80)
plt.tight_layout()
plt.show()

# %%
# Box Plots with Standard Deviation - Centered Layout
print('Generating comprehensive box plots with standard deviation...')

# Prepare data for box plots
metrics_names = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
metrics_data = [acc_per_fold, specificity_per_fold, sensitivity_per_fold,
                precision_per_fold, f1_per_fold, fpr_per_fold]

# Enhanced color palette
box_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6', '#E67E22']

# Create comprehensive box plot with centered layout
fig = plt.figure(figsize=(24, 16))
fig.suptitle('Performance Metrics Distribution Analysis\nSchizophrenia Classification Model - 10-Fold Cross-Validation\n(Box Plots with Statistical Measures)',
             fontsize=20, fontweight='bold', y=0.95)

# Create subplots with custom positioning for centering
# Top row: 3 plots
for i in range(3):
    ax = plt.subplot(2, 3, i + 1)
    metric_name = metrics_names[i]
    metric_values = metrics_data[i]

    # Create box plot with enhanced styling
    bp = ax.boxplot(metric_values, patch_artist=True, widths=0.7,
                    boxprops=dict(facecolor=box_colors[i], alpha=0.7, linewidth=2),
                    medianprops=dict(color='darkblue', linewidth=3),
                    whiskerprops=dict(linewidth=2),
                    capprops=dict(linewidth=2),
                    flierprops=dict(marker='o', markerfacecolor='red', markersize=8, alpha=0.7))

    # Calculate statistics
    mean_val = np.mean(metric_values)
    std_val = np.std(metric_values)
    median_val = np.median(metric_values)
    min_val = np.min(metric_values)
    max_val = np.max(metric_values)

    # Add mean line with enhanced styling
    ax.axhline(y=mean_val, color='red', linestyle='-', linewidth=3, alpha=0.9,
               label=f'Mean: {mean_val:.2f}%')

    # Add standard deviation bands
    ax.axhline(y=mean_val + std_val, color='orange', linestyle='--', linewidth=2, alpha=0.8,
               label=f'+1 SD: {mean_val + std_val:.2f}%')
    ax.axhline(y=mean_val - std_val, color='orange', linestyle='--', linewidth=2, alpha=0.8,
               label=f'-1 SD: {mean_val - std_val:.2f}%')
    ax.fill_between([0.5, 1.5], mean_val - std_val, mean_val + std_val, alpha=0.25, color='orange')

    # Enhanced plot customization
    ax.set_title(f'{metric_name} Distribution', fontsize=16, fontweight='bold', pad=15)
    ax.set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
    ax.legend(loc='upper right', fontsize=11, frameon=True, fancybox=True, shadow=True)

    # Enhanced statistics text box
    stats_text = f'📊 Statistics:\nMean: {mean_val:.2f}%\nStd Dev: {std_val:.2f}%\nMedian: {median_val:.2f}%\nRange: {min_val:.2f}% - {max_val:.2f}%\nCV: {(std_val/mean_val)*100:.1f}%'
    ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, fontsize=11, fontweight='bold',
            verticalalignment='top',
            bbox=dict(boxstyle='round,pad=0.5', facecolor='white', alpha=0.9,
                     edgecolor=box_colors[i], linewidth=2))

    # Enhanced x-axis labeling
    ax.set_xticklabels([metric_name], fontsize=14, fontweight='bold')
    ax.tick_params(axis='y', labelsize=12, labelcolor='black')

    # Set appropriate y-limits
    y_min = max(0, min_val - std_val - 5)
    y_max = min(100 if metric_name != 'FPR' else max_val + std_val + 5, max_val + std_val + 5)
    ax.set_ylim(y_min, y_max)

# Bottom row: 3 plots centered (using positions 4, 5, 6 which centers them)
for i in range(3, 6):
    ax = plt.subplot(2, 3, i + 1)
    metric_name = metrics_names[i]
    metric_values = metrics_data[i]

    # Create box plot with enhanced styling
    bp = ax.boxplot(metric_values, patch_artist=True, widths=0.7,
                    boxprops=dict(facecolor=box_colors[i], alpha=0.7, linewidth=2),
                    medianprops=dict(color='darkblue', linewidth=3),
                    whiskerprops=dict(linewidth=2),
                    capprops=dict(linewidth=2),
                    flierprops=dict(marker='o', markerfacecolor='red', markersize=8, alpha=0.7))

    # Calculate statistics
    mean_val = np.mean(metric_values)
    std_val = np.std(metric_values)
    median_val = np.median(metric_values)
    min_val = np.min(metric_values)
    max_val = np.max(metric_values)

    # Add mean line with enhanced styling
    ax.axhline(y=mean_val, color='red', linestyle='-', linewidth=3, alpha=0.9,
               label=f'Mean: {mean_val:.2f}%')

    # Add standard deviation bands
    ax.axhline(y=mean_val + std_val, color='orange', linestyle='--', linewidth=2, alpha=0.8,
               label=f'+1 SD: {mean_val + std_val:.2f}%')
    ax.axhline(y=mean_val - std_val, color='orange', linestyle='--', linewidth=2, alpha=0.8,
               label=f'-1 SD: {mean_val - std_val:.2f}%')
    ax.fill_between([0.5, 1.5], mean_val - std_val, mean_val + std_val, alpha=0.25, color='orange')

    # Enhanced plot customization
    ax.set_title(f'{metric_name} Distribution', fontsize=16, fontweight='bold', pad=15)
    ax.set_ylabel('Percentage (%)', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
    ax.legend(loc='upper right', fontsize=11, frameon=True, fancybox=True, shadow=True)

    # Enhanced statistics text box
    stats_text = f'📊 Statistics:\nMean: {mean_val:.2f}%\nStd Dev: {std_val:.2f}%\nMedian: {median_val:.2f}%\nRange: {min_val:.2f}% - {max_val:.2f}%\nCV: {(std_val/mean_val)*100:.1f}%'
    ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, fontsize=11, fontweight='bold',
            verticalalignment='top',
            bbox=dict(boxstyle='round,pad=0.5', facecolor='white', alpha=0.9,
                     edgecolor=box_colors[i], linewidth=2))

    # Enhanced x-axis labeling
    ax.set_xticklabels([metric_name], fontsize=14, fontweight='bold')
    ax.tick_params(axis='y', labelsize=12, labelcolor='black')

    # Set appropriate y-limits
    y_min = max(0, min_val - std_val - 5)
    y_max = min(100 if metric_name != 'FPR' else max_val + std_val + 5, max_val + std_val + 5)
    ax.set_ylim(y_min, y_max)

plt.tight_layout(pad=3.0)
plt.subplots_adjust(top=0.90)  # Adjust for the main title
plt.show()
# Out:
# Generating comprehensive box plots with standard deviation...
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\1756891483.py:126: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(pad=3.0)
# f:\code\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Combined Box Plot - All metrics together for comparison
plt.figure(figsize=(14, 10))

# Prepare data for combined box plot (excluding FPR for better scale)
combined_data = [acc_per_fold, specificity_per_fold, sensitivity_per_fold,
                 precision_per_fold, f1_per_fold]
combined_labels = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score']

# Enhanced color palette
combined_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6']

# Create combined box plot with enhanced styling
bp = plt.boxplot(combined_data, labels=combined_labels, patch_artist=True, widths=0.7,
                 boxprops=dict(linewidth=2),
                 medianprops=dict(color='darkblue', linewidth=3),
                 whiskerprops=dict(linewidth=2),
                 capprops=dict(linewidth=2),
                 flierprops=dict(marker='o', markerfacecolor='red', markersize=8, alpha=0.7))

# Color each box differently with enhanced styling
for patch, color in zip(bp['boxes'], combined_colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

# Calculate means and stds
means = [np.mean(data) for data in combined_data]
stds = [np.std(data) for data in combined_data]

# Find the maximum value in the data to position mean markers above
max_values = [np.max(data) for data in combined_data]

# Add mean diamonds OUTSIDE/ABOVE each box plot
for i, (mean_val, std_val, max_val) in enumerate(zip(means, stds, max_values)):
    # Position mean marker above the box plot
    mean_position = max_val + 1.5  # Position above the highest point

    plt.plot(i+1, mean_position, 'D', color='red', markersize=12, markeredgecolor='darkred',
             markeredgewidth=2, label='Mean Values' if i == 0 else "", zorder=10)

    # Add text label with mean value
    plt.text(i+1, mean_position + 0.5, f'{mean_val:.1f}%',
             horizontalalignment='center', fontsize=11, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8, edgecolor='red'))

    # Add error bars for standard deviation - also positioned above
    plt.errorbar(i+1, mean_position, yerr=std_val, fmt='none', color='red',
                 capsize=8, capthick=2, linewidth=2, alpha=0.8,
                 label='±1 Standard Deviation' if i == 0 else "")

# Adjust y-axis to reduce gaps and focus on the data range
data_min = min([np.min(data) for data in combined_data])
data_max = max([np.max(data) for data in combined_data])
mean_position_max = max([np.max(data) + 1.5 for data in combined_data])

# Set tighter y-limits to reduce empty space
y_min = data_min - 1  # Small buffer below minimum
y_max = mean_position_max + 2  # Small buffer above mean markers
plt.ylim(y_min, y_max)

# Enhanced plot styling
plt.title('Performance Metrics Comparative Analysis\nSchizophrenia Classification Model (10-Fold Cross-Validation)\nCombined Distribution Overview',
          fontsize=18, fontweight='bold', pad=20)
plt.ylabel('Performance Score (%)', fontsize=16, fontweight='bold')
plt.xlabel('Performance Metrics', fontsize=16, fontweight='bold')
plt.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)

# Enhanced axis styling
plt.xticks(fontsize=14, fontweight='bold', rotation=15)
plt.yticks(fontsize=12, fontweight='bold')

# Enhanced legend
plt.legend(loc='upper left', fontsize=12, frameon=True, fancybox=True, shadow=True)

# Enhanced statistics table - positioned OUTSIDE the plot area
stats_text = "📊 PERFORMANCE SUMMARY\n" + "="*35 + "\n"
for i, (label, data) in enumerate(zip(combined_labels, combined_data)):
    mean_val = np.mean(data)
    std_val = np.std(data)
    cv = (std_val/mean_val)*100  # Coefficient of variation
    stats_text += f"{label}:\n  Mean: {mean_val:.2f}% (±{std_val:.2f}%)\n  CV: {cv:.1f}%\n\n"

# Position the statistics box outside the plot area (to the right)
plt.text(1.02, 0.98, stats_text, transform=plt.gca().transAxes, fontsize=11, fontweight='bold',
         verticalalignment='top', horizontalalignment='left',
         bbox=dict(boxstyle='round,pad=0.5', facecolor='lightblue', alpha=0.9,
                  edgecolor='darkblue', linewidth=2))

plt.tight_layout()
# Adjust layout to make room for external statistics box
plt.subplots_adjust(right=0.75)
plt.show()
# Out:
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\3907595124.py:13: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot(combined_data, labels=combined_labels, patch_artist=True, widths=0.7,
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\3907595124.py:88: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# f:\code\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Separate FPR Box Plot with Statistics Box Outside
plt.figure(figsize=(12, 10))  # Increased width to accommodate external stats

# Create subplot to control layout better
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

# Enhanced styling for FPR box plot
bp = ax.boxplot(fpr_per_fold, patch_artist=True, widths=0.7,
                boxprops=dict(facecolor='#E67E22', alpha=0.7, linewidth=2),
                medianprops=dict(color='darkblue', linewidth=3),
                whiskerprops=dict(linewidth=2),
                capprops=dict(linewidth=2),
                flierprops=dict(marker='o', markerfacecolor='red', markersize=10, alpha=0.7))

# Calculate FPR statistics
fpr_mean = np.mean(fpr_per_fold)
fpr_std = np.std(fpr_per_fold)
fpr_median = np.median(fpr_per_fold)
fpr_cv = (fpr_std/fpr_mean)*100

# Add mean line with enhanced styling
ax.axhline(y=fpr_mean, color='red', linestyle='-', linewidth=3, alpha=0.9,
           label=f'Mean: {fpr_mean:.2f}%')

# Add standard deviation bands
ax.axhline(y=fpr_mean + fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
           label=f'+1 SD: {fpr_mean + fpr_std:.2f}%')
ax.axhline(y=fpr_mean - fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
           label=f'-1 SD: {fpr_mean - fpr_std:.2f}%')
ax.fill_between([0.5, 1.5], fpr_mean - fpr_std, fpr_mean + fpr_std, alpha=0.25, color='orange')

# Enhanced plot styling
ax.set_title('False Positive Rate (FPR) Distribution Analysis\nSchizophrenia Classification Model\n10-Fold Cross-Validation Results',
             fontsize=16, fontweight='bold', pad=20)
ax.set_ylabel('False Positive Rate (%)', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)

# Enhanced legend
ax.legend(loc='upper right', fontsize=12, frameon=True, fancybox=True, shadow=True)

# Enhanced x-axis labeling
ax.set_xticks([1])
ax.set_xticklabels(['False Positive Rate'], fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=12)

# Method 1: Position statistics box to the right of the plot
fpr_stats_text = f'📊 FPR STATISTICS\n{"="*25}\nMean: {fpr_mean:.2f}%\nStd Dev: {fpr_std:.2f}%\nMedian: {fpr_median:.2f}%\nRange: {np.min(fpr_per_fold):.2f}% - {np.max(fpr_per_fold):.2f}%\nCV: {fpr_cv:.1f}%\n\n💡 Lower FPR is Better\n(Fewer False Positives)'

# Position the text box outside the plot area (to the right)
ax.text(1.02, 0.98, fpr_stats_text, transform=ax.transAxes, fontsize=12, fontweight='bold',
        verticalalignment='top', horizontalalignment='left',
        bbox=dict(boxstyle='round,pad=0.5', facecolor='lightyellow', alpha=0.9,
                 edgecolor='orange', linewidth=2))

# Adjust layout to prevent clipping of the external text box
plt.tight_layout()
plt.subplots_adjust(right=0.7)  # Leave space on the right for the statistics box
plt.show()

# Alternative Method 2: Position statistics box below the plot
plt.figure(figsize=(10, 12))  # Increased height to accommodate bottom stats
fig, ax = plt.subplots(1, 1, figsize=(10, 12))

# Same box plot code as above
bp = ax.boxplot(fpr_per_fold, patch_artist=True, widths=0.7,
                boxprops=dict(facecolor='#E67E22', alpha=0.7, linewidth=2),
                medianprops=dict(color='darkblue', linewidth=3),
                whiskerprops=dict(linewidth=2),
                capprops=dict(linewidth=2),
                flierprops=dict(marker='o', markerfacecolor='red', markersize=10, alpha=0.7))

# Add mean line and bands
ax.axhline(y=fpr_mean, color='red', linestyle='-', linewidth=3, alpha=0.9,
           label=f'Mean: {fpr_mean:.2f}%')
ax.axhline(y=fpr_mean + fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
           label=f'+1 SD: {fpr_mean + fpr_std:.2f}%')
ax.axhline(y=fpr_mean - fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
           label=f'-1 SD: {fpr_mean - fpr_std:.2f}%')
ax.fill_between([0.5, 1.5], fpr_mean - fpr_std, fpr_mean + fpr_std, alpha=0.25, color='orange')

# Plot styling
ax.set_title('False Positive Rate (FPR) Distribution Analysis\nSchizophrenia Classification Model\n10-Fold Cross-Validation Results',
             fontsize=16, fontweight='bold', pad=20)
ax.set_ylabel('False Positive Rate (%)', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
ax.legend(loc='upper right', fontsize=12, frameon=True, fancybox=True, shadow=True)
ax.set_xticks([1])
ax.set_xticklabels(['False Positive Rate'], fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=12)

# Position the text box below the plot
ax.text(0.5, -0.15, fpr_stats_text, transform=ax.transAxes, fontsize=12, fontweight='bold',
        verticalalignment='top', horizontalalignment='center',
        bbox=dict(boxstyle='round,pad=0.5', facecolor='lightyellow', alpha=0.9,
                 edgecolor='orange', linewidth=2))

# Adjust layout to prevent clipping of the external text box
plt.tight_layout()
plt.subplots_adjust(bottom=0.25)  # Leave space at the bottom for the statistics box
plt.show()

# Method 3: Create a separate subplot for statistics (most professional)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), gridspec_kw={'width_ratios': [3, 1]})

# Main box plot in the left subplot
bp = ax1.boxplot(fpr_per_fold, patch_artist=True, widths=0.7,
                 boxprops=dict(facecolor='#E67E22', alpha=0.7, linewidth=2),
                 medianprops=dict(color='darkblue', linewidth=3),
                 whiskerprops=dict(linewidth=2),
                 capprops=dict(linewidth=2),
                 flierprops=dict(marker='o', markerfacecolor='red', markersize=10, alpha=0.7))

# Add mean line and bands
ax1.axhline(y=fpr_mean, color='red', linestyle='-', linewidth=3, alpha=0.9,
            label=f'Mean: {fpr_mean:.2f}%')
ax1.axhline(y=fpr_mean + fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
            label=f'+1 SD: {fpr_mean + fpr_std:.2f}%')
ax1.axhline(y=fpr_mean - fpr_std, color='orange', linestyle='--', linewidth=2, alpha=0.8,
            label=f'-1 SD: {fpr_mean - fpr_std:.2f}%')
ax1.fill_between([0.5, 1.5], fpr_mean - fpr_std, fpr_mean + fpr_std, alpha=0.25, color='orange')

# Main plot styling
ax1.set_title('False Positive Rate (FPR) Distribution Analysis\nSchizophrenia Classification Model\n10-Fold Cross-Validation Results',
              fontsize=16, fontweight='bold', pad=20)
ax1.set_ylabel('False Positive Rate (%)', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.4, linestyle='-', linewidth=0.8)
ax1.legend(loc='upper right', fontsize=12, frameon=True, fancybox=True, shadow=True)
ax1.set_xticks([1])
ax1.set_xticklabels(['False Positive Rate'], fontsize=14, fontweight='bold')
ax1.tick_params(axis='y', labelsize=12)

# Statistics panel in the right subplot
ax2.axis('off')  # Hide axes for the statistics panel
ax2.text(0.1, 0.9, fpr_stats_text, transform=ax2.transAxes, fontsize=14, fontweight='bold',
         verticalalignment='top', horizontalalignment='left',
         bbox=dict(boxstyle='round,pad=0.8', facecolor='lightyellow', alpha=0.9,
                  edgecolor='orange', linewidth=3))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\5396930.py:56: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\5396930.py:56: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# f:\code\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\code\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\5396930.py:98: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\5396930.py:98: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# f:\code\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\code\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\5396930.py:139: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\IIT\AppData\Local\Temp\ipykernel_14236\5396930.py:139: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# f:\code\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\code\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print("Box plot analysis complete!")
print("="*80)

# Combined Confusion Matrix
print('========================================================================')
print('                       COMBINED CONFUSION MATRIX                       ')
print('========================================================================')

# Calculate combined confusion matrix
combined_confusion = confusion_matrix(all_y_true, all_y_pred)
print('Combined Confusion Matrix across all folds:')
print(combined_confusion)

# Calculate overall metrics from combined confusion matrix
tn_total, fp_total, fn_total, tp_total = combined_confusion.ravel()

overall_accuracy = (tp_total + tn_total) / (tp_total + tn_total + fp_total + fn_total) * 100
overall_specificity = tn_total / (tn_total + fp_total) * 100 if (tn_total + fp_total) > 0 else 0
overall_sensitivity = tp_total / (tp_total + fn_total) * 100 if (tp_total + fn_total) > 0 else 0
overall_precision = tp_total / (tp_total + fp_total) * 100 if (tp_total + fp_total) > 0 else 0
overall_f1 = 2 * (overall_precision/100 * overall_sensitivity/100) / (overall_precision/100 + overall_sensitivity/100) * 100 if (overall_precision + overall_sensitivity) > 0 else 0
overall_fpr = fp_total / (fp_total + tn_total) * 100 if (fp_total + tn_total) > 0 else 0

print('\nOverall Performance from Combined Matrix:')
print(f'Overall Accuracy: {overall_accuracy:.2f}%')
print(f'Overall Specificity: {overall_specificity:.2f}%')
print(f'Overall Sensitivity: {overall_sensitivity:.2f}%')
print(f'Overall Precision: {overall_precision:.2f}%')
print(f'Overall F1 Score: {overall_f1:.2f}%')
print(f'Overall FPR: {overall_fpr:.2f}%')

# Enhanced Combined Confusion Matrix Visualization
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# Left plot: Confusion Matrix Heatmap
sns.heatmap(combined_confusion, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=ax1, cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 16, 'weight': 'bold'})

ax1.set_title('Combined Confusion Matrix\nAll Folds (10-Fold Cross-Validation)\nSchizophrenia Classification',
              fontsize=16, fontweight='bold', pad=20)
ax1.set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
ax1.set_ylabel('True Labels', fontsize=14, fontweight='bold')
ax1.tick_params(labelsize=12)

# Add percentage annotations
total_samples = np.sum(combined_confusion)
for i in range(2):
    for j in range(2):
        percentage = (combined_confusion[i, j] / total_samples) * 100
        ax1.text(j + 0.5, i + 0.7, f'({percentage:.1f}%)',
                ha='center', va='center', fontsize=12, fontweight='bold', color='darkred')

# Right plot: Performance Metrics Bar Chart
metrics_names_final = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
overall_values = [overall_accuracy, overall_specificity, overall_sensitivity,
                  overall_precision, overall_f1, overall_fpr]
bar_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6', '#E67E22']

bars = ax2.bar(metrics_names_final, overall_values, color=bar_colors, alpha=0.8,
               edgecolor='black', linewidth=1.5)

# Add value labels on bars
for bar, value in zip(bars, overall_values):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 1,
             f'{value:.2f}%', ha='center', va='bottom',
             fontsize=12, fontweight='bold')

ax2.set_title('Overall Performance Metrics\nCombined Results from All Folds',
              fontsize=16, fontweight='bold', pad=20)
ax2.set_ylabel('Performance Score (%)', fontsize=14, fontweight='bold')
ax2.set_xlabel('Performance Metrics', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.4, axis='y')
ax2.set_ylim(0, max(overall_values) + 10)

# Rotate x-axis labels for better readability
ax2.tick_params(axis='x', labelsize=12, labelrotation=45)
ax2.tick_params(axis='y', labelsize=12)

plt.tight_layout()
plt.show()

# Additional detailed confusion matrix analysis
print('\n' + '='*80)
print('                    DETAILED CONFUSION MATRIX ANALYSIS                 ')
print('='*80)

# Classification metrics breakdown
print(f'\n📊 SAMPLE DISTRIBUTION:')
print(f'Total Samples: {total_samples}')
print(f'Schizophrenia Samples: {combined_confusion[0,0] + combined_confusion[0,1]} ({((combined_confusion[0,0] + combined_confusion[0,1])/total_samples)*100:.1f}%)')
print(f'Healthy Control Samples: {combined_confusion[1,0] + combined_confusion[1,1]} ({((combined_confusion[1,0] + combined_confusion[1,1])/total_samples)*100:.1f}%)')

print(f'\n🎯 PREDICTION RESULTS:')
print(f'True Positives (TP): {tp_total} - Correctly identified Healthy Controls')
print(f'True Negatives (TN): {tn_total} - Correctly identified Schizophrenia cases')
print(f'False Positives (FP): {fp_total} - Schizophrenia cases misclassified as Healthy')
print(f'False Negatives (FN): {fn_total} - Healthy cases misclassified as Schizophrenia')

print(f'\n📈 CLINICAL INTERPRETATION:')
print(f'Sensitivity (Recall): {overall_sensitivity:.2f}% - Ability to correctly identify Healthy Controls')
print(f'Specificity: {overall_specificity:.2f}% - Ability to correctly identify Schizophrenia cases')
print(f'Precision: {overall_precision:.2f}% - Reliability of positive predictions (Healthy)')
print(f'F1 Score: {overall_f1:.2f}% - Harmonic mean of precision and recall')
print(f'False Positive Rate: {overall_fpr:.2f}% - Rate of incorrectly classifying Schizophrenia as Healthy')

print('========================================================================')
print('                           ANALYSIS COMPLETE                           ')
print('========================================================================')
# Out:
# Box plot analysis complete!
# ================================================================================
# ========================================================================
#                        COMBINED CONFUSION MATRIX
# ========================================================================
# Combined Confusion Matrix across all folds:
# [[4164  175]
#  [ 174 5097]]
#
# Overall Performance from Combined Matrix:
# Overall Accuracy: 96.37%
# Overall Specificity: 95.97%
# Overall Sensitivity: 96.70%
# Overall Precision: 96.68%
# Overall F1 Score: 96.69%
# Overall FPR: 4.03%
# ================================================================================
#                     DETAILED CONFUSION MATRIX ANALYSIS
# ================================================================================
#
# 📊 SAMPLE DISTRIBUTION:
# Total Samples: 9610
# Schizophrenia Samples: 4339 (45.2%)
# Healthy Control Samples: 5271 (54.8%)
#
# 🎯 PREDICTION RESULTS:
# True Positives (TP): 5097 - Correctly identified Healthy Controls
# True Negatives (TN): 4164 - Correctly identified Schizophrenia cases
# False Positives (FP): 175 - Schizophrenia cases misclassified as Healthy
# False Negatives (FN): 174 - Healthy cases misclassified as Schizophrenia
#
# 📈 CLINICAL INTERPRETATION:
# Sensitivity (Recall): 96.70% - Ability to correctly identify Healthy Controls
# Specificity: 95.97% - Ability to correctly identify Schizophrenia cases
# Precision: 96.68% - Reliability of positive predictions (Healthy)
# F1 Score: 96.69% - Harmonic mean of precision and recall
# False Positive Rate: 4.03% - Rate of incorrectly classifying Schizophrenia as Healthy
# ========================================================================
#                            ANALYSIS COMPLETE
# ========================================================================

# %%
print("Box plot analysis complete!")
print("="*80)

# Combined Confusion Matrix
print('========================================================================')
print('                       COMBINED CONFUSION MATRIX                       ')
print('========================================================================')

# Calculate combined confusion matrix
combined_confusion = confusion_matrix(all_y_true, all_y_pred)
print('Combined Confusion Matrix across all folds:')
print(combined_confusion)

# Calculate overall metrics from combined confusion matrix
tn_total, fp_total, fn_total, tp_total = combined_confusion.ravel()

overall_accuracy = (tp_total + tn_total) / (tp_total + tn_total + fp_total + fn_total) * 100
overall_specificity = tn_total / (tn_total + fp_total) * 100 if (tn_total + fp_total) > 0 else 0
overall_sensitivity = tp_total / (tp_total + fn_total) * 100 if (tp_total + fn_total) > 0 else 0
overall_precision = tp_total / (tp_total + fp_total) * 100 if (tp_total + fp_total) > 0 else 0
overall_f1 = 2 * (overall_precision/100 * overall_sensitivity/100) / (overall_precision/100 + overall_sensitivity/100) * 100 if (overall_precision + overall_sensitivity) > 0 else 0
overall_fpr = fp_total / (fp_total + tn_total) * 100 if (fp_total + tn_total) > 0 else 0

print('\nOverall Performance from Combined Matrix:')
print(f'Overall Accuracy: {overall_accuracy:.2f}%')
print(f'Overall Specificity: {overall_specificity:.2f}%')
print(f'Overall Sensitivity: {overall_sensitivity:.2f}%')
print(f'Overall Precision: {overall_precision:.2f}%')
print(f'Overall F1 Score: {overall_f1:.2f}%')
print(f'Overall FPR: {overall_fpr:.2f}%')

# Enhanced Combined Confusion Matrix Visualization
fig, axes = plt.subplots(2, 2, figsize=(20, 16))

# Top Left: Confusion Matrix Heatmap with Percentages
sns.heatmap(combined_confusion, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[0,0], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 16, 'weight': 'bold'})

axes[0,0].set_title('Combined Confusion Matrix with Percentages\nAll Folds (10-Fold Cross-Validation)',
                    fontsize=16, fontweight='bold', pad=20)
axes[0,0].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0,0].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0,0].tick_params(labelsize=12)

# Add percentage annotations with better color visibility
total_samples = np.sum(combined_confusion)
for i in range(2):
    for j in range(2):
        percentage = (combined_confusion[i, j] / total_samples) * 100
        # Use white color for the TN cell (top-left, dark blue) and dark color for others
        text_color = 'white' if (i == 0 and j == 0) else 'darkred'
        axes[0,0].text(j + 0.5, i + 0.7, f'({percentage:.1f}%)',
                       ha='center', va='center', fontsize=12, fontweight='bold', color=text_color)

# Top Right: Simple Confusion Matrix without Percentages
sns.heatmap(combined_confusion, annot=True, fmt="d", cmap="Greens",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[0,1], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 18, 'weight': 'bold'})

axes[0,1].set_title('Simple Confusion Matrix\nAll Folds (10-Fold Cross-Validation)',
                    fontsize=16, fontweight='bold', pad=20)
axes[0,1].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0,1].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0,1].tick_params(labelsize=12)

# Bottom Left: Performance Metrics Bar Chart
metrics_names_final = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
overall_values = [overall_accuracy, overall_specificity, overall_sensitivity,
                  overall_precision, overall_f1, overall_fpr]
bar_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6', '#E67E22']

bars = axes[1,0].bar(metrics_names_final, overall_values, color=bar_colors, alpha=0.8,
                     edgecolor='black', linewidth=1.5)

# Add value labels on bars
for bar, value in zip(bars, overall_values):
    height = bar.get_height()
    axes[1,0].text(bar.get_x() + bar.get_width()/2., height + 1,
                   f'{value:.2f}%', ha='center', va='bottom',
                   fontsize=12, fontweight='bold')

axes[1,0].set_title('Overall Performance Metrics\nCombined Results from All Folds',
                    fontsize=16, fontweight='bold', pad=20)
axes[1,0].set_ylabel('Performance Score (%)', fontsize=14, fontweight='bold')
axes[1,0].set_xlabel('Performance Metrics', fontsize=14, fontweight='bold')
axes[1,0].grid(True, alpha=0.4, axis='y')
axes[1,0].set_ylim(0, max(overall_values) + 10)

# Rotate x-axis labels for better readability
axes[1,0].tick_params(axis='x', labelsize=12, labelrotation=45)
axes[1,0].tick_params(axis='y', labelsize=12)

# Bottom Right: Confusion Matrix with Classification Labels
# Create a custom annotation with both counts and labels
confusion_labels = np.array([['TN\n' + str(combined_confusion[0,0]), 'FP\n' + str(combined_confusion[0,1])],
                            ['FN\n' + str(combined_confusion[1,0]), 'TP\n' + str(combined_confusion[1,1])]])

sns.heatmap(combined_confusion, annot=confusion_labels, fmt='', cmap="Oranges",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[1,1], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 14, 'weight': 'bold'})

axes[1,1].set_title('Confusion Matrix with Classification Labels\nTN/FP/FN/TP Breakdown',
                    fontsize=16, fontweight='bold', pad=20)
axes[1,1].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[1,1].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[1,1].tick_params(labelsize=12)

plt.tight_layout()
plt.show()

# Additional detailed confusion matrix analysis
print('\n' + '='*80)
print('                    DETAILED CONFUSION MATRIX ANALYSIS                 ')
print('='*80)

# Classification metrics breakdown
print(f'\n📊 SAMPLE DISTRIBUTION:')
print(f'Total Samples: {total_samples}')
print(f'Schizophrenia Samples: {combined_confusion[0,0] + combined_confusion[0,1]} ({((combined_confusion[0,0] + combined_confusion[0,1])/total_samples)*100:.1f}%)')
print(f'Healthy Control Samples: {combined_confusion[1,0] + combined_confusion[1,1]} ({((combined_confusion[1,0] + combined_confusion[1,1])/total_samples)*100:.1f}%)')

print(f'\n🎯 PREDICTION RESULTS:')
print(f'True Positives (TP): {tp_total} - Correctly identified Healthy Controls')
print(f'True Negatives (TN): {tn_total} - Correctly identified Schizophrenia cases')
print(f'False Positives (FP): {fp_total} - Schizophrenia cases misclassified as Healthy')
print(f'False Negatives (FN): {fn_total} - Healthy cases misclassified as Schizophrenia')

print(f'\n📈 CLINICAL INTERPRETATION:')
print(f'Sensitivity (Recall): {overall_sensitivity:.2f}% - Ability to correctly identify Healthy Controls')
print(f'Specificity: {overall_specificity:.2f}% - Ability to correctly identify Schizophrenia cases')
print(f'Precision: {overall_precision:.2f}% - Reliability of positive predictions (Healthy)')
print(f'F1 Score: {overall_f1:.2f}% - Harmonic mean of precision and recall')
print(f'False Positive Rate: {overall_fpr:.2f}% - Rate of incorrectly classifying Schizophrenia as Healthy')

print('========================================================================')
print('                           ANALYSIS COMPLETE                           ')
print('========================================================================')
# Out:
# Box plot analysis complete!
# ================================================================================
# ========================================================================
#                        COMBINED CONFUSION MATRIX
# ========================================================================
# Combined Confusion Matrix across all folds:
# [[4164  175]
#  [ 174 5097]]
#
# Overall Performance from Combined Matrix:
# Overall Accuracy: 96.37%
# Overall Specificity: 95.97%
# Overall Sensitivity: 96.70%
# Overall Precision: 96.68%
# Overall F1 Score: 96.69%
# Overall FPR: 4.03%
# ================================================================================
#                     DETAILED CONFUSION MATRIX ANALYSIS
# ================================================================================
#
# 📊 SAMPLE DISTRIBUTION:
# Total Samples: 9610
# Schizophrenia Samples: 4339 (45.2%)
# Healthy Control Samples: 5271 (54.8%)
#
# 🎯 PREDICTION RESULTS:
# True Positives (TP): 5097 - Correctly identified Healthy Controls
# True Negatives (TN): 4164 - Correctly identified Schizophrenia cases
# False Positives (FP): 175 - Schizophrenia cases misclassified as Healthy
# False Negatives (FN): 174 - Healthy cases misclassified as Schizophrenia
#
# 📈 CLINICAL INTERPRETATION:
# Sensitivity (Recall): 96.70% - Ability to correctly identify Healthy Controls
# Specificity: 95.97% - Ability to correctly identify Schizophrenia cases
# Precision: 96.68% - Reliability of positive predictions (Healthy)
# F1 Score: 96.69% - Harmonic mean of precision and recall
# False Positive Rate: 4.03% - Rate of incorrectly classifying Schizophrenia as Healthy
# ========================================================================
#                            ANALYSIS COMPLETE
# ========================================================================

# %%
print("Box plot analysis complete!")
print("="*80)

# Combined Confusion Matrix
print('========================================================================')
print('                       COMBINED CONFUSION MATRIX                       ')
print('========================================================================')

# Calculate combined confusion matrix
combined_confusion = confusion_matrix(all_y_true, all_y_pred)
print('Combined Confusion Matrix across all folds:')
print(combined_confusion)

# Calculate overall metrics from combined confusion matrix
tn_total, fp_total, fn_total, tp_total = combined_confusion.ravel()

overall_accuracy = (tp_total + tn_total) / (tp_total + tn_total + fp_total + fn_total) * 100
overall_specificity = tn_total / (tn_total + fp_total) * 100 if (tn_total + fp_total) > 0 else 0
overall_sensitivity = tp_total / (tp_total + fn_total) * 100 if (tp_total + fn_total) > 0 else 0
overall_precision = tp_total / (tp_total + fp_total) * 100 if (tp_total + fp_total) > 0 else 0
overall_f1 = 2 * (overall_precision/100 * overall_sensitivity/100) / (overall_precision/100 + overall_sensitivity/100) * 100 if (overall_precision + overall_sensitivity) > 0 else 0
overall_fpr = fp_total / (fp_total + tn_total) * 100 if (fp_total + tn_total) > 0 else 0

print('\nOverall Performance from Combined Matrix:')
print(f'Overall Accuracy: {overall_accuracy:.2f}%')
print(f'Overall Specificity: {overall_specificity:.2f}%')
print(f'Overall Sensitivity: {overall_sensitivity:.2f}%')
print(f'Overall Precision: {overall_precision:.2f}%')
print(f'Overall F1 Score: {overall_f1:.2f}%')
print(f'Overall FPR: {overall_fpr:.2f}%')

# Enhanced Combined Confusion Matrix Visualization
fig, axes = plt.subplots(2, 2, figsize=(20, 16))

# Top Left: Enhanced Confusion Matrix with Percentages and Labels
sns.heatmap(combined_confusion, annot=True, fmt="d", cmap="Greens",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[0,0], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 16, 'weight': 'bold'})

axes[0,0].set_title('Enhanced Confusion Matrix\nWith Percentages and Labels',
                    fontsize=16, fontweight='bold', pad=20)
axes[0,0].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0,0].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0,0].tick_params(labelsize=12)

# Add both percentages and TN/FP/FN/TP labels
total_samples = np.sum(combined_confusion)
labels_map = [['TN', 'FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        percentage = (combined_confusion[i, j] / total_samples) * 100
        # Add TN/FP/FN/TP label
        axes[0,0].text(j + 0.5, i + 0.3, labels_map[i][j],
                       ha='center', va='center', fontsize=14, fontweight='bold', color='black')
        # Add percentage with better visibility - use white for darker green cells
        percentage_color = 'white' if (i == 1 and j == 1) else 'darkred'
        axes[0,0].text(j + 0.5, i + 0.7, f'({percentage:.1f}%)',
                       ha='center', va='center', fontsize=12, fontweight='bold', color=percentage_color)

# Top Right: Confusion Matrix with Classification Labels
# Create a custom annotation with both counts and labels
confusion_labels = np.array([['TN\n' + str(combined_confusion[0,0]), 'FP\n' + str(combined_confusion[0,1])],
                            ['FN\n' + str(combined_confusion[1,0]), 'TP\n' + str(combined_confusion[1,1])]])

sns.heatmap(combined_confusion, annot=confusion_labels, fmt='', cmap="Oranges",
            xticklabels=['Schizophrenia', 'Healthy Control'],
            yticklabels=['Schizophrenia', 'Healthy Control'],
            ax=axes[0,1], cbar_kws={'label': 'Number of Samples'},
            annot_kws={'size': 14, 'weight': 'bold'})

axes[0,1].set_title('Confusion Matrix with Classification Labels\nTN/FP/FN/TP Breakdown',
                    fontsize=16, fontweight='bold', pad=20)
axes[0,1].set_xlabel('Predicted Labels', fontsize=14, fontweight='bold')
axes[0,1].set_ylabel('True Labels', fontsize=14, fontweight='bold')
axes[0,1].tick_params(labelsize=12)

# Bottom Left: Original Performance Metrics Bar Chart
metrics_names_final = ['Accuracy', 'Specificity', 'Sensitivity', 'Precision', 'F1 Score', 'FPR']
overall_values = [overall_accuracy, overall_specificity, overall_sensitivity,
                  overall_precision, overall_f1, overall_fpr]
bar_colors = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12', '#9B59B6', '#E67E22']

bars = axes[1,0].bar(metrics_names_final, overall_values, color=bar_colors, alpha=0.8,
                     edgecolor='black', linewidth=1.5)

# Add value labels on bars
for bar, value in zip(bars, overall_values):
    height = bar.get_height()
    axes[1,0].text(bar.get_x() + bar.get_width()/2., height + 1,
                   f'{value:.2f}%', ha='center', va='bottom',
                   fontsize=12, fontweight='bold')

axes[1,0].set_title('Performance Metrics (Original)\nCombined Results from All Folds',
                    fontsize=16, fontweight='bold', pad=20)
axes[1,0].set_ylabel('Performance Score (%)', fontsize=14, fontweight='bold')
axes[1,0].set_xlabel('Performance Metrics', fontsize=14, fontweight='bold')
axes[1,0].grid(True, alpha=0.4, axis='y')
axes[1,0].set_ylim(0, max(overall_values) + 10)

# Rotate x-axis labels for better readability
axes[1,0].tick_params(axis='x', labelsize=12, labelrotation=45)
axes[1,0].tick_params(axis='y', labelsize=12)

# Bottom Right: Enhanced Performance Metrics with Better Colors
import matplotlib.colors as mcolors
# Enhanced gradient color palette
enhanced_colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FECA57', '#FF9FF3']

bars2 = axes[1,1].bar(metrics_names_final, overall_values, color=enhanced_colors, alpha=0.9,
                      edgecolor='white', linewidth=2.5)

# Add value labels with contrasting background
for bar, value in zip(bars2, overall_values):
    height = bar.get_height()
    axes[1,1].text(bar.get_x() + bar.get_width()/2., height + 1,
                   f'{value:.2f}%', ha='center', va='bottom',
                   fontsize=12, fontweight='bold', color='black',
                   bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.9, edgecolor='gray'))

axes[1,1].set_title('Performance Metrics (Enhanced)\nWith Improved Color Visualization',
                    fontsize=16, fontweight='bold', pad=20)
axes[1,1].set_ylabel('Performance Score (%)', fontsize=14, fontweight='bold')
axes[1,1].set_xlabel('Performance Metrics', fontsize=14, fontweight='bold')
axes[1,1].grid(True, alpha=0.3, axis='y', linestyle=':', color='gray')
axes[1,1].set_ylim(0, max(overall_values) + 10)
axes[1,1].tick_params(axis='x', labelsize=12, labelrotation=45)
axes[1,1].tick_params(axis='y', labelsize=12)

# Add subtle background gradient
axes[1,1].set_facecolor('#f8f9fa')

plt.tight_layout()
plt.show()

# Additional detailed confusion matrix analysis
print('\n' + '='*80)
print('                    DETAILED CONFUSION MATRIX ANALYSIS                 ')
print('='*80)

# Classification metrics breakdown
print(f'\n📊 SAMPLE DISTRIBUTION:')
print(f'Total Samples: {total_samples}')
print(f'Schizophrenia Samples: {combined_confusion[0,0] + combined_confusion[0,1]} ({((combined_confusion[0,0] + combined_confusion[0,1])/total_samples)*100:.1f}%)')
print(f'Healthy Control Samples: {combined_confusion[1,0] + combined_confusion[1,1]} ({((combined_confusion[1,0] + combined_confusion[1,1])/total_samples)*100:.1f}%)')

print(f'\n🎯 PREDICTION RESULTS:')
print(f'True Positives (TP): {tp_total} - Correctly identified Healthy Controls')
print(f'True Negatives (TN): {tn_total} - Correctly identified Schizophrenia cases')
print(f'False Positives (FP): {fp_total} - Schizophrenia cases misclassified as Healthy')
print(f'False Negatives (FN): {fn_total} - Healthy cases misclassified as Schizophrenia')

print(f'\n📈 CLINICAL INTERPRETATION:')
print(f'Sensitivity (Recall): {overall_sensitivity:.2f}% - Ability to correctly identify Healthy Controls')
print(f'Specificity: {overall_specificity:.2f}% - Ability to correctly identify Schizophrenia cases')
print(f'Precision: {overall_precision:.2f}% - Reliability of positive predictions (Healthy)')
print(f'F1 Score: {overall_f1:.2f}% - Harmonic mean of precision and recall')
print(f'False Positive Rate: {overall_fpr:.2f}% - Rate of incorrectly classifying Schizophrenia as Healthy')

print('========================================================================')
print('                           ANALYSIS COMPLETE                           ')
print('========================================================================')
# Out:
# Box plot analysis complete!
# ================================================================================
# ========================================================================
#                        COMBINED CONFUSION MATRIX
# ========================================================================
# Combined Confusion Matrix across all folds:
# [[4164  175]
#  [ 174 5097]]
#
# Overall Performance from Combined Matrix:
# Overall Accuracy: 96.37%
# Overall Specificity: 95.97%
# Overall Sensitivity: 96.70%
# Overall Precision: 96.68%
# Overall F1 Score: 96.69%
# Overall FPR: 4.03%
# ================================================================================
#                     DETAILED CONFUSION MATRIX ANALYSIS
# ================================================================================
#
# 📊 SAMPLE DISTRIBUTION:
# Total Samples: 9610
# Schizophrenia Samples: 4339 (45.2%)
# Healthy Control Samples: 5271 (54.8%)
#
# 🎯 PREDICTION RESULTS:
# True Positives (TP): 5097 - Correctly identified Healthy Controls
# True Negatives (TN): 4164 - Correctly identified Schizophrenia cases
# False Positives (FP): 175 - Schizophrenia cases misclassified as Healthy
# False Negatives (FN): 174 - Healthy cases misclassified as Schizophrenia
#
# 📈 CLINICAL INTERPRETATION:
# Sensitivity (Recall): 96.70% - Ability to correctly identify Healthy Controls
# Specificity: 95.97% - Ability to correctly identify Schizophrenia cases
# Precision: 96.68% - Reliability of positive predictions (Healthy)
# F1 Score: 96.69% - Harmonic mean of precision and recall
# False Positive Rate: 4.03% - Rate of incorrectly classifying Schizophrenia as Healthy
# ========================================================================
#                            ANALYSIS COMPLETE
# ========================================================================
